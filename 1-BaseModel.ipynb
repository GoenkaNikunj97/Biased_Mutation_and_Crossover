# %%
#importing libraries

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from tqdm import tqdm
import numpy as np
import pandas as pd
import random
import copy

# %%
from google.colab import drive
drive.mount('/content/drive')

DataFolder = "/content/drive/My Drive/Colab Notebooks/geneticsProject/data/"

# CONFIG
SAMPLE_SIZE =200
CHANGE_SAMPLE_AFTER = 15
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class Config:
    MAX_INSTRUCTION_SET_LENGTH = 256
    INIT_MAX_INSTRUCTION_SET_LENGTH = 128
    MIN_INSTRUCTION_SET_LENGTH = 8
    TOTAL_OUTPUT_REGISTER = 10
    TOTAL_OPERATIONS = 4

    #PAR TO TUNE!
    GAP_PERCENTAGE = 20
    MUTATION_PROBABILITY = 90
    CROSSOVER_PROBABILITY = 90
    POPULATION_SIZE = 150
    SAME_NUMBER_OF_ITERATIONS = 50

# %% [markdown]
# ### Get Data

# %%
def getDataFromFile(fileName):
  #Read File
  df = pd.read_csv(fileName, sep=" " ,header=None)
  data = df.dropna(axis=1)

  return data

# %%
def getData(target):
  trainFile = DataFolder + target +"/train.txt"
  testFile = DataFolder + target +"/test.txt"

  #Training Data
  trainData =  getDataFromFile(trainFile)

  #Post Training Evaluation
  testData =  getDataFromFile(testFile)

  return trainData,testData

# %%
def getuniformSample(data, sampleSize, lableSize):
  print("CREATING SAMPLE")
  classesIndex = (data.shape)[1] - 1
  allLables = data[classesIndex].unique()

  #empty Sample df
  sample = pd.DataFrame()
  tempData = data[:]

  while(len(sample) < sampleSize):
    lableToSelect = random.choice(allLables)
    dataForClass = tempData[tempData[classesIndex] == (lableToSelect)]
    selectedData = dataForClass.sample(n=1, replace=False)
    sample = sample.append(selectedData)
    tempData.drop(selectedData.index)
    
  return sample

# %%
def splitDataForXandY(data):
  X = data[data.columns[:-1]]
  Y = data[data.columns[-1]]
  
  # one hot encode lable
  Y = pd.get_dummies(Y)
  
  X = X.values.tolist()
  Y = Y.values.tolist()
  
  return X,Y

# %% [markdown]
# ### Creating Individuals and population

# %%
class Individual:
    # Operators = [+, -, /2, *2]
    # Operators = [0, 1,  2 , 3]
    # instructionSet = [ Select | target Register | operator| source ]

    def __init__(self, instructionSet):
        self.instructionSet = instructionSet
        self.registers = [0] * Config.TOTAL_OUTPUT_REGISTER
        self.fitnessScore = 0

    def reset(self):
        self.registers = [0] * Config.TOTAL_OUTPUT_REGISTER

    def resetFitness(self):
        self.fitnessScore = 0

    def isValid(self):
        if( (len(self.instructionSet) > Config.MIN_INSTRUCTION_SET_LENGTH) and (len(self.instructionSet) < Config.MAX_INSTRUCTION_SET_LENGTH)):
            return True
        else:
            return False

    def runProgram(self, data):
        self.reset()
        for instruction in self.instructionSet:
            select = instruction[0]
            target = instruction[1]
            operator = instruction[2]
            source = instruction[3]

            if select == 0:
                source = source%len(data)
                source = data[source]
            else:
                source = source % Config.TOTAL_OUTPUT_REGISTER
                source = self.registers[source]

            if operator == 0:
                self.registers[target] = self.registers[target] + source
            if operator == 1:
                self.registers[target] = self.registers[target] - source
            if operator == 2:
                self.registers[target] = self.registers[target] / 2
            if operator == 3:
                self.registers[target] = self.registers[target] * 2

    def predict(self, data, lable):

        self.runProgram(data)

        maxLableIndex = np.array(lable).argmax()
        maxRegisterIndex = np.array(self.registers[:len(lable)]).argmax()

        if maxLableIndex == maxRegisterIndex:
            return True
        else:
            return False

# %%
def getInstructionSet(dataLen):
  
  configOb = Config()

  #randomly selecting the length of instruction set
  endIndex = random.randint(2,configOb.INIT_MAX_INSTRUCTION_SET_LENGTH)
  instructionSet = list()
  for i in range(endIndex):
    selectBit = random.randint(0,1)
    targetValue = random.randint(0,configOb.TOTAL_OUTPUT_REGISTER - 1)
    operator = random.randint(0,configOb.TOTAL_OPERATIONS - 1)
    source = random.randint(0,max(dataLen, configOb.TOTAL_OUTPUT_REGISTER ) - 1 )

    instruction = [selectBit, targetValue, operator, source]
    instructionSet.append(instruction)

  return instructionSet

# %%
def createGenotype(X):
  dataLen = len(X[0])
  populationList = list()
  for i in range(Config.POPULATION_SIZE):
    individualInstructionSet = getInstructionSet(dataLen)
    individualOb = Individual(individualInstructionSet)
    populationList.append(individualOb)
    
  print(str(len(populationList)) + " individuals created.")
  return populationList

# %% [markdown]
# ### Methods for GL

# %%
class TwoPointCrossover:

    def getTwoCrossoverPoints(self, parent):
        crossoverPoint1 = 0
        crossoverPoint2 = 0

        while (crossoverPoint1 == crossoverPoint2):
            crossoverPoint1 = random.randint(0, len(parent.instructionSet) - 2)
            crossoverPoint2 = random.randint(crossoverPoint1 + 1, len(parent.instructionSet) - 1)

        return crossoverPoint1,crossoverPoint2

    def createChild(self, parent1, parent2, p1CP1,p1CP2, p2CP1,p2CP2 ):

        childInstructionSet = parent1.instructionSet[:p1CP1 - 1]
        childInstructionSet = childInstructionSet + parent2.instructionSet[p2CP1: p2CP2]
        childInstructionSet = childInstructionSet + parent1.instructionSet[p1CP2 + 1:]

        child = Individual(childInstructionSet)

        return child

    def crossover(self, parent1, parent2):

        p1CP1, p1CP2 = self.getTwoCrossoverPoints(parent1)
        p2CP1, p2CP2 = self.getTwoCrossoverPoints(parent2)

        child1 = self.createChild(parent1, parent2, p1CP1, p1CP2, p2CP1, p2CP2)

        child2 = self.createChild(parent2, parent1, p2CP1, p2CP2, p1CP1, p1CP2)

        if (not (child1.isValid())):
            child1 = None
        if (not (child2.isValid())):
            child2 = None

        return child1, child2

# %%
class Mutation:

    mutationTypes = 3

    def swapMutation(self, child):
        bit1 = random.randint(0, len(child.instructionSet) - 1)
        bit2 = random.randint(0, len(child.instructionSet) - 1)
        #print("Swapping bit: ",bit1, "and ", bit2)
        child.instructionSet[bit1], child.instructionSet[bit2] = child.instructionSet[bit2], child.instructionSet[bit1]

        return child

    def reverseMutation(self, child):
        bit1 = random.randint(0, len(child.instructionSet) - 2)
        bit2 = random.randint(bit1+1, len(child.instructionSet) - 1)

        mutatedChild = child.instructionSet[0:bit1] + child.instructionSet[bit2: bit1-1: -1] + child.instructionSet[bit2+1:]
        mutatedChild = Individual(mutatedChild)

        return mutatedChild

    def scrambleMutation(self, child):
        bit1 = random.randint(0, len(child.instructionSet) - 2)
        bit2 = random.randint(bit1 + 1, len(child.instructionSet) - 1)

        temp = child.instructionSet[bit1: bit2]
        random.shuffle(temp)
        mutatedList = child.instructionSet[:bit1] + temp + child.instructionSet[bit2:]
        mutatedChild = Individual(mutatedList)

        return mutatedChild

    def mutateIndividual(self, childToMutate):
        child = childToMutate
        type = random.randint(0, self.mutationTypes - 1)
        if (random.randint(0, 100) < Config.MUTATION_PROBABILITY):
            if (type == 0):
                child = self.swapMutation(child)
            if (type == 1):
                child = self.reverseMutation(child)
            if (type == 2):
                child = self.scrambleMutation(child)

        return child

# %%
def calculateFitness(populationList, data, lable):
  for person in populationList:
    correctPrediction = 0
    person.resetFitness()
    for i in range(len(data)):
      answer = person.predict(data[i] , lable[i])
      correctPrediction += answer

    fitness = 100*(correctPrediction/len(data))
    person.fitnessScore = fitness

# %%
def getGapedPopulation(populationList):
  sortedPopulation = sorted(populationList, key=lambda x: x.fitnessScore, reverse=True)
  
  totalGap = (Config.GAP_PERCENTAGE * len(sortedPopulation)) / 100
  
  gapedPopulation = sortedPopulation[: int(len(sortedPopulation)- totalGap)]
  return gapedPopulation

# %%
def isChildReadyToPush(populationList, child,newPopulation):
  crossoverChance = random.randint(0, 100) < Config.CROSSOVER_PROBABILITY
  if (crossoverChance and (not (child is None)) and (len(newPopulation) < len(populationList))):
    return True
  else:
    return False

# %%
def breed(populationList, gapedPopulation):
  newPopulation = gapedPopulation[:]
  while (len(newPopulation) < len(populationList)):
    parent1 = random.choice(gapedPopulation)
    parent2 = random.choice(gapedPopulation)
    
    child1,child2 = TwoPointCrossover().crossover(parent1, parent2)
    mutationOb = Mutation()
    
    if (isChildReadyToPush(populationList, child1, newPopulation)):
      mutatedChild = mutationOb.mutateIndividual(child1)
      newPopulation.append(mutatedChild)
      
      if (isChildReadyToPush(populationList,child2,newPopulation)):
        mutatedChild = mutationOb.mutateIndividual(child2)
        newPopulation.append(mutatedChild)
  
  return newPopulation

# %% [markdown]
# ### Making Data for visualization

# %%
def pushToGenerationAccuracyDictionary(classwiseAccuracy,classWiseAccuracyInGeneration):
  for key in classwiseAccuracy.keys():
    if key in classWiseAccuracyInGeneration:
      classWiseAccuracyInGeneration[key].append(classwiseAccuracy[key])
    else:
      classWiseAccuracyInGeneration[key] = []
      classWiseAccuracyInGeneration[key].append(classwiseAccuracy[key])

# %%
def calculateClasswiseAccuracy(individual, data, lable, classWiseAccuracyInGeneration):
  classwiseAccuracy = dict()
  for i in range(len(data)):
    lableToPush = tuple(lable[i])
    answer = individual.predict(data[i], lable[i])
    if (answer):
      if (lableToPush in classwiseAccuracy):
        classwiseAccuracy[lableToPush] += 1
      else:
        classwiseAccuracy[lableToPush] = 1
    else:
      if (lableToPush in classwiseAccuracy):
        classwiseAccuracy[lableToPush] += 0
      else:
        classwiseAccuracy[lableToPush] = 0
  pushToGenerationAccuracyDictionary(classwiseAccuracy, classWiseAccuracyInGeneration)

# %% [markdown]
# ### Training Model

# %%
#method to run everything
def runGA(targetFile, accuracy):
  trainData,testData = getData(targetFile)
  attributes = (trainData.shape)[1] - 1
  classes = len(trainData[attributes].unique())
  print("Data contains", attributes, "and", classes, "classes")

  sample = getuniformSample(trainData, SAMPLE_SIZE, classes)
  

  X, Y = splitDataForXandY(sample)
  X_test, Y_test = splitDataForXandY(testData)

  #init Population
  populationList = list()
  populationList = createGenotype(X)

  classWiseAccuracyInGeneration = dict()

  generationAccuracy = 0
  desiredAccuracy = accuracy
  generationCount = 0
  accuracyOverGenerations = list()
  testAccuracy = list()

  while (generationAccuracy < desiredAccuracy):
    if (generationCount % CHANGE_SAMPLE_AFTER == 0):
      sample = getuniformSample(trainData, SAMPLE_SIZE, classes)
      X, Y = splitDataForXandY(sample)
      
    calculateFitness(populationList, X, Y)
    gapedPopulation = getGapedPopulation(populationList)

    mostFitIndi = gapedPopulation[0]
    calculateClasswiseAccuracy(mostFitIndi, X, Y,classWiseAccuracyInGeneration)
    
    accuracyOverGenerations.append(round(gapedPopulation[0].fitnessScore, 2))
    print("Generation ", generationCount + 1, " Accuracy = ", accuracyOverGenerations[generationCount])

    newPopulation = breed(populationList, gapedPopulation)
    populationList = newPopulation
    generationAccuracy = accuracyOverGenerations[generationCount]
    generationCount += 1

    calculateFitness([gapedPopulation[0]], X_test, Y_test)
    testAccuracy.append(round(gapedPopulation[0].fitnessScore, 2))
    
    if(len(accuracyOverGenerations) > 30):
      checkList = accuracyOverGenerations[-25:]
      result = checkList.count(checkList[0]) == len(checkList)
      if (result):
        print("Same Accuracy for last 25 generations")
        break
  
  return generationCount,accuracyOverGenerations,testAccuracy

# %%
class ModelInfo():
  def __init__(self, generationCount,accuracyOverGenerations,testAccuracy ):
        self.generationCount = generationCount
        self.trainAccuracy = accuracyOverGenerations
        self.testAccuracy = testAccuracy

# %%
datasetList = ['abalone','bank','thyroid']
accuracy = [70, 90, 90]
modelInfo = {}
a = 0
for dataset in datasetList:
  modelList = []
  print("Running GA for Dataset:", dataset, "desired Accuracy:", accuracy[a])
  for i in range(10):
    generationCount,accuracyOverGenerations,testAccuracy = runGA(dataset, accuracy[a])
    modelObject = ModelInfo(generationCount,accuracyOverGenerations,testAccuracy)
    modelList.append(modelObject)

  modelInfo[dataset] = modelList
  a += 1
# Out:
# Running GA for Dataset: abalone desired Accuracy: 65
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  47.5
# Generation  2  Accuracy =  47.5
# Generation  3  Accuracy =  47.5
# Generation  4  Accuracy =  47.5
# Generation  5  Accuracy =  47.5
# Generation  6  Accuracy =  47.5
# Generation  7  Accuracy =  47.5
# Generation  8  Accuracy =  47.5
# Generation  9  Accuracy =  48.5
# Generation  10  Accuracy =  48.5
# Generation  11  Accuracy =  48.5
# Generation  12  Accuracy =  48.5
# Generation  13  Accuracy =  48.5
# Generation  14  Accuracy =  48.5
# Generation  15  Accuracy =  48.5
# CREATING SAMPLE
# Generation  16  Accuracy =  54.5
# Generation  17  Accuracy =  54.5
# Generation  18  Accuracy =  54.5
# Generation  19  Accuracy =  54.5
# Generation  20  Accuracy =  54.5
# Generation  21  Accuracy =  54.5
# Generation  22  Accuracy =  54.5
# Generation  23  Accuracy =  54.5
# Generation  24  Accuracy =  54.5
# Generation  25  Accuracy =  54.5
# Generation  26  Accuracy =  54.5
# Generation  27  Accuracy =  54.5
# Generation  28  Accuracy =  55.5
# Generation  29  Accuracy =  55.5
# Generation  30  Accuracy =  55.5
# CREATING SAMPLE
# Generation  31  Accuracy =  52.0
# Generation  32  Accuracy =  53.0
# Generation  33  Accuracy =  53.0
# Generation  34  Accuracy =  53.0
# Generation  35  Accuracy =  53.0
# Generation  36  Accuracy =  53.0
# Generation  37  Accuracy =  53.0
# Generation  38  Accuracy =  53.0
# Generation  39  Accuracy =  53.0
# Generation  40  Accuracy =  53.0
# Generation  41  Accuracy =  53.0
# Generation  42  Accuracy =  53.0
# Generation  43  Accuracy =  53.0
# Generation  44  Accuracy =  53.0
# Generation  45  Accuracy =  53.0
# CREATING SAMPLE
# Generation  46  Accuracy =  52.5
# Generation  47  Accuracy =  52.5
# Generation  48  Accuracy =  52.5
# Generation  49  Accuracy =  52.5
# Generation  50  Accuracy =  52.5
# Generation  51  Accuracy =  52.5
# Generation  52  Accuracy =  52.5
# Generation  53  Accuracy =  52.5
# Generation  54  Accuracy =  52.5
# Generation  55  Accuracy =  54.0
# Generation  56  Accuracy =  54.0
# Generation  57  Accuracy =  54.0
# Generation  58  Accuracy =  54.0
# Generation  59  Accuracy =  54.0
# Generation  60  Accuracy =  54.0
# CREATING SAMPLE
# Generation  61  Accuracy =  49.0
# Generation  62  Accuracy =  49.0
# Generation  63  Accuracy =  49.0
# Generation  64  Accuracy =  49.0
# Generation  65  Accuracy =  49.0
# Generation  66  Accuracy =  49.0
# Generation  67  Accuracy =  49.0
# Generation  68  Accuracy =  49.0
# Generation  69  Accuracy =  49.0
# Generation  70  Accuracy =  49.0
# Generation  71  Accuracy =  49.0
# Generation  72  Accuracy =  49.0
# Generation  73  Accuracy =  50.0
# Generation  74  Accuracy =  50.0
# Generation  75  Accuracy =  50.0
# CREATING SAMPLE
# Generation  76  Accuracy =  50.5
# Generation  77  Accuracy =  50.5
# Generation  78  Accuracy =  50.5
# Generation  79  Accuracy =  50.5
# Generation  80  Accuracy =  50.5
# Generation  81  Accuracy =  50.5
# Generation  82  Accuracy =  50.5
# Generation  83  Accuracy =  50.5
# Generation  84  Accuracy =  50.5
# Generation  85  Accuracy =  50.5
# Generation  86  Accuracy =  50.5
# Generation  87  Accuracy =  50.5
# Generation  88  Accuracy =  50.5
# Generation  89  Accuracy =  50.5
# Generation  90  Accuracy =  50.5
# CREATING SAMPLE
# Generation  91  Accuracy =  53.5
# Generation  92  Accuracy =  53.5
# Generation  93  Accuracy =  53.5
# Generation  94  Accuracy =  53.5
# Generation  95  Accuracy =  53.5
# Generation  96  Accuracy =  53.5
# Generation  97  Accuracy =  53.5
# Generation  98  Accuracy =  53.5
# Generation  99  Accuracy =  53.5
# Generation  100  Accuracy =  53.5
# Generation  101  Accuracy =  53.5
# Generation  102  Accuracy =  53.5
# Generation  103  Accuracy =  53.5
# Generation  104  Accuracy =  53.5
# Generation  105  Accuracy =  53.5
# CREATING SAMPLE
# Generation  106  Accuracy =  56.0
# Generation  107  Accuracy =  56.0
# Generation  108  Accuracy =  56.0
# Generation  109  Accuracy =  56.0
# Generation  110  Accuracy =  56.0
# Generation  111  Accuracy =  56.0
# Generation  112  Accuracy =  56.0
# Generation  113  Accuracy =  56.0
# Generation  114  Accuracy =  56.0
# Generation  115  Accuracy =  56.0
# Generation  116  Accuracy =  56.0
# Generation  117  Accuracy =  56.0
# Generation  118  Accuracy =  56.0
# Generation  119  Accuracy =  56.0
# Generation  120  Accuracy =  56.0
# CREATING SAMPLE
# Generation  121  Accuracy =  57.5
# Generation  122  Accuracy =  57.5
# Generation  123  Accuracy =  57.5
# Generation  124  Accuracy =  57.5
# Generation  125  Accuracy =  57.5
# Generation  126  Accuracy =  57.5
# Generation  127  Accuracy =  57.5
# Generation  128  Accuracy =  57.5
# Generation  129  Accuracy =  57.5
# Generation  130  Accuracy =  57.5
# Generation  131  Accuracy =  58.0
# Generation  132  Accuracy =  58.0
# Generation  133  Accuracy =  58.0
# Generation  134  Accuracy =  58.0
# Generation  135  Accuracy =  58.0
# CREATING SAMPLE
# Generation  136  Accuracy =  59.0
# Generation  137  Accuracy =  59.0
# Generation  138  Accuracy =  59.0
# Generation  139  Accuracy =  59.0
# Generation  140  Accuracy =  59.0
# Generation  141  Accuracy =  59.0
# Generation  142  Accuracy =  59.0
# Generation  143  Accuracy =  59.0
# Generation  144  Accuracy =  59.0
# Generation  145  Accuracy =  59.0
# Generation  146  Accuracy =  59.0
# Generation  147  Accuracy =  59.0
# Generation  148  Accuracy =  59.0
# Generation  149  Accuracy =  59.0
# Generation  150  Accuracy =  59.0
# CREATING SAMPLE
# Generation  151  Accuracy =  55.0
# Generation  152  Accuracy =  55.0
# Generation  153  Accuracy =  55.0
# Generation  154  Accuracy =  55.0
# Generation  155  Accuracy =  55.0
# Generation  156  Accuracy =  55.0
# Generation  157  Accuracy =  55.0
# Generation  158  Accuracy =  55.0
# Generation  159  Accuracy =  55.0
# Generation  160  Accuracy =  55.0
# Generation  161  Accuracy =  55.0
# Generation  162  Accuracy =  55.0
# Generation  163  Accuracy =  55.0
# Generation  164  Accuracy =  55.0
# Generation  165  Accuracy =  55.0
# CREATING SAMPLE
# Generation  166  Accuracy =  56.0
# Generation  167  Accuracy =  56.0
# Generation  168  Accuracy =  56.0
# Generation  169  Accuracy =  56.0
# Generation  170  Accuracy =  56.0
# Generation  171  Accuracy =  56.0
# Generation  172  Accuracy =  56.0
# Generation  173  Accuracy =  56.0
# Generation  174  Accuracy =  56.0
# Generation  175  Accuracy =  56.0
# Generation  176  Accuracy =  56.0
# Generation  177  Accuracy =  56.0
# Generation  178  Accuracy =  56.0
# Generation  179  Accuracy =  56.0
# Generation  180  Accuracy =  56.0
# CREATING SAMPLE
# Generation  181  Accuracy =  59.0
# Generation  182  Accuracy =  59.0
# Generation  183  Accuracy =  59.0
# Generation  184  Accuracy =  59.0
# Generation  185  Accuracy =  59.0
# Generation  186  Accuracy =  59.0
# Generation  187  Accuracy =  59.0
# Generation  188  Accuracy =  59.0
# Generation  189  Accuracy =  59.0
# Generation  190  Accuracy =  59.0
# Generation  191  Accuracy =  59.0
# Generation  192  Accuracy =  59.0
# Generation  193  Accuracy =  59.0
# Generation  194  Accuracy =  59.0
# Generation  195  Accuracy =  59.0
# CREATING SAMPLE
# Generation  196  Accuracy =  57.0
# Generation  197  Accuracy =  57.0
# Generation  198  Accuracy =  57.0
# Generation  199  Accuracy =  57.0
# Generation  200  Accuracy =  57.0
# Generation  201  Accuracy =  57.0
# Generation  202  Accuracy =  57.0
# Generation  203  Accuracy =  57.0
# Generation  204  Accuracy =  57.0
# Generation  205  Accuracy =  57.0
# Generation  206  Accuracy =  57.0
# Generation  207  Accuracy =  57.0
# Generation  208  Accuracy =  57.0
# Generation  209  Accuracy =  57.0
# Generation  210  Accuracy =  57.0
# CREATING SAMPLE
# Generation  211  Accuracy =  62.5
# Generation  212  Accuracy =  62.5
# Generation  213  Accuracy =  62.5
# Generation  214  Accuracy =  62.5
# Generation  215  Accuracy =  62.5
# Generation  216  Accuracy =  62.5
# Generation  217  Accuracy =  62.5
# Generation  218  Accuracy =  62.5
# Generation  219  Accuracy =  62.5
# Generation  220  Accuracy =  62.5
# Generation  221  Accuracy =  62.5
# Generation  222  Accuracy =  62.5
# Generation  223  Accuracy =  62.5
# Generation  224  Accuracy =  62.5
# Generation  225  Accuracy =  62.5
# CREATING SAMPLE
# Generation  226  Accuracy =  57.0
# Generation  227  Accuracy =  57.0
# Generation  228  Accuracy =  57.0
# Generation  229  Accuracy =  57.0
# Generation  230  Accuracy =  57.0
# Generation  231  Accuracy =  57.0
# Generation  232  Accuracy =  57.0
# Generation  233  Accuracy =  57.0
# Generation  234  Accuracy =  57.0
# Generation  235  Accuracy =  57.0
# Generation  236  Accuracy =  57.0
# Generation  237  Accuracy =  57.0
# Generation  238  Accuracy =  57.0
# Generation  239  Accuracy =  57.0
# Generation  240  Accuracy =  57.0
# CREATING SAMPLE
# Generation  241  Accuracy =  59.0
# Generation  242  Accuracy =  59.0
# Generation  243  Accuracy =  59.0
# Generation  244  Accuracy =  59.0
# Generation  245  Accuracy =  59.0
# Generation  246  Accuracy =  59.0
# Generation  247  Accuracy =  60.5
# Generation  248  Accuracy =  60.5
# Generation  249  Accuracy =  60.5
# Generation  250  Accuracy =  60.5
# Generation  251  Accuracy =  60.5
# Generation  252  Accuracy =  60.5
# Generation  253  Accuracy =  60.5
# Generation  254  Accuracy =  60.5
# Generation  255  Accuracy =  60.5
# CREATING SAMPLE
# Generation  256  Accuracy =  60.5
# Generation  257  Accuracy =  60.5
# Generation  258  Accuracy =  60.5
# Generation  259  Accuracy =  60.5
# Generation  260  Accuracy =  60.5
# Generation  261  Accuracy =  60.5
# Generation  262  Accuracy =  60.5
# Generation  263  Accuracy =  60.5
# Generation  264  Accuracy =  60.5
# Generation  265  Accuracy =  60.5
# Generation  266  Accuracy =  60.5
# Generation  267  Accuracy =  60.5
# Generation  268  Accuracy =  60.5
# Generation  269  Accuracy =  60.5
# Generation  270  Accuracy =  60.5
# CREATING SAMPLE
# Generation  271  Accuracy =  61.0
# Generation  272  Accuracy =  61.0
# Generation  273  Accuracy =  61.0
# Generation  274  Accuracy =  61.0
# Generation  275  Accuracy =  61.0
# Generation  276  Accuracy =  61.0
# Generation  277  Accuracy =  61.0
# Generation  278  Accuracy =  61.0
# Generation  279  Accuracy =  61.0
# Generation  280  Accuracy =  61.0
# Generation  281  Accuracy =  61.0
# Generation  282  Accuracy =  61.0
# Generation  283  Accuracy =  61.0
# Generation  284  Accuracy =  61.0
# Generation  285  Accuracy =  61.0
# CREATING SAMPLE
# Generation  286  Accuracy =  61.5
# Generation  287  Accuracy =  61.5
# Generation  288  Accuracy =  61.5
# Generation  289  Accuracy =  61.5
# Generation  290  Accuracy =  61.5
# Generation  291  Accuracy =  61.5
# Generation  292  Accuracy =  61.5
# Generation  293  Accuracy =  61.5
# Generation  294  Accuracy =  61.5
# Generation  295  Accuracy =  61.5
# Generation  296  Accuracy =  61.5
# Generation  297  Accuracy =  61.5
# Generation  298  Accuracy =  61.5
# Generation  299  Accuracy =  61.5
# Generation  300  Accuracy =  61.5
# CREATING SAMPLE
# Generation  301  Accuracy =  64.0
# Generation  302  Accuracy =  64.0
# Generation  303  Accuracy =  64.0
# Generation  304  Accuracy =  64.0
# Generation  305  Accuracy =  64.0
# Generation  306  Accuracy =  64.0
# Generation  307  Accuracy =  64.0
# Generation  308  Accuracy =  64.0
# Generation  309  Accuracy =  64.0
# Generation  310  Accuracy =  64.0
# Generation  311  Accuracy =  64.0
# Generation  312  Accuracy =  64.0
# Generation  313  Accuracy =  64.0
# Generation  314  Accuracy =  64.0
# Generation  315  Accuracy =  64.0
# CREATING SAMPLE
# Generation  316  Accuracy =  61.5
# Generation  317  Accuracy =  64.0
# Generation  318  Accuracy =  64.0
# Generation  319  Accuracy =  64.0
# Generation  320  Accuracy =  64.0
# Generation  321  Accuracy =  64.0
# Generation  322  Accuracy =  64.0
# Generation  323  Accuracy =  64.0
# Generation  324  Accuracy =  64.0
# Generation  325  Accuracy =  64.0
# Generation  326  Accuracy =  64.0
# Generation  327  Accuracy =  64.0
# Generation  328  Accuracy =  64.0
# Generation  329  Accuracy =  64.0
# Generation  330  Accuracy =  64.0
# CREATING SAMPLE
# Generation  331  Accuracy =  63.5
# Generation  332  Accuracy =  63.5
# Generation  333  Accuracy =  63.5
# Generation  334  Accuracy =  63.5
# Generation  335  Accuracy =  63.5
# Generation  336  Accuracy =  63.5
# Generation  337  Accuracy =  63.5
# Generation  338  Accuracy =  63.5
# Generation  339  Accuracy =  63.5
# Generation  340  Accuracy =  63.5
# Generation  341  Accuracy =  63.5
# Generation  342  Accuracy =  63.5
# Generation  343  Accuracy =  63.5
# Generation  344  Accuracy =  63.5
# Generation  345  Accuracy =  63.5
# CREATING SAMPLE
# Generation  346  Accuracy =  64.5
# Generation  347  Accuracy =  64.5
# Generation  348  Accuracy =  64.5
# Generation  349  Accuracy =  64.5
# Generation  350  Accuracy =  64.5
# Generation  351  Accuracy =  64.5
# Generation  352  Accuracy =  64.5
# Generation  353  Accuracy =  64.5
# Generation  354  Accuracy =  64.5
# Generation  355  Accuracy =  64.5
# Generation  356  Accuracy =  64.5
# Generation  357  Accuracy =  64.5
# Generation  358  Accuracy =  64.5
# Generation  359  Accuracy =  64.5
# Generation  360  Accuracy =  64.5
# CREATING SAMPLE
# Generation  361  Accuracy =  58.0
# Generation  362  Accuracy =  58.0
# Generation  363  Accuracy =  58.0
# Generation  364  Accuracy =  58.0
# Generation  365  Accuracy =  58.0
# Generation  366  Accuracy =  58.0
# Generation  367  Accuracy =  58.0
# Generation  368  Accuracy =  58.0
# Generation  369  Accuracy =  58.0
# Generation  370  Accuracy =  58.0
# Generation  371  Accuracy =  58.0
# Generation  372  Accuracy =  58.0
# Generation  373  Accuracy =  58.0
# Generation  374  Accuracy =  58.0
# Generation  375  Accuracy =  58.0
# CREATING SAMPLE
# Generation  376  Accuracy =  60.0
# Generation  377  Accuracy =  60.0
# Generation  378  Accuracy =  60.0
# Generation  379  Accuracy =  60.0
# Generation  380  Accuracy =  60.0
# Generation  381  Accuracy =  60.0
# Generation  382  Accuracy =  60.0
# Generation  383  Accuracy =  60.0
# Generation  384  Accuracy =  61.5
# Generation  385  Accuracy =  61.5
# Generation  386  Accuracy =  61.5
# Generation  387  Accuracy =  61.5
# Generation  388  Accuracy =  61.5
# Generation  389  Accuracy =  61.5
# Generation  390  Accuracy =  61.5
# CREATING SAMPLE
# Generation  391  Accuracy =  57.0
# Generation  392  Accuracy =  57.0
# Generation  393  Accuracy =  57.0
# Generation  394  Accuracy =  57.0
# Generation  395  Accuracy =  57.0
# Generation  396  Accuracy =  57.0
# Generation  397  Accuracy =  57.0
# Generation  398  Accuracy =  57.0
# Generation  399  Accuracy =  57.0
# Generation  400  Accuracy =  57.0
# Generation  401  Accuracy =  57.0
# Generation  402  Accuracy =  57.0
# Generation  403  Accuracy =  57.0
# Generation  404  Accuracy =  57.0
# Generation  405  Accuracy =  57.0
# CREATING SAMPLE
# Generation  406  Accuracy =  59.0
# Generation  407  Accuracy =  59.0
# Generation  408  Accuracy =  59.0
# Generation  409  Accuracy =  59.0
# Generation  410  Accuracy =  59.0
# Generation  411  Accuracy =  59.0
# Generation  412  Accuracy =  59.0
# Generation  413  Accuracy =  59.0
# Generation  414  Accuracy =  59.0
# Generation  415  Accuracy =  60.0
# Generation  416  Accuracy =  60.0
# Generation  417  Accuracy =  60.0
# Generation  418  Accuracy =  60.0
# Generation  419  Accuracy =  60.0
# Generation  420  Accuracy =  60.0
# CREATING SAMPLE
# Generation  421  Accuracy =  64.5
# Generation  422  Accuracy =  64.5
# Generation  423  Accuracy =  64.5
# Generation  424  Accuracy =  64.5
# Generation  425  Accuracy =  64.5
# Generation  426  Accuracy =  64.5
# Generation  427  Accuracy =  66.0
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  45.5
# Generation  2  Accuracy =  45.5
# Generation  3  Accuracy =  45.5
# Generation  4  Accuracy =  45.5
# Generation  5  Accuracy =  45.5
# Generation  6  Accuracy =  46.5
# Generation  7  Accuracy =  46.5
# Generation  8  Accuracy =  46.5
# Generation  9  Accuracy =  46.5
# Generation  10  Accuracy =  46.5
# Generation  11  Accuracy =  46.5
# Generation  12  Accuracy =  46.5
# Generation  13  Accuracy =  46.5
# Generation  14  Accuracy =  46.5
# Generation  15  Accuracy =  46.5
# CREATING SAMPLE
# Generation  16  Accuracy =  46.0
# Generation  17  Accuracy =  46.0
# Generation  18  Accuracy =  46.0
# Generation  19  Accuracy =  46.0
# Generation  20  Accuracy =  46.0
# Generation  21  Accuracy =  46.0
# Generation  22  Accuracy =  46.0
# Generation  23  Accuracy =  46.0
# Generation  24  Accuracy =  46.0
# Generation  25  Accuracy =  46.0
# Generation  26  Accuracy =  46.0
# Generation  27  Accuracy =  46.0
# Generation  28  Accuracy =  46.0
# Generation  29  Accuracy =  46.0
# Generation  30  Accuracy =  46.0
# CREATING SAMPLE
# Generation  31  Accuracy =  49.5
# Generation  32  Accuracy =  49.5
# Generation  33  Accuracy =  49.5
# Generation  34  Accuracy =  49.5
# Generation  35  Accuracy =  49.5
# Generation  36  Accuracy =  49.5
# Generation  37  Accuracy =  49.5
# Generation  38  Accuracy =  49.5
# Generation  39  Accuracy =  49.5
# Generation  40  Accuracy =  49.5
# Generation  41  Accuracy =  49.5
# Generation  42  Accuracy =  49.5
# Generation  43  Accuracy =  49.5
# Generation  44  Accuracy =  49.5
# Generation  45  Accuracy =  49.5
# CREATING SAMPLE
# Generation  46  Accuracy =  52.5
# Generation  47  Accuracy =  52.5
# Generation  48  Accuracy =  52.5
# Generation  49  Accuracy =  52.5
# Generation  50  Accuracy =  52.5
# Generation  51  Accuracy =  52.5
# Generation  52  Accuracy =  52.5
# Generation  53  Accuracy =  52.5
# Generation  54  Accuracy =  52.5
# Generation  55  Accuracy =  52.5
# Generation  56  Accuracy =  52.5
# Generation  57  Accuracy =  52.5
# Generation  58  Accuracy =  52.5
# Generation  59  Accuracy =  52.5
# Generation  60  Accuracy =  52.5
# CREATING SAMPLE
# Generation  61  Accuracy =  48.0
# Generation  62  Accuracy =  48.5
# Generation  63  Accuracy =  48.5
# Generation  64  Accuracy =  48.5
# Generation  65  Accuracy =  49.0
# Generation  66  Accuracy =  49.0
# Generation  67  Accuracy =  49.0
# Generation  68  Accuracy =  49.0
# Generation  69  Accuracy =  49.0
# Generation  70  Accuracy =  51.5
# Generation  71  Accuracy =  51.5
# Generation  72  Accuracy =  51.5
# Generation  73  Accuracy =  51.5
# Generation  74  Accuracy =  51.5
# Generation  75  Accuracy =  51.5
# CREATING SAMPLE
# Generation  76  Accuracy =  53.0
# Generation  77  Accuracy =  53.0
# Generation  78  Accuracy =  53.0
# Generation  79  Accuracy =  53.0
# Generation  80  Accuracy =  53.0
# Generation  81  Accuracy =  53.0
# Generation  82  Accuracy =  53.0
# Generation  83  Accuracy =  53.0
# Generation  84  Accuracy =  53.0
# Generation  85  Accuracy =  53.0
# Generation  86  Accuracy =  53.0
# Generation  87  Accuracy =  53.0
# Generation  88  Accuracy =  53.0
# Generation  89  Accuracy =  53.0
# Generation  90  Accuracy =  53.0
# CREATING SAMPLE
# Generation  91  Accuracy =  52.5
# Generation  92  Accuracy =  52.5
# Generation  93  Accuracy =  52.5
# Generation  94  Accuracy =  52.5
# Generation  95  Accuracy =  52.5
# Generation  96  Accuracy =  52.5
# Generation  97  Accuracy =  52.5
# Generation  98  Accuracy =  52.5
# Generation  99  Accuracy =  52.5
# Generation  100  Accuracy =  52.5
# Generation  101  Accuracy =  52.5
# Generation  102  Accuracy =  52.5
# Generation  103  Accuracy =  52.5
# Generation  104  Accuracy =  52.5
# Generation  105  Accuracy =  52.5
# CREATING SAMPLE
# Generation  106  Accuracy =  55.0
# Generation  107  Accuracy =  55.0
# Generation  108  Accuracy =  55.0
# Generation  109  Accuracy =  55.0
# Generation  110  Accuracy =  55.0
# Generation  111  Accuracy =  55.0
# Generation  112  Accuracy =  55.0
# Generation  113  Accuracy =  58.5
# Generation  114  Accuracy =  58.5
# Generation  115  Accuracy =  58.5
# Generation  116  Accuracy =  58.5
# Generation  117  Accuracy =  58.5
# Generation  118  Accuracy =  58.5
# Generation  119  Accuracy =  58.5
# Generation  120  Accuracy =  58.5
# CREATING SAMPLE
# Generation  121  Accuracy =  56.0
# Generation  122  Accuracy =  56.0
# Generation  123  Accuracy =  56.0
# Generation  124  Accuracy =  56.0
# Generation  125  Accuracy =  56.0
# Generation  126  Accuracy =  56.5
# Generation  127  Accuracy =  56.5
# Generation  128  Accuracy =  56.5
# Generation  129  Accuracy =  56.5
# Generation  130  Accuracy =  56.5
# Generation  131  Accuracy =  56.5
# Generation  132  Accuracy =  56.5
# Generation  133  Accuracy =  56.5
# Generation  134  Accuracy =  56.5
# Generation  135  Accuracy =  56.5
# CREATING SAMPLE
# Generation  136  Accuracy =  55.0
# Generation  137  Accuracy =  55.0
# Generation  138  Accuracy =  55.0
# Generation  139  Accuracy =  55.0
# Generation  140  Accuracy =  55.0
# Generation  141  Accuracy =  55.0
# Generation  142  Accuracy =  55.0
# Generation  143  Accuracy =  55.0
# Generation  144  Accuracy =  56.0
# Generation  145  Accuracy =  56.0
# Generation  146  Accuracy =  56.0
# Generation  147  Accuracy =  56.0
# Generation  148  Accuracy =  59.0
# Generation  149  Accuracy =  59.0
# Generation  150  Accuracy =  59.0
# CREATING SAMPLE
# Generation  151  Accuracy =  57.5
# Generation  152  Accuracy =  57.5
# Generation  153  Accuracy =  57.5
# Generation  154  Accuracy =  57.5
# Generation  155  Accuracy =  57.5
# Generation  156  Accuracy =  57.5
# Generation  157  Accuracy =  57.5
# Generation  158  Accuracy =  57.5
# Generation  159  Accuracy =  57.5
# Generation  160  Accuracy =  57.5
# Generation  161  Accuracy =  57.5
# Generation  162  Accuracy =  57.5
# Generation  163  Accuracy =  57.5
# Generation  164  Accuracy =  57.5
# Generation  165  Accuracy =  57.5
# CREATING SAMPLE
# Generation  166  Accuracy =  54.0
# Generation  167  Accuracy =  54.0
# Generation  168  Accuracy =  54.0
# Generation  169  Accuracy =  54.0
# Generation  170  Accuracy =  54.0
# Generation  171  Accuracy =  54.0
# Generation  172  Accuracy =  54.0
# Generation  173  Accuracy =  54.0
# Generation  174  Accuracy =  54.0
# Generation  175  Accuracy =  54.0
# Generation  176  Accuracy =  54.0
# Generation  177  Accuracy =  54.0
# Generation  178  Accuracy =  54.0
# Generation  179  Accuracy =  54.0
# Generation  180  Accuracy =  54.0
# CREATING SAMPLE
# Generation  181  Accuracy =  57.5
# Generation  182  Accuracy =  57.5
# Generation  183  Accuracy =  57.5
# Generation  184  Accuracy =  57.5
# Generation  185  Accuracy =  57.5
# Generation  186  Accuracy =  57.5
# Generation  187  Accuracy =  57.5
# Generation  188  Accuracy =  57.5
# Generation  189  Accuracy =  61.0
# Generation  190  Accuracy =  61.0
# Generation  191  Accuracy =  62.5
# Generation  192  Accuracy =  62.5
# Generation  193  Accuracy =  62.5
# Generation  194  Accuracy =  62.5
# Generation  195  Accuracy =  62.5
# CREATING SAMPLE
# Generation  196  Accuracy =  61.5
# Generation  197  Accuracy =  61.5
# Generation  198  Accuracy =  61.5
# Generation  199  Accuracy =  61.5
# Generation  200  Accuracy =  61.5
# Generation  201  Accuracy =  61.5
# Generation  202  Accuracy =  61.5
# Generation  203  Accuracy =  61.5
# Generation  204  Accuracy =  61.5
# Generation  205  Accuracy =  61.5
# Generation  206  Accuracy =  61.5
# Generation  207  Accuracy =  61.5
# Generation  208  Accuracy =  61.5
# Generation  209  Accuracy =  61.5
# Generation  210  Accuracy =  61.5
# CREATING SAMPLE
# Generation  211  Accuracy =  61.0
# Generation  212  Accuracy =  61.0
# Generation  213  Accuracy =  61.0
# Generation  214  Accuracy =  64.5
# Generation  215  Accuracy =  64.5
# Generation  216  Accuracy =  64.5
# Generation  217  Accuracy =  64.5
# Generation  218  Accuracy =  64.5
# Generation  219  Accuracy =  64.5
# Generation  220  Accuracy =  64.5
# Generation  221  Accuracy =  64.5
# Generation  222  Accuracy =  64.5
# Generation  223  Accuracy =  64.5
# Generation  224  Accuracy =  64.5
# Generation  225  Accuracy =  64.5
# CREATING SAMPLE
# Generation  226  Accuracy =  59.5
# Generation  227  Accuracy =  59.5
# Generation  228  Accuracy =  59.5
# Generation  229  Accuracy =  59.5
# Generation  230  Accuracy =  59.5
# Generation  231  Accuracy =  59.5
# Generation  232  Accuracy =  60.5
# Generation  233  Accuracy =  60.5
# Generation  234  Accuracy =  60.5
# Generation  235  Accuracy =  60.5
# Generation  236  Accuracy =  60.5
# Generation  237  Accuracy =  60.5
# Generation  238  Accuracy =  60.5
# Generation  239  Accuracy =  60.5
# Generation  240  Accuracy =  60.5
# CREATING SAMPLE
# Generation  241  Accuracy =  59.0
# Generation  242  Accuracy =  59.0
# Generation  243  Accuracy =  59.0
# Generation  244  Accuracy =  59.0
# Generation  245  Accuracy =  59.0
# Generation  246  Accuracy =  59.0
# Generation  247  Accuracy =  59.0
# Generation  248  Accuracy =  59.0
# Generation  249  Accuracy =  59.0
# Generation  250  Accuracy =  59.0
# Generation  251  Accuracy =  59.0
# Generation  252  Accuracy =  59.0
# Generation  253  Accuracy =  59.0
# Generation  254  Accuracy =  59.0
# Generation  255  Accuracy =  59.0
# CREATING SAMPLE
# Generation  256  Accuracy =  59.0
# Generation  257  Accuracy =  59.0
# Generation  258  Accuracy =  59.0
# Generation  259  Accuracy =  59.0
# Generation  260  Accuracy =  59.0
# Generation  261  Accuracy =  59.0
# Generation  262  Accuracy =  59.0
# Generation  263  Accuracy =  59.0
# Generation  264  Accuracy =  59.0
# Generation  265  Accuracy =  59.0
# Same Accuracy for last 25 generations
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  48.5
# Generation  2  Accuracy =  48.5
# Generation  3  Accuracy =  48.5
# Generation  4  Accuracy =  48.5
# Generation  5  Accuracy =  48.5
# Generation  6  Accuracy =  48.5
# Generation  7  Accuracy =  48.5
# Generation  8  Accuracy =  53.0
# Generation  9  Accuracy =  53.0
# Generation  10  Accuracy =  53.0
# Generation  11  Accuracy =  53.0
# Generation  12  Accuracy =  53.0
# Generation  13  Accuracy =  53.0
# Generation  14  Accuracy =  53.0
# Generation  15  Accuracy =  53.0
# CREATING SAMPLE
# Generation  16  Accuracy =  48.5
# Generation  17  Accuracy =  48.5
# Generation  18  Accuracy =  48.5
# Generation  19  Accuracy =  48.5
# Generation  20  Accuracy =  48.5
# Generation  21  Accuracy =  48.5
# Generation  22  Accuracy =  48.5
# Generation  23  Accuracy =  48.5
# Generation  24  Accuracy =  48.5
# Generation  25  Accuracy =  48.5
# Generation  26  Accuracy =  48.5
# Generation  27  Accuracy =  48.5
# Generation  28  Accuracy =  48.5
# Generation  29  Accuracy =  50.0
# Generation  30  Accuracy =  50.0
# CREATING SAMPLE
# Generation  31  Accuracy =  46.0
# Generation  32  Accuracy =  46.0
# Generation  33  Accuracy =  46.0
# Generation  34  Accuracy =  46.0
# Generation  35  Accuracy =  46.0
# Generation  36  Accuracy =  46.0
# Generation  37  Accuracy =  46.0
# Generation  38  Accuracy =  46.0
# Generation  39  Accuracy =  46.0
# Generation  40  Accuracy =  46.0
# Generation  41  Accuracy =  46.0
# Generation  42  Accuracy =  46.0
# Generation  43  Accuracy =  46.0
# Generation  44  Accuracy =  46.0
# Generation  45  Accuracy =  46.0
# CREATING SAMPLE
# Generation  46  Accuracy =  52.0
# Generation  47  Accuracy =  52.0
# Generation  48  Accuracy =  52.0
# Generation  49  Accuracy =  52.0
# Generation  50  Accuracy =  52.0
# Generation  51  Accuracy =  52.0
# Generation  52  Accuracy =  52.0
# Generation  53  Accuracy =  52.0
# Generation  54  Accuracy =  52.0
# Generation  55  Accuracy =  52.0
# Generation  56  Accuracy =  52.0
# Generation  57  Accuracy =  52.0
# Generation  58  Accuracy =  52.0
# Generation  59  Accuracy =  52.0
# Generation  60  Accuracy =  52.0
# CREATING SAMPLE
# Generation  61  Accuracy =  46.5
# Generation  62  Accuracy =  46.5
# Generation  63  Accuracy =  46.5
# Generation  64  Accuracy =  46.5
# Generation  65  Accuracy =  46.5
# Generation  66  Accuracy =  46.5
# Generation  67  Accuracy =  46.5
# Generation  68  Accuracy =  46.5
# Generation  69  Accuracy =  46.5
# Generation  70  Accuracy =  46.5
# Generation  71  Accuracy =  46.5
# Generation  72  Accuracy =  46.5
# Generation  73  Accuracy =  46.5
# Generation  74  Accuracy =  46.5
# Generation  75  Accuracy =  46.5
# CREATING SAMPLE
# Generation  76  Accuracy =  50.5
# Generation  77  Accuracy =  50.5
# Generation  78  Accuracy =  50.5
# Generation  79  Accuracy =  50.5
# Generation  80  Accuracy =  50.5
# Generation  81  Accuracy =  50.5
# Generation  82  Accuracy =  50.5
# Generation  83  Accuracy =  50.5
# Generation  84  Accuracy =  50.5
# Generation  85  Accuracy =  50.5
# Generation  86  Accuracy =  50.5
# Generation  87  Accuracy =  50.5
# Generation  88  Accuracy =  50.5
# Generation  89  Accuracy =  50.5
# Generation  90  Accuracy =  50.5
# CREATING SAMPLE
# Generation  91  Accuracy =  51.5
# Generation  92  Accuracy =  51.5
# Generation  93  Accuracy =  51.5
# Generation  94  Accuracy =  51.5
# Generation  95  Accuracy =  51.5
# Generation  96  Accuracy =  51.5
# Generation  97  Accuracy =  51.5
# Generation  98  Accuracy =  51.5
# Generation  99  Accuracy =  51.5
# Generation  100  Accuracy =  51.5
# Generation  101  Accuracy =  51.5
# Generation  102  Accuracy =  51.5
# Generation  103  Accuracy =  51.5
# Generation  104  Accuracy =  51.5
# Generation  105  Accuracy =  51.5
# CREATING SAMPLE
# Generation  106  Accuracy =  46.5
# Generation  107  Accuracy =  46.5
# Generation  108  Accuracy =  46.5
# Generation  109  Accuracy =  46.5
# Generation  110  Accuracy =  46.5
# Generation  111  Accuracy =  46.5
# Generation  112  Accuracy =  46.5
# Generation  113  Accuracy =  46.5
# Generation  114  Accuracy =  47.0
# Generation  115  Accuracy =  48.0
# Generation  116  Accuracy =  48.0
# Generation  117  Accuracy =  48.0
# Generation  118  Accuracy =  48.0
# Generation  119  Accuracy =  48.0
# Generation  120  Accuracy =  48.0
# CREATING SAMPLE
# Generation  121  Accuracy =  54.5
# Generation  122  Accuracy =  54.5
# Generation  123  Accuracy =  54.5
# Generation  124  Accuracy =  54.5
# Generation  125  Accuracy =  54.5
# Generation  126  Accuracy =  54.5
# Generation  127  Accuracy =  54.5
# Generation  128  Accuracy =  54.5
# Generation  129  Accuracy =  54.5
# Generation  130  Accuracy =  54.5
# Generation  131  Accuracy =  54.5
# Generation  132  Accuracy =  54.5
# Generation  133  Accuracy =  54.5
# Generation  134  Accuracy =  54.5
# Generation  135  Accuracy =  54.5
# CREATING SAMPLE
# Generation  136  Accuracy =  53.0
# Generation  137  Accuracy =  53.0
# Generation  138  Accuracy =  53.0
# Generation  139  Accuracy =  53.0
# Generation  140  Accuracy =  53.0
# Generation  141  Accuracy =  53.0
# Generation  142  Accuracy =  53.0
# Generation  143  Accuracy =  53.0
# Generation  144  Accuracy =  53.0
# Generation  145  Accuracy =  53.0
# Generation  146  Accuracy =  53.0
# Generation  147  Accuracy =  53.0
# Generation  148  Accuracy =  53.0
# Generation  149  Accuracy =  53.0
# Generation  150  Accuracy =  53.0
# CREATING SAMPLE
# Generation  151  Accuracy =  53.5
# Generation  152  Accuracy =  53.5
# Generation  153  Accuracy =  53.5
# Generation  154  Accuracy =  53.5
# Generation  155  Accuracy =  53.5
# Generation  156  Accuracy =  53.5
# Generation  157  Accuracy =  53.5
# Generation  158  Accuracy =  53.5
# Generation  159  Accuracy =  53.5
# Generation  160  Accuracy =  53.5
# Generation  161  Accuracy =  53.5
# Generation  162  Accuracy =  53.5
# Generation  163  Accuracy =  53.5
# Generation  164  Accuracy =  53.5
# Generation  165  Accuracy =  53.5
# CREATING SAMPLE
# Generation  166  Accuracy =  53.0
# Generation  167  Accuracy =  53.0
# Generation  168  Accuracy =  53.0
# Generation  169  Accuracy =  53.0
# Generation  170  Accuracy =  53.0
# Generation  171  Accuracy =  53.0
# Generation  172  Accuracy =  53.0
# Generation  173  Accuracy =  53.0
# Generation  174  Accuracy =  53.0
# Generation  175  Accuracy =  53.0
# Generation  176  Accuracy =  53.0
# Generation  177  Accuracy =  53.0
# Generation  178  Accuracy =  53.0
# Generation  179  Accuracy =  53.0
# Generation  180  Accuracy =  53.0
# CREATING SAMPLE
# Generation  181  Accuracy =  49.5
# Generation  182  Accuracy =  49.5
# Generation  183  Accuracy =  49.5
# Generation  184  Accuracy =  49.5
# Generation  185  Accuracy =  49.5
# Generation  186  Accuracy =  49.5
# Generation  187  Accuracy =  49.5
# Generation  188  Accuracy =  49.5
# Generation  189  Accuracy =  49.5
# Generation  190  Accuracy =  49.5
# Generation  191  Accuracy =  49.5
# Generation  192  Accuracy =  49.5
# Generation  193  Accuracy =  49.5
# Generation  194  Accuracy =  49.5
# Generation  195  Accuracy =  49.5
# CREATING SAMPLE
# Generation  196  Accuracy =  54.5
# Generation  197  Accuracy =  54.5
# Generation  198  Accuracy =  54.5
# Generation  199  Accuracy =  54.5
# Generation  200  Accuracy =  54.5
# Generation  201  Accuracy =  54.5
# Generation  202  Accuracy =  54.5
# Generation  203  Accuracy =  54.5
# Generation  204  Accuracy =  54.5
# Generation  205  Accuracy =  54.5
# Generation  206  Accuracy =  54.5
# Generation  207  Accuracy =  54.5
# Generation  208  Accuracy =  54.5
# Generation  209  Accuracy =  54.5
# Generation  210  Accuracy =  54.5
# CREATING SAMPLE
# Generation  211  Accuracy =  51.5
# Generation  212  Accuracy =  51.5
# Generation  213  Accuracy =  51.5
# Generation  214  Accuracy =  51.5
# Generation  215  Accuracy =  51.5
# Generation  216  Accuracy =  51.5
# Generation  217  Accuracy =  51.5
# Generation  218  Accuracy =  51.5
# Generation  219  Accuracy =  51.5
# Generation  220  Accuracy =  51.5
# Generation  221  Accuracy =  51.5
# Generation  222  Accuracy =  51.5
# Generation  223  Accuracy =  51.5
# Generation  224  Accuracy =  51.5
# Generation  225  Accuracy =  51.5
# CREATING SAMPLE
# Generation  226  Accuracy =  57.0
# Generation  227  Accuracy =  57.0
# Generation  228  Accuracy =  57.0
# Generation  229  Accuracy =  57.0
# Generation  230  Accuracy =  57.0
# Generation  231  Accuracy =  57.0
# Generation  232  Accuracy =  57.0
# Generation  233  Accuracy =  57.0
# Generation  234  Accuracy =  57.0
# Generation  235  Accuracy =  57.0
# Generation  236  Accuracy =  57.0
# Generation  237  Accuracy =  57.0
# Generation  238  Accuracy =  57.0
# Generation  239  Accuracy =  57.0
# Generation  240  Accuracy =  57.0
# CREATING SAMPLE
# Generation  241  Accuracy =  51.5
# Generation  242  Accuracy =  51.5
# Generation  243  Accuracy =  51.5
# Generation  244  Accuracy =  51.5
# Generation  245  Accuracy =  51.5
# Generation  246  Accuracy =  51.5
# Generation  247  Accuracy =  51.5
# Generation  248  Accuracy =  51.5
# Generation  249  Accuracy =  51.5
# Generation  250  Accuracy =  51.5
# Generation  251  Accuracy =  51.5
# Generation  252  Accuracy =  51.5
# Generation  253  Accuracy =  51.5
# Generation  254  Accuracy =  51.5
# Generation  255  Accuracy =  51.5
# CREATING SAMPLE
# Generation  256  Accuracy =  53.0
# Generation  257  Accuracy =  53.0
# Generation  258  Accuracy =  53.0
# Generation  259  Accuracy =  53.0
# Generation  260  Accuracy =  53.0
# Generation  261  Accuracy =  53.0
# Generation  262  Accuracy =  53.0
# Generation  263  Accuracy =  53.0
# Generation  264  Accuracy =  53.0
# Generation  265  Accuracy =  53.0
# Generation  266  Accuracy =  53.0
# Generation  267  Accuracy =  53.0
# Generation  268  Accuracy =  53.0
# Generation  269  Accuracy =  53.0
# Generation  270  Accuracy =  53.0
# CREATING SAMPLE
# Generation  271  Accuracy =  52.5
# Generation  272  Accuracy =  52.5
# Generation  273  Accuracy =  52.5
# Generation  274  Accuracy =  52.5
# Generation  275  Accuracy =  52.5
# Generation  276  Accuracy =  52.5
# Generation  277  Accuracy =  52.5
# Generation  278  Accuracy =  52.5
# Generation  279  Accuracy =  52.5
# Generation  280  Accuracy =  52.5
# Generation  281  Accuracy =  52.5
# Generation  282  Accuracy =  52.5
# Generation  283  Accuracy =  52.5
# Generation  284  Accuracy =  52.5
# Generation  285  Accuracy =  53.5
# CREATING SAMPLE
# Generation  286  Accuracy =  57.0
# Generation  287  Accuracy =  57.0
# Generation  288  Accuracy =  57.0
# Generation  289  Accuracy =  57.0
# Generation  290  Accuracy =  57.0
# Generation  291  Accuracy =  57.0
# Generation  292  Accuracy =  57.0
# Generation  293  Accuracy =  57.0
# Generation  294  Accuracy =  57.0
# Generation  295  Accuracy =  57.0
# Generation  296  Accuracy =  57.0
# Generation  297  Accuracy =  57.0
# Generation  298  Accuracy =  58.0
# Generation  299  Accuracy =  58.0
# Generation  300  Accuracy =  58.0
# CREATING SAMPLE
# Generation  301  Accuracy =  58.5
# Generation  302  Accuracy =  58.5
# Generation  303  Accuracy =  58.5
# Generation  304  Accuracy =  58.5
# Generation  305  Accuracy =  58.5
# Generation  306  Accuracy =  58.5
# Generation  307  Accuracy =  58.5
# Generation  308  Accuracy =  58.5
# Generation  309  Accuracy =  58.5
# Generation  310  Accuracy =  58.5
# Generation  311  Accuracy =  58.5
# Generation  312  Accuracy =  58.5
# Generation  313  Accuracy =  58.5
# Generation  314  Accuracy =  58.5
# Generation  315  Accuracy =  59.0
# CREATING SAMPLE
# Generation  316  Accuracy =  56.0
# Generation  317  Accuracy =  56.0
# Generation  318  Accuracy =  56.0
# Generation  319  Accuracy =  57.5
# Generation  320  Accuracy =  57.5
# Generation  321  Accuracy =  57.5
# Generation  322  Accuracy =  57.5
# Generation  323  Accuracy =  57.5
# Generation  324  Accuracy =  57.5
# Generation  325  Accuracy =  57.5
# Generation  326  Accuracy =  57.5
# Generation  327  Accuracy =  57.5
# Generation  328  Accuracy =  57.5
# Generation  329  Accuracy =  57.5
# Generation  330  Accuracy =  57.5
# CREATING SAMPLE
# Generation  331  Accuracy =  54.5
# Generation  332  Accuracy =  54.5
# Generation  333  Accuracy =  54.5
# Generation  334  Accuracy =  54.5
# Generation  335  Accuracy =  54.5
# Generation  336  Accuracy =  54.5
# Generation  337  Accuracy =  54.5
# Generation  338  Accuracy =  54.5
# Generation  339  Accuracy =  54.5
# Generation  340  Accuracy =  54.5
# Generation  341  Accuracy =  54.5
# Generation  342  Accuracy =  54.5
# Generation  343  Accuracy =  54.5
# Generation  344  Accuracy =  54.5
# Generation  345  Accuracy =  54.5
# CREATING SAMPLE
# Generation  346  Accuracy =  57.5
# Generation  347  Accuracy =  57.5
# Generation  348  Accuracy =  57.5
# Generation  349  Accuracy =  57.5
# Generation  350  Accuracy =  57.5
# Generation  351  Accuracy =  57.5
# Generation  352  Accuracy =  57.5
# Generation  353  Accuracy =  57.5
# Generation  354  Accuracy =  57.5
# Generation  355  Accuracy =  57.5
# Generation  356  Accuracy =  57.5
# Generation  357  Accuracy =  57.5
# Generation  358  Accuracy =  57.5
# Generation  359  Accuracy =  57.5
# Generation  360  Accuracy =  57.5
# CREATING SAMPLE
# Generation  361  Accuracy =  51.5
# Generation  362  Accuracy =  51.5
# Generation  363  Accuracy =  51.5
# Generation  364  Accuracy =  51.5
# Generation  365  Accuracy =  51.5
# Generation  366  Accuracy =  53.5
# Generation  367  Accuracy =  53.5
# Generation  368  Accuracy =  53.5
# Generation  369  Accuracy =  53.5
# Generation  370  Accuracy =  53.5
# Generation  371  Accuracy =  53.5
# Generation  372  Accuracy =  53.5
# Generation  373  Accuracy =  53.5
# Generation  374  Accuracy =  53.5
# Generation  375  Accuracy =  53.5
# CREATING SAMPLE
# Generation  376  Accuracy =  56.5
# Generation  377  Accuracy =  56.5
# Generation  378  Accuracy =  56.5
# Generation  379  Accuracy =  56.5
# Generation  380  Accuracy =  56.5
# Generation  381  Accuracy =  56.5
# Generation  382  Accuracy =  56.5
# Generation  383  Accuracy =  56.5
# Generation  384  Accuracy =  56.5
# Generation  385  Accuracy =  56.5
# Generation  386  Accuracy =  56.5
# Generation  387  Accuracy =  56.5
# Generation  388  Accuracy =  56.5
# Generation  389  Accuracy =  56.5
# Generation  390  Accuracy =  56.5
# CREATING SAMPLE
# Generation  391  Accuracy =  49.5
# Generation  392  Accuracy =  49.5
# Generation  393  Accuracy =  49.5
# Generation  394  Accuracy =  49.5
# Generation  395  Accuracy =  49.5
# Generation  396  Accuracy =  49.5
# Generation  397  Accuracy =  49.5
# Generation  398  Accuracy =  49.5
# Generation  399  Accuracy =  49.5
# Generation  400  Accuracy =  49.5
# Generation  401  Accuracy =  49.5
# Generation  402  Accuracy =  49.5
# Generation  403  Accuracy =  49.5
# Generation  404  Accuracy =  49.5
# Generation  405  Accuracy =  49.5
# CREATING SAMPLE
# Generation  406  Accuracy =  53.0
# Generation  407  Accuracy =  53.0
# Generation  408  Accuracy =  53.0
# Generation  409  Accuracy =  53.0
# Generation  410  Accuracy =  53.0
# Generation  411  Accuracy =  53.0
# Generation  412  Accuracy =  53.0
# Generation  413  Accuracy =  53.0
# Generation  414  Accuracy =  53.0
# Generation  415  Accuracy =  53.0
# Generation  416  Accuracy =  53.0
# Generation  417  Accuracy =  53.0
# Generation  418  Accuracy =  53.0
# Generation  419  Accuracy =  53.0
# Generation  420  Accuracy =  53.0
# CREATING SAMPLE
# Generation  421  Accuracy =  53.5
# Generation  422  Accuracy =  53.5
# Generation  423  Accuracy =  56.5
# Generation  424  Accuracy =  56.5
# Generation  425  Accuracy =  56.5
# Generation  426  Accuracy =  56.5
# Generation  427  Accuracy =  56.5
# Generation  428  Accuracy =  56.5
# Generation  429  Accuracy =  56.5
# Generation  430  Accuracy =  56.5
# Generation  431  Accuracy =  56.5
# Generation  432  Accuracy =  56.5
# Generation  433  Accuracy =  56.5
# Generation  434  Accuracy =  56.5
# Generation  435  Accuracy =  56.5
# CREATING SAMPLE
# Generation  436  Accuracy =  51.0
# Generation  437  Accuracy =  51.0
# Generation  438  Accuracy =  51.0
# Generation  439  Accuracy =  51.0
# Generation  440  Accuracy =  51.0
# Generation  441  Accuracy =  56.5
# Generation  442  Accuracy =  56.5
# Generation  443  Accuracy =  56.5
# Generation  444  Accuracy =  56.5
# Generation  445  Accuracy =  56.5
# Generation  446  Accuracy =  56.5
# Generation  447  Accuracy =  56.5
# Generation  448  Accuracy =  56.5
# Generation  449  Accuracy =  56.5
# Generation  450  Accuracy =  56.5
# CREATING SAMPLE
# Generation  451  Accuracy =  53.0
# Generation  452  Accuracy =  53.0
# Generation  453  Accuracy =  53.0
# Generation  454  Accuracy =  53.0
# Generation  455  Accuracy =  53.0
# Generation  456  Accuracy =  53.0
# Generation  457  Accuracy =  53.0
# Generation  458  Accuracy =  53.0
# Generation  459  Accuracy =  53.0
# Generation  460  Accuracy =  53.0
# Generation  461  Accuracy =  53.0
# Generation  462  Accuracy =  53.0
# Generation  463  Accuracy =  53.0
# Generation  464  Accuracy =  53.0
# Generation  465  Accuracy =  53.0
# CREATING SAMPLE
# Generation  466  Accuracy =  54.5
# Generation  467  Accuracy =  54.5
# Generation  468  Accuracy =  54.5
# Generation  469  Accuracy =  54.5
# Generation  470  Accuracy =  54.5
# Generation  471  Accuracy =  54.5
# Generation  472  Accuracy =  54.5
# Generation  473  Accuracy =  54.5
# Generation  474  Accuracy =  54.5
# Generation  475  Accuracy =  54.5
# Generation  476  Accuracy =  54.5
# Generation  477  Accuracy =  54.5
# Generation  478  Accuracy =  56.0
# Generation  479  Accuracy =  56.0
# Generation  480  Accuracy =  56.0
# CREATING SAMPLE
# Generation  481  Accuracy =  59.0
# Generation  482  Accuracy =  59.0
# Generation  483  Accuracy =  59.0
# Generation  484  Accuracy =  59.0
# Generation  485  Accuracy =  59.0
# Generation  486  Accuracy =  59.0
# Generation  487  Accuracy =  59.0
# Generation  488  Accuracy =  59.0
# Generation  489  Accuracy =  59.0
# Generation  490  Accuracy =  59.0
# Generation  491  Accuracy =  59.0
# Generation  492  Accuracy =  59.0
# Generation  493  Accuracy =  59.0
# Generation  494  Accuracy =  59.0
# Generation  495  Accuracy =  59.0
# CREATING SAMPLE
# Generation  496  Accuracy =  54.0
# Generation  497  Accuracy =  55.5
# Generation  498  Accuracy =  55.5
# Generation  499  Accuracy =  55.5
# Generation  500  Accuracy =  55.5
# Generation  501  Accuracy =  55.5
# Generation  502  Accuracy =  55.5
# Generation  503  Accuracy =  55.5
# Generation  504  Accuracy =  55.5
# Generation  505  Accuracy =  56.5
# Generation  506  Accuracy =  56.5
# Generation  507  Accuracy =  56.5
# Generation  508  Accuracy =  56.5
# Generation  509  Accuracy =  56.5
# Generation  510  Accuracy =  56.5
# CREATING SAMPLE
# Generation  511  Accuracy =  52.5
# Generation  512  Accuracy =  52.5
# Generation  513  Accuracy =  52.5
# Generation  514  Accuracy =  52.5
# Generation  515  Accuracy =  52.5
# Generation  516  Accuracy =  52.5
# Generation  517  Accuracy =  52.5
# Generation  518  Accuracy =  52.5
# Generation  519  Accuracy =  52.5
# Generation  520  Accuracy =  52.5
# Generation  521  Accuracy =  52.5
# Generation  522  Accuracy =  52.5
# Generation  523  Accuracy =  52.5
# Generation  524  Accuracy =  52.5
# Generation  525  Accuracy =  52.5
# CREATING SAMPLE
# Generation  526  Accuracy =  50.0
# Generation  527  Accuracy =  50.0
# Generation  528  Accuracy =  50.0
# Generation  529  Accuracy =  50.0
# Generation  530  Accuracy =  50.0
# Generation  531  Accuracy =  50.0
# Generation  532  Accuracy =  50.5
# Generation  533  Accuracy =  50.5
# Generation  534  Accuracy =  50.5
# Generation  535  Accuracy =  50.5
# Generation  536  Accuracy =  50.5
# Generation  537  Accuracy =  50.5
# Generation  538  Accuracy =  50.5
# Generation  539  Accuracy =  50.5
# Generation  540  Accuracy =  50.5
# CREATING SAMPLE
# Generation  541  Accuracy =  49.5
# Generation  542  Accuracy =  49.5
# Generation  543  Accuracy =  49.5
# Generation  544  Accuracy =  49.5
# Generation  545  Accuracy =  49.5
# Generation  546  Accuracy =  49.5
# Generation  547  Accuracy =  49.5
# Generation  548  Accuracy =  49.5
# Generation  549  Accuracy =  49.5
# Generation  550  Accuracy =  49.5
# Generation  551  Accuracy =  49.5
# Generation  552  Accuracy =  49.5
# Generation  553  Accuracy =  50.5
# Generation  554  Accuracy =  50.5
# Generation  555  Accuracy =  50.5
# CREATING SAMPLE
# Generation  556  Accuracy =  49.0
# Generation  557  Accuracy =  49.0
# Generation  558  Accuracy =  49.0
# Generation  559  Accuracy =  49.0
# Generation  560  Accuracy =  49.0
# Generation  561  Accuracy =  49.0
# Generation  562  Accuracy =  49.0
# Generation  563  Accuracy =  49.0
# Generation  564  Accuracy =  49.0
# Generation  565  Accuracy =  49.0
# Generation  566  Accuracy =  49.0
# Generation  567  Accuracy =  49.0
# Generation  568  Accuracy =  49.0
# Generation  569  Accuracy =  49.0
# Generation  570  Accuracy =  49.0
# CREATING SAMPLE
# Generation  571  Accuracy =  60.0
# Generation  572  Accuracy =  60.0
# Generation  573  Accuracy =  60.0
# Generation  574  Accuracy =  60.0
# Generation  575  Accuracy =  60.0
# Generation  576  Accuracy =  60.0
# Generation  577  Accuracy =  60.0
# Generation  578  Accuracy =  60.0
# Generation  579  Accuracy =  60.0
# Generation  580  Accuracy =  60.0
# Generation  581  Accuracy =  60.0
# Generation  582  Accuracy =  60.0
# Generation  583  Accuracy =  60.0
# Generation  584  Accuracy =  60.0
# Generation  585  Accuracy =  60.0
# CREATING SAMPLE
# Generation  586  Accuracy =  57.5
# Generation  587  Accuracy =  57.5
# Generation  588  Accuracy =  57.5
# Generation  589  Accuracy =  57.5
# Generation  590  Accuracy =  57.5
# Generation  591  Accuracy =  57.5
# Generation  592  Accuracy =  57.5
# Generation  593  Accuracy =  57.5
# Generation  594  Accuracy =  57.5
# Generation  595  Accuracy =  57.5
# Generation  596  Accuracy =  57.5
# Generation  597  Accuracy =  57.5
# Generation  598  Accuracy =  57.5
# Generation  599  Accuracy =  57.5
# Generation  600  Accuracy =  57.5
# CREATING SAMPLE
# Generation  601  Accuracy =  53.0
# Generation  602  Accuracy =  53.0
# Generation  603  Accuracy =  53.0
# Generation  604  Accuracy =  53.0
# Generation  605  Accuracy =  53.0
# Generation  606  Accuracy =  53.0
# Generation  607  Accuracy =  53.0
# Generation  608  Accuracy =  53.0
# Generation  609  Accuracy =  53.0
# Generation  610  Accuracy =  53.0
# Generation  611  Accuracy =  53.0
# Generation  612  Accuracy =  53.0
# Generation  613  Accuracy =  54.5
# Generation  614  Accuracy =  54.5
# Generation  615  Accuracy =  54.5
# CREATING SAMPLE
# Generation  616  Accuracy =  53.0
# Generation  617  Accuracy =  53.0
# Generation  618  Accuracy =  53.0
# Generation  619  Accuracy =  53.0
# Generation  620  Accuracy =  53.0
# Generation  621  Accuracy =  53.0
# Generation  622  Accuracy =  53.0
# Generation  623  Accuracy =  53.0
# Generation  624  Accuracy =  53.0
# Generation  625  Accuracy =  53.0
# Generation  626  Accuracy =  53.0
# Generation  627  Accuracy =  53.0
# Generation  628  Accuracy =  53.0
# Generation  629  Accuracy =  53.0
# Generation  630  Accuracy =  53.0
# CREATING SAMPLE
# Generation  631  Accuracy =  48.0
# Generation  632  Accuracy =  48.0
# Generation  633  Accuracy =  48.0
# Generation  634  Accuracy =  48.0
# Generation  635  Accuracy =  48.0
# Generation  636  Accuracy =  48.0
# Generation  637  Accuracy =  48.0
# Generation  638  Accuracy =  48.0
# Generation  639  Accuracy =  48.0
# Generation  640  Accuracy =  48.0
# Generation  641  Accuracy =  48.0
# Generation  642  Accuracy =  48.0
# Generation  643  Accuracy =  48.0
# Generation  644  Accuracy =  48.0
# Generation  645  Accuracy =  48.0
# CREATING SAMPLE
# Generation  646  Accuracy =  53.0
# Generation  647  Accuracy =  53.0
# Generation  648  Accuracy =  53.0
# Generation  649  Accuracy =  53.0
# Generation  650  Accuracy =  53.0
# Generation  651  Accuracy =  53.0
# Generation  652  Accuracy =  53.0
# Generation  653  Accuracy =  53.0
# Generation  654  Accuracy =  53.0
# Generation  655  Accuracy =  53.0
# Generation  656  Accuracy =  53.0
# Generation  657  Accuracy =  53.0
# Generation  658  Accuracy =  53.0
# Generation  659  Accuracy =  53.5
# Generation  660  Accuracy =  53.5
# CREATING SAMPLE
# Generation  661  Accuracy =  53.0
# Generation  662  Accuracy =  53.0
# Generation  663  Accuracy =  53.0
# Generation  664  Accuracy =  53.0
# Generation  665  Accuracy =  53.0
# Generation  666  Accuracy =  53.0
# Generation  667  Accuracy =  53.0
# Generation  668  Accuracy =  53.0
# Generation  669  Accuracy =  53.0
# Generation  670  Accuracy =  53.0
# Generation  671  Accuracy =  53.0
# Generation  672  Accuracy =  54.0
# Generation  673  Accuracy =  54.0
# Generation  674  Accuracy =  54.0
# Generation  675  Accuracy =  54.0
# CREATING SAMPLE
# Generation  676  Accuracy =  53.5
# ...
# Generation  139  Accuracy =  51.0
# Generation  140  Accuracy =  51.0
# Generation  141  Accuracy =  51.0
# Generation  142  Accuracy =  51.0
# Generation  143  Accuracy =  51.0
# Generation  144  Accuracy =  51.0
# Generation  145  Accuracy =  51.0
# Generation  146  Accuracy =  51.0
# Generation  147  Accuracy =  51.0
# Generation  148  Accuracy =  51.0
# Generation  149  Accuracy =  51.0
# Generation  150  Accuracy =  51.0
# CREATING SAMPLE
# Generation  151  Accuracy =  55.0
# Generation  152  Accuracy =  55.0
# Generation  153  Accuracy =  55.0
# Generation  154  Accuracy =  55.0
# Generation  155  Accuracy =  55.0
# Generation  156  Accuracy =  55.0
# Generation  157  Accuracy =  55.0
# Generation  158  Accuracy =  55.0
# Generation  159  Accuracy =  55.0
# Generation  160  Accuracy =  55.0
# Generation  161  Accuracy =  55.0
# Generation  162  Accuracy =  55.0
# Generation  163  Accuracy =  55.0
# Generation  164  Accuracy =  55.0
# Generation  165  Accuracy =  55.0
# CREATING SAMPLE
# Generation  166  Accuracy =  53.0
# Generation  167  Accuracy =  53.0
# Generation  168  Accuracy =  53.0
# Generation  169  Accuracy =  53.0
# Generation  170  Accuracy =  53.0
# Generation  171  Accuracy =  53.0
# Generation  172  Accuracy =  53.0
# Generation  173  Accuracy =  53.0
# Generation  174  Accuracy =  53.0
# Generation  175  Accuracy =  53.0
# Generation  176  Accuracy =  53.0
# Generation  177  Accuracy =  53.0
# Generation  178  Accuracy =  53.0
# Generation  179  Accuracy =  53.0
# Generation  180  Accuracy =  53.0
# CREATING SAMPLE
# Generation  181  Accuracy =  53.5
# Generation  182  Accuracy =  53.5
# Generation  183  Accuracy =  53.5
# Generation  184  Accuracy =  53.5
# Generation  185  Accuracy =  53.5
# Generation  186  Accuracy =  53.5
# Generation  187  Accuracy =  53.5
# Generation  188  Accuracy =  53.5
# Generation  189  Accuracy =  53.5
# Generation  190  Accuracy =  53.5
# Generation  191  Accuracy =  53.5
# Generation  192  Accuracy =  53.5
# Generation  193  Accuracy =  53.5
# Generation  194  Accuracy =  53.5
# Generation  195  Accuracy =  53.5
# CREATING SAMPLE
# Generation  196  Accuracy =  48.5
# Generation  197  Accuracy =  48.5
# Generation  198  Accuracy =  48.5
# Generation  199  Accuracy =  48.5
# Generation  200  Accuracy =  49.0
# Generation  201  Accuracy =  49.0
# Generation  202  Accuracy =  49.0
# Generation  203  Accuracy =  51.5
# Generation  204  Accuracy =  51.5
# Generation  205  Accuracy =  51.5
# Generation  206  Accuracy =  51.5
# Generation  207  Accuracy =  51.5
# Generation  208  Accuracy =  51.5
# Generation  209  Accuracy =  51.5
# Generation  210  Accuracy =  51.5
# CREATING SAMPLE
# Generation  211  Accuracy =  52.5
# Generation  212  Accuracy =  52.5
# Generation  213  Accuracy =  52.5
# Generation  214  Accuracy =  52.5
# Generation  215  Accuracy =  52.5
# Generation  216  Accuracy =  52.5
# Generation  217  Accuracy =  52.5
# Generation  218  Accuracy =  52.5
# Generation  219  Accuracy =  52.5
# Generation  220  Accuracy =  52.5
# Generation  221  Accuracy =  52.5
# Generation  222  Accuracy =  52.5
# Generation  223  Accuracy =  52.5
# Generation  224  Accuracy =  52.5
# Generation  225  Accuracy =  52.5
# CREATING SAMPLE
# Generation  226  Accuracy =  49.0
# Generation  227  Accuracy =  49.0
# Generation  228  Accuracy =  49.0
# Generation  229  Accuracy =  49.0
# Generation  230  Accuracy =  49.0
# Generation  231  Accuracy =  49.0
# Generation  232  Accuracy =  49.0
# Generation  233  Accuracy =  49.0
# Generation  234  Accuracy =  49.0
# Generation  235  Accuracy =  49.0
# Generation  236  Accuracy =  49.0
# Generation  237  Accuracy =  49.0
# Generation  238  Accuracy =  49.0
# Generation  239  Accuracy =  49.0
# Generation  240  Accuracy =  49.0
# CREATING SAMPLE
# Generation  241  Accuracy =  51.0
# Generation  242  Accuracy =  51.0
# Generation  243  Accuracy =  51.0
# Generation  244  Accuracy =  51.0
# Generation  245  Accuracy =  52.5
# Generation  246  Accuracy =  52.5
# Generation  247  Accuracy =  52.5
# Generation  248  Accuracy =  52.5
# Generation  249  Accuracy =  52.5
# Generation  250  Accuracy =  52.5
# Generation  251  Accuracy =  52.5
# Generation  252  Accuracy =  52.5
# Generation  253  Accuracy =  52.5
# Generation  254  Accuracy =  52.5
# Generation  255  Accuracy =  52.5
# CREATING SAMPLE
# Generation  256  Accuracy =  53.5
# Generation  257  Accuracy =  53.5
# Generation  258  Accuracy =  53.5
# Generation  259  Accuracy =  53.5
# Generation  260  Accuracy =  53.5
# Generation  261  Accuracy =  53.5
# Generation  262  Accuracy =  53.5
# Generation  263  Accuracy =  53.5
# Generation  264  Accuracy =  54.0
# Generation  265  Accuracy =  57.0
# Generation  266  Accuracy =  57.0
# Generation  267  Accuracy =  57.0
# Generation  268  Accuracy =  57.0
# Generation  269  Accuracy =  57.0
# Generation  270  Accuracy =  57.0
# CREATING SAMPLE
# Generation  271  Accuracy =  57.5
# Generation  272  Accuracy =  57.5
# Generation  273  Accuracy =  57.5
# Generation  274  Accuracy =  57.5
# Generation  275  Accuracy =  57.5
# Generation  276  Accuracy =  57.5
# Generation  277  Accuracy =  57.5
# Generation  278  Accuracy =  57.5
# Generation  279  Accuracy =  57.5
# Generation  280  Accuracy =  57.5
# Generation  281  Accuracy =  57.5
# Generation  282  Accuracy =  57.5
# Generation  283  Accuracy =  57.5
# Generation  284  Accuracy =  57.5
# Generation  285  Accuracy =  57.5
# CREATING SAMPLE
# Generation  286  Accuracy =  62.0
# Generation  287  Accuracy =  66.0
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  50.0
# Generation  2  Accuracy =  50.0
# Generation  3  Accuracy =  50.0
# Generation  4  Accuracy =  50.0
# Generation  5  Accuracy =  50.0
# Generation  6  Accuracy =  50.0
# Generation  7  Accuracy =  50.0
# Generation  8  Accuracy =  50.0
# Generation  9  Accuracy =  50.0
# Generation  10  Accuracy =  50.0
# Generation  11  Accuracy =  50.0
# Generation  12  Accuracy =  50.0
# Generation  13  Accuracy =  50.0
# Generation  14  Accuracy =  50.0
# Generation  15  Accuracy =  50.0
# CREATING SAMPLE
# Generation  16  Accuracy =  49.5
# Generation  17  Accuracy =  49.5
# Generation  18  Accuracy =  49.5
# Generation  19  Accuracy =  49.5
# Generation  20  Accuracy =  49.5
# Generation  21  Accuracy =  49.5
# Generation  22  Accuracy =  49.5
# Generation  23  Accuracy =  49.5
# Generation  24  Accuracy =  49.5
# Generation  25  Accuracy =  49.5
# Generation  26  Accuracy =  49.5
# Generation  27  Accuracy =  49.5
# Generation  28  Accuracy =  49.5
# Generation  29  Accuracy =  49.5
# Generation  30  Accuracy =  49.5
# CREATING SAMPLE
# Generation  31  Accuracy =  53.5
# Generation  32  Accuracy =  53.5
# Generation  33  Accuracy =  53.5
# Generation  34  Accuracy =  53.5
# Generation  35  Accuracy =  54.5
# Generation  36  Accuracy =  54.5
# Generation  37  Accuracy =  54.5
# Generation  38  Accuracy =  54.5
# Generation  39  Accuracy =  54.5
# Generation  40  Accuracy =  54.5
# Generation  41  Accuracy =  54.5
# Generation  42  Accuracy =  55.5
# Generation  43  Accuracy =  55.5
# Generation  44  Accuracy =  55.5
# Generation  45  Accuracy =  55.5
# CREATING SAMPLE
# Generation  46  Accuracy =  51.5
# Generation  47  Accuracy =  51.5
# Generation  48  Accuracy =  51.5
# Generation  49  Accuracy =  51.5
# Generation  50  Accuracy =  51.5
# Generation  51  Accuracy =  51.5
# Generation  52  Accuracy =  51.5
# Generation  53  Accuracy =  57.0
# Generation  54  Accuracy =  57.0
# Generation  55  Accuracy =  57.0
# Generation  56  Accuracy =  57.0
# Generation  57  Accuracy =  57.0
# Generation  58  Accuracy =  57.0
# Generation  59  Accuracy =  57.0
# Generation  60  Accuracy =  57.0
# CREATING SAMPLE
# Generation  61  Accuracy =  52.0
# Generation  62  Accuracy =  52.0
# Generation  63  Accuracy =  52.0
# Generation  64  Accuracy =  52.0
# Generation  65  Accuracy =  52.0
# Generation  66  Accuracy =  52.0
# Generation  67  Accuracy =  52.0
# Generation  68  Accuracy =  52.0
# Generation  69  Accuracy =  52.0
# Generation  70  Accuracy =  52.0
# Generation  71  Accuracy =  52.0
# Generation  72  Accuracy =  52.0
# Generation  73  Accuracy =  52.0
# Generation  74  Accuracy =  53.5
# Generation  75  Accuracy =  53.5
# CREATING SAMPLE
# Generation  76  Accuracy =  53.0
# Generation  77  Accuracy =  53.0
# Generation  78  Accuracy =  56.0
# Generation  79  Accuracy =  56.0
# Generation  80  Accuracy =  56.0
# Generation  81  Accuracy =  56.0
# Generation  82  Accuracy =  56.0
# Generation  83  Accuracy =  56.0
# Generation  84  Accuracy =  56.0
# Generation  85  Accuracy =  56.0
# Generation  86  Accuracy =  56.0
# Generation  87  Accuracy =  56.0
# Generation  88  Accuracy =  56.0
# Generation  89  Accuracy =  56.0
# Generation  90  Accuracy =  56.0
# CREATING SAMPLE
# Generation  91  Accuracy =  59.0
# Generation  92  Accuracy =  59.0
# Generation  93  Accuracy =  59.0
# Generation  94  Accuracy =  59.0
# Generation  95  Accuracy =  59.0
# Generation  96  Accuracy =  59.0
# Generation  97  Accuracy =  59.0
# Generation  98  Accuracy =  59.0
# Generation  99  Accuracy =  59.0
# Generation  100  Accuracy =  59.0
# Generation  101  Accuracy =  59.0
# Generation  102  Accuracy =  59.0
# Generation  103  Accuracy =  59.0
# Generation  104  Accuracy =  59.0
# Generation  105  Accuracy =  59.0
# CREATING SAMPLE
# Generation  106  Accuracy =  59.5
# Generation  107  Accuracy =  59.5
# Generation  108  Accuracy =  59.5
# Generation  109  Accuracy =  59.5
# Generation  110  Accuracy =  59.5
# Generation  111  Accuracy =  59.5
# Generation  112  Accuracy =  59.5
# Generation  113  Accuracy =  59.5
# Generation  114  Accuracy =  59.5
# Generation  115  Accuracy =  59.5
# Generation  116  Accuracy =  59.5
# Generation  117  Accuracy =  59.5
# Generation  118  Accuracy =  59.5
# Generation  119  Accuracy =  60.0
# Generation  120  Accuracy =  60.0
# CREATING SAMPLE
# Generation  121  Accuracy =  64.0
# Generation  122  Accuracy =  64.0
# Generation  123  Accuracy =  64.0
# Generation  124  Accuracy =  64.0
# Generation  125  Accuracy =  64.0
# Generation  126  Accuracy =  64.0
# Generation  127  Accuracy =  64.0
# Generation  128  Accuracy =  64.0
# Generation  129  Accuracy =  64.0
# Generation  130  Accuracy =  64.0
# Generation  131  Accuracy =  64.0
# Generation  132  Accuracy =  64.0
# Generation  133  Accuracy =  64.0
# Generation  134  Accuracy =  64.0
# Generation  135  Accuracy =  67.5
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  49.0
# Generation  2  Accuracy =  49.0
# Generation  3  Accuracy =  49.0
# Generation  4  Accuracy =  49.0
# Generation  5  Accuracy =  49.0
# Generation  6  Accuracy =  49.5
# Generation  7  Accuracy =  49.5
# Generation  8  Accuracy =  49.5
# Generation  9  Accuracy =  49.5
# Generation  10  Accuracy =  49.5
# Generation  11  Accuracy =  49.5
# Generation  12  Accuracy =  49.5
# Generation  13  Accuracy =  49.5
# Generation  14  Accuracy =  49.5
# Generation  15  Accuracy =  49.5
# CREATING SAMPLE
# Generation  16  Accuracy =  48.5
# Generation  17  Accuracy =  48.5
# Generation  18  Accuracy =  49.5
# Generation  19  Accuracy =  49.5
# Generation  20  Accuracy =  51.0
# Generation  21  Accuracy =  51.0
# Generation  22  Accuracy =  51.0
# Generation  23  Accuracy =  51.0
# Generation  24  Accuracy =  51.0
# Generation  25  Accuracy =  51.0
# Generation  26  Accuracy =  51.0
# Generation  27  Accuracy =  51.0
# Generation  28  Accuracy =  51.0
# Generation  29  Accuracy =  51.0
# Generation  30  Accuracy =  51.0
# CREATING SAMPLE
# Generation  31  Accuracy =  54.0
# Generation  32  Accuracy =  54.0
# Generation  33  Accuracy =  54.0
# Generation  34  Accuracy =  54.0
# Generation  35  Accuracy =  54.0
# Generation  36  Accuracy =  54.0
# Generation  37  Accuracy =  54.0
# Generation  38  Accuracy =  54.0
# Generation  39  Accuracy =  54.0
# Generation  40  Accuracy =  54.0
# Generation  41  Accuracy =  54.0
# Generation  42  Accuracy =  54.0
# Generation  43  Accuracy =  54.0
# Generation  44  Accuracy =  54.0
# Generation  45  Accuracy =  54.0
# CREATING SAMPLE
# Generation  46  Accuracy =  51.0
# Generation  47  Accuracy =  51.0
# Generation  48  Accuracy =  51.0
# Generation  49  Accuracy =  51.0
# Generation  50  Accuracy =  51.0
# Generation  51  Accuracy =  51.0
# Generation  52  Accuracy =  51.0
# Generation  53  Accuracy =  51.0
# Generation  54  Accuracy =  51.0
# Generation  55  Accuracy =  51.0
# Generation  56  Accuracy =  51.0
# Generation  57  Accuracy =  51.5
# Generation  58  Accuracy =  51.5
# Generation  59  Accuracy =  51.5
# Generation  60  Accuracy =  51.5
# CREATING SAMPLE
# Generation  61  Accuracy =  49.5
# Generation  62  Accuracy =  49.5
# Generation  63  Accuracy =  49.5
# Generation  64  Accuracy =  49.5
# Generation  65  Accuracy =  49.5
# Generation  66  Accuracy =  49.5
# Generation  67  Accuracy =  49.5
# Generation  68  Accuracy =  49.5
# Generation  69  Accuracy =  49.5
# Generation  70  Accuracy =  49.5
# Generation  71  Accuracy =  49.5
# Generation  72  Accuracy =  49.5
# Generation  73  Accuracy =  50.0
# Generation  74  Accuracy =  50.0
# Generation  75  Accuracy =  50.0
# CREATING SAMPLE
# Generation  76  Accuracy =  52.0
# Generation  77  Accuracy =  52.0
# Generation  78  Accuracy =  52.0
# Generation  79  Accuracy =  52.0
# Generation  80  Accuracy =  52.0
# Generation  81  Accuracy =  52.0
# Generation  82  Accuracy =  52.0
# Generation  83  Accuracy =  52.0
# Generation  84  Accuracy =  52.0
# Generation  85  Accuracy =  52.0
# Generation  86  Accuracy =  52.0
# Generation  87  Accuracy =  52.0
# Generation  88  Accuracy =  52.0
# Generation  89  Accuracy =  52.0
# Generation  90  Accuracy =  52.0
# CREATING SAMPLE
# Generation  91  Accuracy =  51.5
# Generation  92  Accuracy =  51.5
# Generation  93  Accuracy =  51.5
# Generation  94  Accuracy =  51.5
# Generation  95  Accuracy =  51.5
# Generation  96  Accuracy =  51.5
# Generation  97  Accuracy =  51.5
# Generation  98  Accuracy =  51.5
# Generation  99  Accuracy =  51.5
# Generation  100  Accuracy =  51.5
# Generation  101  Accuracy =  51.5
# Generation  102  Accuracy =  51.5
# Generation  103  Accuracy =  51.5
# Generation  104  Accuracy =  59.0
# Generation  105  Accuracy =  59.0
# CREATING SAMPLE
# Generation  106  Accuracy =  53.0
# Generation  107  Accuracy =  53.0
# Generation  108  Accuracy =  53.0
# Generation  109  Accuracy =  53.0
# Generation  110  Accuracy =  53.0
# Generation  111  Accuracy =  53.0
# Generation  112  Accuracy =  53.0
# Generation  113  Accuracy =  53.0
# Generation  114  Accuracy =  53.0
# Generation  115  Accuracy =  53.0
# Generation  116  Accuracy =  53.0
# Generation  117  Accuracy =  53.0
# Generation  118  Accuracy =  53.0
# Generation  119  Accuracy =  53.0
# Generation  120  Accuracy =  53.0
# CREATING SAMPLE
# Generation  121  Accuracy =  60.5
# Generation  122  Accuracy =  60.5
# Generation  123  Accuracy =  60.5
# Generation  124  Accuracy =  60.5
# Generation  125  Accuracy =  60.5
# Generation  126  Accuracy =  60.5
# Generation  127  Accuracy =  60.5
# Generation  128  Accuracy =  60.5
# Generation  129  Accuracy =  60.5
# Generation  130  Accuracy =  60.5
# Generation  131  Accuracy =  60.5
# Generation  132  Accuracy =  60.5
# Generation  133  Accuracy =  60.5
# Generation  134  Accuracy =  60.5
# Generation  135  Accuracy =  60.5
# CREATING SAMPLE
# Generation  136  Accuracy =  59.0
# Generation  137  Accuracy =  59.0
# Generation  138  Accuracy =  59.0
# Generation  139  Accuracy =  59.0
# Generation  140  Accuracy =  59.0
# Generation  141  Accuracy =  59.0
# Generation  142  Accuracy =  59.0
# Generation  143  Accuracy =  59.0
# Generation  144  Accuracy =  59.0
# Generation  145  Accuracy =  59.0
# Generation  146  Accuracy =  59.0
# Generation  147  Accuracy =  59.0
# Generation  148  Accuracy =  59.0
# Generation  149  Accuracy =  59.0
# Generation  150  Accuracy =  59.0
# CREATING SAMPLE
# Generation  151  Accuracy =  67.0
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  44.0
# Generation  2  Accuracy =  46.0
# Generation  3  Accuracy =  46.0
# Generation  4  Accuracy =  46.0
# Generation  5  Accuracy =  46.0
# Generation  6  Accuracy =  48.0
# Generation  7  Accuracy =  48.0
# Generation  8  Accuracy =  48.0
# Generation  9  Accuracy =  48.0
# Generation  10  Accuracy =  48.0
# Generation  11  Accuracy =  48.0
# Generation  12  Accuracy =  48.0
# Generation  13  Accuracy =  48.0
# Generation  14  Accuracy =  48.0
# Generation  15  Accuracy =  48.0
# CREATING SAMPLE
# Generation  16  Accuracy =  53.0
# Generation  17  Accuracy =  53.0
# Generation  18  Accuracy =  53.0
# Generation  19  Accuracy =  53.0
# Generation  20  Accuracy =  53.0
# Generation  21  Accuracy =  53.0

# %%
plt.plot(range(len(accuracyOverGenerations)), accuracyOverGenerations)
plt.plot(range(len(accuracyOverGenerations)), testAccuracy)
plt.xlabel("Generations")
plt.ylabel("Accuracy")
plt.title("Overall Accuracy Curve")
