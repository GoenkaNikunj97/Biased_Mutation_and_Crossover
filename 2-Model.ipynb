# %%
#importing libraries

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from tqdm import tqdm
import numpy as np
import pandas as pd
import random
import copy

# %%
from google.colab import drive
drive.mount('/content/drive')

DataFolder = "/content/drive/My Drive/Colab Notebooks/geneticsProject/data/"

# CONFIG
SAMPLE_SIZE =200
CHANGE_SAMPLE_AFTER = 15
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class Config:
    MAX_INSTRUCTION_SET_LENGTH = 256
    INIT_MAX_INSTRUCTION_SET_LENGTH = 128
    MIN_INSTRUCTION_SET_LENGTH = 8
    TOTAL_OUTPUT_REGISTER = 10
    TOTAL_OPERATIONS = 4

    #PAR TO TUNE!
    GAP_PERCENTAGE = 20
    MUTATION_PROBABILITY = 90
    CROSSOVER_PROBABILITY = 90
    POPULATION_SIZE = 150
    SAME_NUMBER_OF_ITERATIONS = 50

# %% [markdown]
# ### Get Data

# %%
def getDataFromFile(fileName):
  #Read File
  df = pd.read_csv(fileName, sep=" " ,header=None)
  data = df.dropna(axis=1)

  return data

# %%
def getData(target):
  trainFile = DataFolder + target +"/train.txt"
  testFile = DataFolder + target +"/test.txt"

  #Training Data
  trainData =  getDataFromFile(trainFile)

  #Post Training Evaluation
  testData =  getDataFromFile(testFile)

  return trainData,testData

# %%
def getuniformSample(data, sampleSize, lableSize):
  print("CREATING SAMPLE")
  classesIndex = (data.shape)[1] - 1
  allLables = data[classesIndex].unique()

  #empty Sample df
  sample = pd.DataFrame()
  tempData = data[:]

  while(len(sample) < sampleSize):
    lableToSelect = random.choice(allLables)
    dataForClass = tempData[tempData[classesIndex] == (lableToSelect)]
    selectedData = dataForClass.sample(n=1, replace=False)
    sample = sample.append(selectedData)
    tempData.drop(selectedData.index)
    
  return sample

# %%
def splitDataForXandY(data):
  X = data[data.columns[:-1]]
  Y = data[data.columns[-1]]
  
  # one hot encode lable
  Y = pd.get_dummies(Y)
  
  X = X.values.tolist()
  Y = Y.values.tolist()
  
  return X,Y

# %% [markdown]
# ### Creating Individuals and population

# %%
class Individual:
    # Operators = [+, -, /2, *2]
    # Operators = [0, 1,  2 , 3]
    # instructionSet = [ Select | target Register | operator| source ]

    def __init__(self, instructionSet):
        self.instructionSet = instructionSet
        self.registers = [0] * Config.TOTAL_OUTPUT_REGISTER
        self.fitnessScore = 0

    def reset(self):
        self.registers = [0] * Config.TOTAL_OUTPUT_REGISTER

    def resetFitness(self):
        self.fitnessScore = 0

    def isValid(self):
        if( (len(self.instructionSet) > Config.MIN_INSTRUCTION_SET_LENGTH) and (len(self.instructionSet) < Config.MAX_INSTRUCTION_SET_LENGTH)):
            return True
        else:
            return False

    def runProgram(self, data):
        self.reset()
        for instruction in self.instructionSet:
            select = instruction[0]
            target = instruction[1]
            operator = instruction[2]
            source = instruction[3]

            if select == 0:
                source = source%len(data)
                source = data[source]
            else:
                source = source % Config.TOTAL_OUTPUT_REGISTER
                source = self.registers[source]

            if operator == 0:
                self.registers[target] = self.registers[target] + source
            if operator == 1:
                self.registers[target] = self.registers[target] - source
            if operator == 2:
                self.registers[target] = self.registers[target] / 2
            if operator == 3:
                self.registers[target] = self.registers[target] * 2

    def predict(self, data, lable):

        self.runProgram(data)

        maxLableIndex = np.array(lable).argmax()
        maxRegisterIndex = np.array(self.registers[:len(lable)]).argmax()

        if maxLableIndex == maxRegisterIndex:
            return True
        else:
            return False

# %%
def getInstructionSet(dataLen):
  
  configOb = Config()

  #randomly selecting the length of instruction set
  endIndex = random.randint(2,configOb.INIT_MAX_INSTRUCTION_SET_LENGTH)
  instructionSet = list()
  for i in range(endIndex):
    selectBit = random.randint(0,1)
    targetValue = random.randint(0,configOb.TOTAL_OUTPUT_REGISTER - 1)
    operator = random.randint(0,configOb.TOTAL_OPERATIONS - 1)
    source = random.randint(0,max(dataLen, configOb.TOTAL_OUTPUT_REGISTER ) - 1 )

    instruction = [selectBit, targetValue, operator, source]
    instructionSet.append(instruction)

  return instructionSet

# %%
def createGenotype(X):
  dataLen = len(X[0])
  populationList = list()
  for i in range(Config.POPULATION_SIZE):
    individualInstructionSet = getInstructionSet(dataLen)
    individualOb = Individual(individualInstructionSet)
    populationList.append(individualOb)
    
  print(str(len(populationList)) + " individuals created.")
  return populationList

# %% [markdown]
# ### Methods for GL

# %%
class TwoPointCrossover:

  def getBiasedCrossoverPoints(self, parent):
    n = len(parent.instructionSet)
    temp = 1
    myList = []
    while (temp <= n):
      tempList = [temp-1]*temp
      myList = myList + tempList
      temp +=1

    crossoverPoint1 = random.choice(myList)
    crossoverPoint2 = random.choice(myList)
    while (crossoverPoint1 == crossoverPoint2 or crossoverPoint1 > crossoverPoint2):
      crossoverPoint1 = random.choice(myList)
      crossoverPoint2 = random.choice(myList)

    return crossoverPoint1,crossoverPoint2
  
  def getTwoCrossoverPoints(self, parent):
    crossoverPoint1 = 0
    crossoverPoint2 = 0
    while (crossoverPoint1 == crossoverPoint2):
      crossoverPoint1 = random.randint(0, len(parent.instructionSet) - 2)
      crossoverPoint2 = random.randint(crossoverPoint1 + 1, len(parent.instructionSet) - 1)
      
    return crossoverPoint1,crossoverPoint2
    
  def createChild(self, parent1, parent2, p1CP1,p1CP2, p2CP1,p2CP2 ):
    childInstructionSet = parent1.instructionSet[:p1CP1 - 1]
    childInstructionSet = childInstructionSet + parent2.instructionSet[p2CP1: p2CP2]
    childInstructionSet = childInstructionSet + parent1.instructionSet[p1CP2 + 1:]

    child = Individual(childInstructionSet)

    return child
  
  def crossover(self, parent1, parent2):
    p1CP1, p1CP2 = self.getBiasedCrossoverPoints(parent1)
    p2CP1, p2CP2 = self.getBiasedCrossoverPoints(parent2)

    child1 = self.createChild(parent1, parent2, p1CP1, p1CP2, p2CP1, p2CP2)

    child2 = self.createChild(parent2, parent1, p2CP1, p2CP2, p1CP1, p1CP2)

    if (not (child1.isValid())):
      child1 = None
      if (not (child2.isValid())):
        child2 = None
    return child1, child2

# %%
class Mutation:

    mutationTypes = 3

    def swapMutation(self, child):
        bit1 = random.randint(0, len(child.instructionSet) - 1)
        bit2 = random.randint(0, len(child.instructionSet) - 1)
        #print("Swapping bit: ",bit1, "and ", bit2)
        child.instructionSet[bit1], child.instructionSet[bit2] = child.instructionSet[bit2], child.instructionSet[bit1]

        return child

    def reverseMutation(self, child):
        bit1 = random.randint(0, len(child.instructionSet) - 2)
        bit2 = random.randint(bit1+1, len(child.instructionSet) - 1)

        mutatedChild = child.instructionSet[0:bit1] + child.instructionSet[bit2: bit1-1: -1] + child.instructionSet[bit2+1:]
        mutatedChild = Individual(mutatedChild)

        return mutatedChild

    def scrambleMutation(self, child):
        bit1 = random.randint(0, len(child.instructionSet) - 2)
        bit2 = random.randint(bit1 + 1, len(child.instructionSet) - 1)

        temp = child.instructionSet[bit1: bit2]
        random.shuffle(temp)
        mutatedList = child.instructionSet[:bit1] + temp + child.instructionSet[bit2:]
        mutatedChild = Individual(mutatedList)

        return mutatedChild

    def mutateIndividual(self, childToMutate):
        child = childToMutate
        type = random.randint(0, self.mutationTypes - 1)
        if (random.randint(0, 100) < Config.MUTATION_PROBABILITY):
            if (type == 0):
                child = self.swapMutation(child)
            if (type == 1):
                child = self.reverseMutation(child)
            if (type == 2):
                child = self.scrambleMutation(child)

        return child

# %%
def calculateFitness(populationList, data, lable):
  for person in populationList:
    correctPrediction = 0
    person.resetFitness()
    for i in range(len(data)):
      answer = person.predict(data[i] , lable[i])
      correctPrediction += answer

    fitness = 100*(correctPrediction/len(data))
    person.fitnessScore = fitness

# %%
def getGapedPopulation(populationList):
  sortedPopulation = sorted(populationList, key=lambda x: x.fitnessScore, reverse=True)
  
  totalGap = (Config.GAP_PERCENTAGE * len(sortedPopulation)) / 100
  
  gapedPopulation = sortedPopulation[: int(len(sortedPopulation)- totalGap)]
  return gapedPopulation

# %%
def isChildReadyToPush(populationList, child,newPopulation):
  crossoverChance = random.randint(0, 100) < Config.CROSSOVER_PROBABILITY
  if (crossoverChance and (not (child is None)) and (len(newPopulation) < len(populationList))):
    return True
  else:
    return False

# %%
def breed(populationList, gapedPopulation):
  newPopulation = gapedPopulation[:]
  while (len(newPopulation) < len(populationList)):
    parent1 = random.choice(gapedPopulation)
    parent2 = random.choice(gapedPopulation)
    if (len(parent1.instructionSet) > 5 and len(parent2.instructionSet) > 5):
      child1,child2 = TwoPointCrossover().crossover(parent1, parent2)
    else:
      break
    mutationOb = Mutation()
    
    if (isChildReadyToPush(populationList, child1, newPopulation)):
      mutatedChild = mutationOb.mutateIndividual(child1)
      newPopulation.append(mutatedChild)
      
      if (isChildReadyToPush(populationList,child2,newPopulation)):
        mutatedChild = mutationOb.mutateIndividual(child2)
        newPopulation.append(mutatedChild)
  
  return newPopulation

# %% [markdown]
# ### Making Data for visualization

# %%
def pushToGenerationAccuracyDictionary(classwiseAccuracy,classWiseAccuracyInGeneration):
  for key in classwiseAccuracy.keys():
    if key in classWiseAccuracyInGeneration:
      classWiseAccuracyInGeneration[key].append(classwiseAccuracy[key])
    else:
      classWiseAccuracyInGeneration[key] = []
      classWiseAccuracyInGeneration[key].append(classwiseAccuracy[key])

# %%
def calculateClasswiseAccuracy(individual, data, lable, classWiseAccuracyInGeneration):
  classwiseAccuracy = dict()
  for i in range(len(data)):
    lableToPush = tuple(lable[i])
    answer = individual.predict(data[i], lable[i])
    if (answer):
      if (lableToPush in classwiseAccuracy):
        classwiseAccuracy[lableToPush] += 1
      else:
        classwiseAccuracy[lableToPush] = 1
    else:
      if (lableToPush in classwiseAccuracy):
        classwiseAccuracy[lableToPush] += 0
      else:
        classwiseAccuracy[lableToPush] = 0
  pushToGenerationAccuracyDictionary(classwiseAccuracy, classWiseAccuracyInGeneration)

# %% [markdown]
# ### Training Model

# %%
#method to run everything
def runGA(targetFile, accuracy):
  trainData,testData = getData(targetFile)
  attributes = (trainData.shape)[1] - 1
  classes = len(trainData[attributes].unique())
  print("Data contains", attributes, "and", classes, "classes")

  sample = getuniformSample(trainData, SAMPLE_SIZE, classes)
  

  X, Y = splitDataForXandY(sample)
  X_test, Y_test = splitDataForXandY(testData)

  #init Population
  populationList = list()
  populationList = createGenotype(X)

  classWiseAccuracyInGeneration = dict()

  generationAccuracy = 0
  desiredAccuracy = accuracy
  generationCount = 0
  accuracyOverGenerations = list()
  testAccuracy = list()

  while (generationAccuracy < desiredAccuracy):
    if (generationCount % CHANGE_SAMPLE_AFTER == 0):
      sample = getuniformSample(trainData, SAMPLE_SIZE, classes)
      X, Y = splitDataForXandY(sample)
      
    calculateFitness(populationList, X, Y)
    gapedPopulation = getGapedPopulation(populationList)

    mostFitIndi = gapedPopulation[0]
    calculateClasswiseAccuracy(mostFitIndi, X, Y,classWiseAccuracyInGeneration)
    
    accuracyOverGenerations.append(round(gapedPopulation[0].fitnessScore, 2))
    print("Generation ", generationCount + 1, " Accuracy = ", accuracyOverGenerations[generationCount])

    newPopulation = breed(populationList, gapedPopulation)
    populationList = newPopulation
    generationAccuracy = accuracyOverGenerations[generationCount]
    generationCount += 1

    calculateFitness([gapedPopulation[0]], X_test, Y_test)
    testAccuracy.append(round(gapedPopulation[0].fitnessScore, 2))
    
    if(len(accuracyOverGenerations) > 30):
      checkList = accuracyOverGenerations[-25:]
      result = checkList.count(checkList[0]) == len(checkList)
      if (result):
        print("Same Accuracy for last 25 generations")
        break

  
  return generationCount,accuracyOverGenerations,testAccuracy

# %%
class ModelInfo():
  def __init__(self, generationCount,accuracyOverGenerations,testAccuracy ):
        self.generationCount = generationCount
        self.trainAccuracy = accuracyOverGenerations
        self.testAccuracy = testAccuracy

# %%
datasetList = ['abalone','bank','thyroid']
accuracy = [60, 85, 90]
modelInfo = {}
a = 0
for dataset in datasetList:
  modelList = []
  print("========================================================================")
  print("Running GA for Dataset:", dataset, "desired Accuracy:", accuracy[a])
  print("========================================================================")
  for i in range(5):
    print("========================================================================")
    print("RUN -",i)
    print("========================================================================")
    generationCount,accuracyOverGenerations,testAccuracy = runGA(dataset, accuracy[a])
    plt.plot(range(len(accuracyOverGenerations)), accuracyOverGenerations)
    plt.plot(range(len(accuracyOverGenerations)), testAccuracy)
    plt.xlabel("Generations")
    plt.ylabel("Accuracy")
    plt.title("Overall Accuracy Curve") 
    plt.show()
    modelObject = ModelInfo(generationCount,accuracyOverGenerations,testAccuracy)
    modelList.append(modelObject)

  modelInfo[dataset] = modelList
  a += 1
# Out:
# ========================================================================
# Running GA for Dataset: abalone desired Accuracy: 60
# ========================================================================
# ========================================================================
# RUN - 0
# ========================================================================
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  43.5
# Generation  2  Accuracy =  43.5
# Generation  3  Accuracy =  43.5
# Generation  4  Accuracy =  43.5
# Generation  5  Accuracy =  43.5
# Generation  6  Accuracy =  44.0
# Generation  7  Accuracy =  44.0
# Generation  8  Accuracy =  44.0
# Generation  9  Accuracy =  44.0
# Generation  10  Accuracy =  44.0
# Generation  11  Accuracy =  44.0
# Generation  12  Accuracy =  44.0
# Generation  13  Accuracy =  44.0
# Generation  14  Accuracy =  44.0
# Generation  15  Accuracy =  44.0
# CREATING SAMPLE
# Generation  16  Accuracy =  46.5
# Generation  17  Accuracy =  46.5
# Generation  18  Accuracy =  46.5
# Generation  19  Accuracy =  46.5
# Generation  20  Accuracy =  46.5
# Generation  21  Accuracy =  46.5
# Generation  22  Accuracy =  46.5
# Generation  23  Accuracy =  46.5
# Generation  24  Accuracy =  46.5
# Generation  25  Accuracy =  46.5
# Generation  26  Accuracy =  46.5
# Generation  27  Accuracy =  46.5
# Generation  28  Accuracy =  46.5
# Generation  29  Accuracy =  46.5
# Generation  30  Accuracy =  46.5
# CREATING SAMPLE
# Generation  31  Accuracy =  47.5
# Generation  32  Accuracy =  47.5
# Generation  33  Accuracy =  47.5
# Generation  34  Accuracy =  47.5
# Generation  35  Accuracy =  47.5
# Generation  36  Accuracy =  47.5
# Generation  37  Accuracy =  47.5
# Generation  38  Accuracy =  47.5
# Generation  39  Accuracy =  47.5
# Generation  40  Accuracy =  47.5
# Generation  41  Accuracy =  47.5
# Generation  42  Accuracy =  47.5
# Generation  43  Accuracy =  48.5
# Generation  44  Accuracy =  56.0
# Generation  45  Accuracy =  56.0
# CREATING SAMPLE
# Generation  46  Accuracy =  48.5
# Generation  47  Accuracy =  48.5
# Generation  48  Accuracy =  48.5
# Generation  49  Accuracy =  48.5
# Generation  50  Accuracy =  49.0
# Generation  51  Accuracy =  49.0
# Generation  52  Accuracy =  49.0
# Generation  53  Accuracy =  49.0
# Generation  54  Accuracy =  49.0
# Generation  55  Accuracy =  49.5
# Generation  56  Accuracy =  49.5
# Generation  57  Accuracy =  49.5
# Generation  58  Accuracy =  49.5
# Generation  59  Accuracy =  49.5
# Generation  60  Accuracy =  49.5
# CREATING SAMPLE
# Generation  61  Accuracy =  49.5
# Generation  62  Accuracy =  49.5
# Generation  63  Accuracy =  49.5
# Generation  64  Accuracy =  49.5
# Generation  65  Accuracy =  49.5
# Generation  66  Accuracy =  49.5
# Generation  67  Accuracy =  49.5
# Generation  68  Accuracy =  49.5
# Generation  69  Accuracy =  49.5
# Generation  70  Accuracy =  49.5
# Generation  71  Accuracy =  49.5
# Generation  72  Accuracy =  49.5
# Generation  73  Accuracy =  49.5
# Generation  74  Accuracy =  49.5
# Generation  75  Accuracy =  49.5
# CREATING SAMPLE
# Generation  76  Accuracy =  54.0
# Generation  77  Accuracy =  54.0
# Generation  78  Accuracy =  54.0
# Generation  79  Accuracy =  54.0
# Generation  80  Accuracy =  54.0
# Generation  81  Accuracy =  54.0
# Generation  82  Accuracy =  54.0
# Generation  83  Accuracy =  54.0
# Generation  84  Accuracy =  54.0
# Generation  85  Accuracy =  54.0
# Generation  86  Accuracy =  54.0
# Generation  87  Accuracy =  54.0
# Generation  88  Accuracy =  54.0
# Generation  89  Accuracy =  54.0
# Generation  90  Accuracy =  54.0
# CREATING SAMPLE
# Generation  91  Accuracy =  50.5
# Generation  92  Accuracy =  50.5
# Generation  93  Accuracy =  50.5
# Generation  94  Accuracy =  50.5
# Generation  95  Accuracy =  50.5
# Generation  96  Accuracy =  50.5
# Generation  97  Accuracy =  50.5
# Generation  98  Accuracy =  50.5
# Generation  99  Accuracy =  50.5
# Generation  100  Accuracy =  50.5
# Generation  101  Accuracy =  50.5
# Generation  102  Accuracy =  50.5
# Generation  103  Accuracy =  50.5
# Generation  104  Accuracy =  50.5
# Generation  105  Accuracy =  50.5
# CREATING SAMPLE
# Generation  106  Accuracy =  49.0
# Generation  107  Accuracy =  49.0
# Generation  108  Accuracy =  49.0
# Generation  109  Accuracy =  49.0
# Generation  110  Accuracy =  49.0
# Generation  111  Accuracy =  49.0
# Generation  112  Accuracy =  49.0
# Generation  113  Accuracy =  49.0
# Generation  114  Accuracy =  49.0
# Generation  115  Accuracy =  49.0
# Generation  116  Accuracy =  49.0
# Generation  117  Accuracy =  49.0
# Generation  118  Accuracy =  49.0
# Generation  119  Accuracy =  49.0
# Generation  120  Accuracy =  49.0
# CREATING SAMPLE
# Generation  121  Accuracy =  51.0
# Generation  122  Accuracy =  51.0
# Generation  123  Accuracy =  51.0
# Generation  124  Accuracy =  51.0
# Generation  125  Accuracy =  51.0
# Generation  126  Accuracy =  51.0
# Generation  127  Accuracy =  51.0
# Generation  128  Accuracy =  51.0
# Generation  129  Accuracy =  51.0
# Generation  130  Accuracy =  51.0
# Generation  131  Accuracy =  51.0
# Generation  132  Accuracy =  51.0
# Generation  133  Accuracy =  51.0
# Generation  134  Accuracy =  51.0
# Generation  135  Accuracy =  51.0
# CREATING SAMPLE
# Generation  136  Accuracy =  57.0
# Generation  137  Accuracy =  57.0
# Generation  138  Accuracy =  57.0
# Generation  139  Accuracy =  57.0
# Generation  140  Accuracy =  57.0
# Generation  141  Accuracy =  57.0
# Generation  142  Accuracy =  57.0
# Generation  143  Accuracy =  57.0
# Generation  144  Accuracy =  57.0
# Generation  145  Accuracy =  57.0
# Generation  146  Accuracy =  57.0
# Generation  147  Accuracy =  57.0
# Generation  148  Accuracy =  57.0
# Generation  149  Accuracy =  57.0
# Generation  150  Accuracy =  57.0
# CREATING SAMPLE
# Generation  151  Accuracy =  48.0
# Generation  152  Accuracy =  48.0
# Generation  153  Accuracy =  48.0
# Generation  154  Accuracy =  48.0
# Generation  155  Accuracy =  48.0
# Generation  156  Accuracy =  48.0
# Generation  157  Accuracy =  48.0
# Generation  158  Accuracy =  48.0
# Generation  159  Accuracy =  48.0
# Generation  160  Accuracy =  48.0
# Generation  161  Accuracy =  48.0
# Generation  162  Accuracy =  48.0
# Generation  163  Accuracy =  48.0
# Generation  164  Accuracy =  48.0
# Generation  165  Accuracy =  48.0
# CREATING SAMPLE
# Generation  166  Accuracy =  55.0
# Generation  167  Accuracy =  55.0
# Generation  168  Accuracy =  55.0
# Generation  169  Accuracy =  55.0
# Generation  170  Accuracy =  55.0
# Generation  171  Accuracy =  55.0
# Generation  172  Accuracy =  55.0
# Generation  173  Accuracy =  55.0
# Generation  174  Accuracy =  55.0
# Generation  175  Accuracy =  55.0
# Generation  176  Accuracy =  55.0
# Generation  177  Accuracy =  55.0
# Generation  178  Accuracy =  55.0
# Generation  179  Accuracy =  55.0
# Generation  180  Accuracy =  55.0
# CREATING SAMPLE
# Generation  181  Accuracy =  56.0
# Generation  182  Accuracy =  56.0
# Generation  183  Accuracy =  56.0
# Generation  184  Accuracy =  56.0
# Generation  185  Accuracy =  56.0
# Generation  186  Accuracy =  56.0
# Generation  187  Accuracy =  56.0
# Generation  188  Accuracy =  56.0
# Generation  189  Accuracy =  56.0
# Generation  190  Accuracy =  56.0
# Generation  191  Accuracy =  56.0
# Generation  192  Accuracy =  56.0
# Generation  193  Accuracy =  56.0
# Generation  194  Accuracy =  56.0
# Generation  195  Accuracy =  56.0
# CREATING SAMPLE
# Generation  196  Accuracy =  48.0
# Generation  197  Accuracy =  48.0
# Generation  198  Accuracy =  48.0
# Generation  199  Accuracy =  48.0
# Generation  200  Accuracy =  48.0
# Generation  201  Accuracy =  48.0
# Generation  202  Accuracy =  48.0
# Generation  203  Accuracy =  48.0
# Generation  204  Accuracy =  48.0
# Generation  205  Accuracy =  48.0
# Generation  206  Accuracy =  48.0
# Generation  207  Accuracy =  48.0
# Generation  208  Accuracy =  48.0
# Generation  209  Accuracy =  48.0
# Generation  210  Accuracy =  48.0
# CREATING SAMPLE
# Generation  211  Accuracy =  56.5
# Generation  212  Accuracy =  56.5
# Generation  213  Accuracy =  56.5
# Generation  214  Accuracy =  56.5
# Generation  215  Accuracy =  56.5
# Generation  216  Accuracy =  56.5
# Generation  217  Accuracy =  56.5
# Generation  218  Accuracy =  56.5
# Generation  219  Accuracy =  56.5
# Generation  220  Accuracy =  56.5
# Generation  221  Accuracy =  56.5
# Generation  222  Accuracy =  56.5
# Generation  223  Accuracy =  56.5
# Generation  224  Accuracy =  56.5
# Generation  225  Accuracy =  56.5
# CREATING SAMPLE
# Generation  226  Accuracy =  50.0
# Generation  227  Accuracy =  50.0
# Generation  228  Accuracy =  50.0
# Generation  229  Accuracy =  50.0
# Generation  230  Accuracy =  50.0
# Generation  231  Accuracy =  50.0
# Generation  232  Accuracy =  50.0
# Generation  233  Accuracy =  50.0
# Generation  234  Accuracy =  50.0
# Generation  235  Accuracy =  50.0
# Generation  236  Accuracy =  50.0
# Generation  237  Accuracy =  50.0
# Generation  238  Accuracy =  50.0
# Generation  239  Accuracy =  50.0
# Generation  240  Accuracy =  50.0
# CREATING SAMPLE
# Generation  241  Accuracy =  53.5
# Generation  242  Accuracy =  53.5
# Generation  243  Accuracy =  53.5
# Generation  244  Accuracy =  53.5
# Generation  245  Accuracy =  53.5
# Generation  246  Accuracy =  53.5
# Generation  247  Accuracy =  53.5
# Generation  248  Accuracy =  53.5
# Generation  249  Accuracy =  53.5
# Generation  250  Accuracy =  53.5
# Generation  251  Accuracy =  53.5
# Generation  252  Accuracy =  53.5
# Generation  253  Accuracy =  53.5
# Generation  254  Accuracy =  53.5
# Generation  255  Accuracy =  53.5
# CREATING SAMPLE
# Generation  256  Accuracy =  57.0
# Generation  257  Accuracy =  57.0
# Generation  258  Accuracy =  57.0
# Generation  259  Accuracy =  57.0
# Generation  260  Accuracy =  57.0
# Generation  261  Accuracy =  57.0
# Generation  262  Accuracy =  57.0
# Generation  263  Accuracy =  57.0
# Generation  264  Accuracy =  57.0
# Generation  265  Accuracy =  57.0
# Generation  266  Accuracy =  57.0
# Generation  267  Accuracy =  57.0
# Generation  268  Accuracy =  57.0
# Generation  269  Accuracy =  57.0
# Generation  270  Accuracy =  57.0
# CREATING SAMPLE
# Generation  271  Accuracy =  53.5
# Generation  272  Accuracy =  53.5
# Generation  273  Accuracy =  53.5
# Generation  274  Accuracy =  53.5
# Generation  275  Accuracy =  53.5
# Generation  276  Accuracy =  53.5
# Generation  277  Accuracy =  53.5
# Generation  278  Accuracy =  53.5
# Generation  279  Accuracy =  53.5
# Generation  280  Accuracy =  53.5
# Generation  281  Accuracy =  53.5
# Generation  282  Accuracy =  53.5
# Generation  283  Accuracy =  53.5
# Generation  284  Accuracy =  53.5
# Generation  285  Accuracy =  53.5
# CREATING SAMPLE
# Generation  286  Accuracy =  54.0
# Generation  287  Accuracy =  54.0
# Generation  288  Accuracy =  54.0
# Generation  289  Accuracy =  54.0
# Generation  290  Accuracy =  54.0
# Generation  291  Accuracy =  54.0
# Generation  292  Accuracy =  54.0
# Generation  293  Accuracy =  54.0
# Generation  294  Accuracy =  54.0
# Generation  295  Accuracy =  54.0
# Generation  296  Accuracy =  54.0
# Generation  297  Accuracy =  54.0
# Generation  298  Accuracy =  54.0
# Generation  299  Accuracy =  54.0
# Generation  300  Accuracy =  54.0
# CREATING SAMPLE
# Generation  301  Accuracy =  48.0
# Generation  302  Accuracy =  48.0
# Generation  303  Accuracy =  48.0
# Generation  304  Accuracy =  48.0
# Generation  305  Accuracy =  48.0
# Generation  306  Accuracy =  48.0
# Generation  307  Accuracy =  48.0
# Generation  308  Accuracy =  48.0
# Generation  309  Accuracy =  48.0
# Generation  310  Accuracy =  48.0
# Generation  311  Accuracy =  48.0
# Generation  312  Accuracy =  48.0
# Generation  313  Accuracy =  48.0
# Generation  314  Accuracy =  48.0
# Generation  315  Accuracy =  48.0
# CREATING SAMPLE
# Generation  316  Accuracy =  48.0
# Generation  317  Accuracy =  48.0
# Generation  318  Accuracy =  48.0
# Generation  319  Accuracy =  48.0
# Generation  320  Accuracy =  48.0
# Generation  321  Accuracy =  48.0
# Generation  322  Accuracy =  48.0
# Generation  323  Accuracy =  48.0
# Generation  324  Accuracy =  48.0
# Generation  325  Accuracy =  48.0
# Same Accuracy for last 25 generations
# ========================================================================
# RUN - 1
# ========================================================================
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  51.5
# Generation  2  Accuracy =  51.5
# Generation  3  Accuracy =  51.5
# Generation  4  Accuracy =  51.5
# Generation  5  Accuracy =  51.5
# Generation  6  Accuracy =  51.5
# Generation  7  Accuracy =  51.5
# Generation  8  Accuracy =  51.5
# Generation  9  Accuracy =  51.5
# Generation  10  Accuracy =  51.5
# Generation  11  Accuracy =  51.5
# Generation  12  Accuracy =  51.5
# Generation  13  Accuracy =  51.5
# Generation  14  Accuracy =  51.5
# Generation  15  Accuracy =  52.5
# CREATING SAMPLE
# Generation  16  Accuracy =  47.5
# Generation  17  Accuracy =  47.5
# Generation  18  Accuracy =  47.5
# Generation  19  Accuracy =  47.5
# Generation  20  Accuracy =  47.5
# Generation  21  Accuracy =  47.5
# Generation  22  Accuracy =  47.5
# Generation  23  Accuracy =  47.5
# Generation  24  Accuracy =  47.5
# Generation  25  Accuracy =  48.0
# Generation  26  Accuracy =  48.5
# Generation  27  Accuracy =  48.5
# Generation  28  Accuracy =  48.5
# Generation  29  Accuracy =  48.5
# Generation  30  Accuracy =  48.5
# CREATING SAMPLE
# Generation  31  Accuracy =  50.0
# Generation  32  Accuracy =  50.0
# Generation  33  Accuracy =  50.0
# Generation  34  Accuracy =  50.0
# Generation  35  Accuracy =  50.0
# Generation  36  Accuracy =  51.5
# Generation  37  Accuracy =  51.5
# Generation  38  Accuracy =  51.5
# Generation  39  Accuracy =  51.5
# Generation  40  Accuracy =  51.5
# Generation  41  Accuracy =  51.5
# Generation  42  Accuracy =  51.5
# Generation  43  Accuracy =  51.5
# Generation  44  Accuracy =  51.5
# Generation  45  Accuracy =  51.5
# CREATING SAMPLE
# Generation  46  Accuracy =  56.5
# Generation  47  Accuracy =  56.5
# Generation  48  Accuracy =  56.5
# Generation  49  Accuracy =  56.5
# Generation  50  Accuracy =  56.5
# Generation  51  Accuracy =  56.5
# Generation  52  Accuracy =  56.5
# Generation  53  Accuracy =  56.5
# Generation  54  Accuracy =  56.5
# Generation  55  Accuracy =  56.5
# Generation  56  Accuracy =  56.5
# Generation  57  Accuracy =  56.5
# Generation  58  Accuracy =  56.5
# Generation  59  Accuracy =  56.5
# Generation  60  Accuracy =  56.5
# CREATING SAMPLE
# Generation  61  Accuracy =  52.5
# Generation  62  Accuracy =  52.5
# Generation  63  Accuracy =  52.5
# Generation  64  Accuracy =  52.5
# Generation  65  Accuracy =  52.5
# Generation  66  Accuracy =  52.5
# Generation  67  Accuracy =  52.5
# Generation  68  Accuracy =  52.5
# Generation  69  Accuracy =  52.5
# Generation  70  Accuracy =  52.5
# Generation  71  Accuracy =  52.5
# Generation  72  Accuracy =  52.5
# Generation  73  Accuracy =  52.5
# Generation  74  Accuracy =  52.5
# Generation  75  Accuracy =  52.5
# CREATING SAMPLE
# Generation  76  Accuracy =  52.5
# Generation  77  Accuracy =  52.5
# Generation  78  Accuracy =  52.5
# Generation  79  Accuracy =  56.5
# Generation  80  Accuracy =  56.5
# Generation  81  Accuracy =  56.5
# Generation  82  Accuracy =  56.5
# Generation  83  Accuracy =  56.5
# Generation  84  Accuracy =  56.5
# Generation  85  Accuracy =  56.5
# Generation  86  Accuracy =  56.5
# Generation  87  Accuracy =  56.5
# Generation  88  Accuracy =  56.5
# Generation  89  Accuracy =  56.5
# Generation  90  Accuracy =  56.5
# CREATING SAMPLE
# Generation  91  Accuracy =  56.5
# Generation  92  Accuracy =  56.5
# Generation  93  Accuracy =  56.5
# Generation  94  Accuracy =  56.5
# Generation  95  Accuracy =  56.5
# Generation  96  Accuracy =  56.5
# Generation  97  Accuracy =  56.5
# Generation  98  Accuracy =  56.5
# Generation  99  Accuracy =  56.5
# Generation  100  Accuracy =  56.5
# Generation  101  Accuracy =  56.5
# Generation  102  Accuracy =  56.5
# Generation  103  Accuracy =  56.5
# Same Accuracy for last 25 generations
# ========================================================================
# RUN - 2
# ========================================================================
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  43.0
# Generation  2  Accuracy =  43.0
# Generation  3  Accuracy =  43.0
# Generation  4  Accuracy =  43.0
# Generation  5  Accuracy =  44.0
# Generation  6  Accuracy =  44.0
# Generation  7  Accuracy =  48.5
# Generation  8  Accuracy =  48.5
# Generation  9  Accuracy =  48.5
# Generation  10  Accuracy =  48.5
# Generation  11  Accuracy =  48.5
# Generation  12  Accuracy =  48.5
# Generation  13  Accuracy =  48.5
# Generation  14  Accuracy =  48.5
# Generation  15  Accuracy =  48.5
# CREATING SAMPLE
# Generation  16  Accuracy =  50.0
# Generation  17  Accuracy =  50.0
# Generation  18  Accuracy =  50.0
# Generation  19  Accuracy =  50.0
# Generation  20  Accuracy =  50.0
# Generation  21  Accuracy =  50.5
# Generation  22  Accuracy =  50.5
# Generation  23  Accuracy =  50.5
# Generation  24  Accuracy =  50.5
# Generation  25  Accuracy =  50.5
# Generation  26  Accuracy =  50.5
# Generation  27  Accuracy =  50.5
# Generation  28  Accuracy =  50.5
# Generation  29  Accuracy =  50.5
# Generation  30  Accuracy =  55.5
# CREATING SAMPLE
# Generation  31  Accuracy =  56.0
# Generation  32  Accuracy =  56.0
# Generation  33  Accuracy =  56.0
# Generation  34  Accuracy =  56.0
# Generation  35  Accuracy =  56.0
# Generation  36  Accuracy =  56.0
# Generation  37  Accuracy =  56.0
# Generation  38  Accuracy =  56.0
# Generation  39  Accuracy =  56.0
# Generation  40  Accuracy =  56.0
# Generation  41  Accuracy =  56.0
# Generation  42  Accuracy =  56.0
# Generation  43  Accuracy =  56.0
# Generation  44  Accuracy =  56.0
# Generation  45  Accuracy =  56.0
# CREATING SAMPLE
# Generation  46  Accuracy =  55.0
# Generation  47  Accuracy =  55.0
# Generation  48  Accuracy =  55.0
# Generation  49  Accuracy =  55.0
# Generation  50  Accuracy =  55.0
# Generation  51  Accuracy =  55.0
# Generation  52  Accuracy =  55.0
# Generation  53  Accuracy =  55.0
# Generation  54  Accuracy =  55.0
# Generation  55  Accuracy =  55.0
# Generation  56  Accuracy =  55.0
# Generation  57  Accuracy =  55.0
# Generation  58  Accuracy =  55.0
# Generation  59  Accuracy =  55.0
# Generation  60  Accuracy =  55.0
# CREATING SAMPLE
# Generation  61  Accuracy =  52.5
# Generation  62  Accuracy =  52.5
# Generation  63  Accuracy =  52.5
# Generation  64  Accuracy =  52.5
# Generation  65  Accuracy =  52.5
# Generation  66  Accuracy =  52.5
# Generation  67  Accuracy =  52.5
# Generation  68  Accuracy =  53.0
# Generation  69  Accuracy =  53.0
# Generation  70  Accuracy =  53.0
# Generation  71  Accuracy =  53.0
# Generation  72  Accuracy =  53.0
# Generation  73  Accuracy =  53.0
# Generation  74  Accuracy =  53.0
# Generation  75  Accuracy =  53.0
# CREATING SAMPLE
# Generation  76  Accuracy =  50.0
# Generation  77  Accuracy =  50.0
# Generation  78  Accuracy =  50.0
# Generation  79  Accuracy =  50.0
# Generation  80  Accuracy =  50.0
# Generation  81  Accuracy =  51.5
# Generation  82  Accuracy =  51.5
# Generation  83  Accuracy =  51.5
# Generation  84  Accuracy =  51.5
# Generation  85  Accuracy =  51.5
# Generation  86  Accuracy =  51.5
# Generation  87  Accuracy =  51.5
# Generation  88  Accuracy =  51.5
# Generation  89  Accuracy =  51.5
# Generation  90  Accuracy =  51.5
# CREATING SAMPLE
# Generation  91  Accuracy =  55.0
# Generation  92  Accuracy =  55.0
# Generation  93  Accuracy =  55.0
# Generation  94  Accuracy =  55.0
# Generation  95  Accuracy =  55.0
# Generation  96  Accuracy =  55.0
# Generation  97  Accuracy =  55.0
# Generation  98  Accuracy =  55.0
# Generation  99  Accuracy =  55.0
# Generation  100  Accuracy =  55.0
# Generation  101  Accuracy =  55.0
# Generation  102  Accuracy =  55.0
# Generation  103  Accuracy =  55.0
# Generation  104  Accuracy =  55.0
# Generation  105  Accuracy =  55.0
# CREATING SAMPLE
# Generation  106  Accuracy =  59.5
# Generation  107  Accuracy =  59.5
# Generation  108  Accuracy =  59.5
# Generation  109  Accuracy =  59.5
# Generation  110  Accuracy =  61.0
# ========================================================================
# RUN - 3
# ========================================================================
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  46.0
# Generation  2  Accuracy =  46.0
# Generation  3  Accuracy =  46.0
# Generation  4  Accuracy =  46.0
# Generation  5  Accuracy =  46.0
# Generation  6  Accuracy =  46.0
# Generation  7  Accuracy =  46.0
# Generation  8  Accuracy =  46.0
# Generation  9  Accuracy =  46.0
# Generation  10  Accuracy =  46.0
# Generation  11  Accuracy =  46.0
# Generation  12  Accuracy =  46.0
# Generation  13  Accuracy =  46.0
# Generation  14  Accuracy =  46.0
# Generation  15  Accuracy =  46.0
# CREATING SAMPLE
# Generation  16  Accuracy =  51.5
# Generation  17  Accuracy =  51.5
# Generation  18  Accuracy =  51.5
# Generation  19  Accuracy =  51.5
# Generation  20  Accuracy =  55.5
# Generation  21  Accuracy =  55.5
# Generation  22  Accuracy =  55.5
# Generation  23  Accuracy =  55.5
# Generation  24  Accuracy =  55.5
# Generation  25  Accuracy =  55.5
# Generation  26  Accuracy =  55.5
# Generation  27  Accuracy =  55.5
# Generation  28  Accuracy =  55.5
# Generation  29  Accuracy =  55.5
# Generation  30  Accuracy =  55.5
# CREATING SAMPLE
# Generation  31  Accuracy =  48.0
# Generation  32  Accuracy =  48.0
# Generation  33  Accuracy =  48.0
# Generation  34  Accuracy =  48.0
# Generation  35  Accuracy =  48.0
# Generation  36  Accuracy =  48.0
# Generation  37  Accuracy =  48.0
# Generation  38  Accuracy =  48.0
# Generation  39  Accuracy =  48.0
# Generation  40  Accuracy =  48.0
# Generation  41  Accuracy =  48.0
# Generation  42  Accuracy =  48.0
# Generation  43  Accuracy =  48.0
# Generation  44  Accuracy =  48.0
# Generation  45  Accuracy =  48.0
# CREATING SAMPLE
# Generation  46  Accuracy =  53.0
# Generation  47  Accuracy =  53.0
# Generation  48  Accuracy =  53.0
# Generation  49  Accuracy =  53.0
# Generation  50  Accuracy =  53.0
# Generation  51  Accuracy =  53.0
# Generation  52  Accuracy =  53.0
# Generation  53  Accuracy =  53.0
# Generation  54  Accuracy =  53.0
# Generation  55  Accuracy =  53.0
# Generation  56  Accuracy =  53.0
# Generation  57  Accuracy =  53.0
# Generation  58  Accuracy =  53.0
# Generation  59  Accuracy =  53.0
# Generation  60  Accuracy =  53.0
# CREATING SAMPLE
# Generation  61  Accuracy =  51.0
# Generation  62  Accuracy =  51.0
# Generation  63  Accuracy =  51.0
# Generation  64  Accuracy =  51.0
# Generation  65  Accuracy =  51.0
# Generation  66  Accuracy =  51.0
# Generation  67  Accuracy =  51.0
# Generation  68  Accuracy =  51.0
# Generation  69  Accuracy =  51.0
# Generation  70  Accuracy =  51.0
# Generation  71  Accuracy =  51.0
# Generation  72  Accuracy =  51.0
# Generation  73  Accuracy =  51.0
# Generation  74  Accuracy =  51.0
# Generation  75  Accuracy =  51.0
# CREATING SAMPLE
# Generation  76  Accuracy =  46.5
# Generation  77  Accuracy =  46.5
# Generation  78  Accuracy =  46.5
# Generation  79  Accuracy =  46.5
# Generation  80  Accuracy =  46.5
# Generation  81  Accuracy =  46.5
# Generation  82  Accuracy =  46.5
# Generation  83  Accuracy =  46.5
# Generation  84  Accuracy =  46.5
# Generation  85  Accuracy =  46.5
# Generation  86  Accuracy =  46.5
# Generation  87  Accuracy =  46.5
# Generation  88  Accuracy =  46.5
# Generation  89  Accuracy =  46.5
# Generation  90  Accuracy =  46.5
# CREATING SAMPLE
# Generation  91  Accuracy =  50.0
# Generation  92  Accuracy =  50.0
# Generation  93  Accuracy =  50.0
# Generation  94  Accuracy =  50.0
# Generation  95  Accuracy =  50.0
# Generation  96  Accuracy =  50.0
# Generation  97  Accuracy =  50.0
# Generation  98  Accuracy =  50.0
# Generation  99  Accuracy =  50.0
# Generation  100  Accuracy =  50.0
# Generation  101  Accuracy =  50.0
# Generation  102  Accuracy =  50.0
# Generation  103  Accuracy =  50.0
# Generation  104  Accuracy =  50.0
# Generation  105  Accuracy =  50.0
# CREATING SAMPLE
# Generation  106  Accuracy =  56.0
# Generation  107  Accuracy =  56.0
# Generation  108  Accuracy =  56.0
# Generation  109  Accuracy =  56.0
# Generation  110  Accuracy =  56.0
# Generation  111  Accuracy =  56.0
# Generation  112  Accuracy =  56.0
# Generation  113  Accuracy =  56.0
# Generation  114  Accuracy =  56.0
# Generation  115  Accuracy =  56.0
# Generation  116  Accuracy =  56.0
# Generation  117  Accuracy =  56.0
# Generation  118  Accuracy =  56.0
# Generation  119  Accuracy =  56.0
# Generation  120  Accuracy =  56.0
# CREATING SAMPLE
# Generation  121  Accuracy =  52.5
# Generation  122  Accuracy =  52.5
# Generation  123  Accuracy =  52.5
# Generation  124  Accuracy =  52.5
# Generation  125  Accuracy =  52.5
# Generation  126  Accuracy =  52.5
# Generation  127  Accuracy =  52.5
# Generation  128  Accuracy =  52.5
# Generation  129  Accuracy =  52.5
# Generation  130  Accuracy =  52.5
# Generation  131  Accuracy =  52.5
# Generation  132  Accuracy =  52.5
# Generation  133  Accuracy =  52.5
# Generation  134  Accuracy =  52.5
# Generation  135  Accuracy =  52.5
# CREATING SAMPLE
# Generation  136  Accuracy =  54.0
# Generation  137  Accuracy =  54.0
# Generation  138  Accuracy =  54.0
# Generation  139  Accuracy =  54.0
# Generation  140  Accuracy =  54.0
# Generation  141  Accuracy =  54.0
# Generation  142  Accuracy =  54.0
# Generation  143  Accuracy =  54.0
# Generation  144  Accuracy =  54.0
# Generation  145  Accuracy =  54.0
# Generation  146  Accuracy =  54.0
# Generation  147  Accuracy =  54.0
# Generation  148  Accuracy =  54.0
# Generation  149  Accuracy =  54.0
# Generation  150  Accuracy =  54.0
# CREATING SAMPLE
# Generation  151  Accuracy =  55.5
# Generation  152  Accuracy =  55.5
# Generation  153  Accuracy =  55.5
# Generation  154  Accuracy =  55.5
# Generation  155  Accuracy =  55.5
# Generation  156  Accuracy =  55.5
# Generation  157  Accuracy =  55.5
# Generation  158  Accuracy =  55.5
# Generation  159  Accuracy =  55.5
# Generation  160  Accuracy =  55.5
# Generation  161  Accuracy =  55.5
# Generation  162  Accuracy =  55.5
# Generation  163  Accuracy =  55.5
# Generation  164  Accuracy =  55.5
# Generation  165  Accuracy =  55.5
# CREATING SAMPLE
# Generation  166  Accuracy =  51.5
# Generation  167  Accuracy =  51.5
# Generation  168  Accuracy =  51.5
# Generation  169  Accuracy =  51.5
# Generation  170  Accuracy =  51.5
# Generation  171  Accuracy =  51.5
# Generation  172  Accuracy =  51.5
# Generation  173  Accuracy =  51.5
# Generation  174  Accuracy =  51.5
# Generation  175  Accuracy =  51.5
# Generation  176  Accuracy =  51.5
# Generation  177  Accuracy =  51.5
# Generation  178  Accuracy =  51.5
# Generation  179  Accuracy =  51.5
# Generation  180  Accuracy =  51.5
# CREATING SAMPLE
# Generation  181  Accuracy =  51.5
# Generation  182  Accuracy =  51.5
# Generation  183  Accuracy =  51.5
# Generation  184  Accuracy =  53.5
# Generation  185  Accuracy =  53.5
# Generation  186  Accuracy =  53.5
# Generation  187  Accuracy =  53.5
# Generation  188  Accuracy =  53.5
# Generation  189  Accuracy =  53.5
# Generation  190  Accuracy =  53.5
# Generation  191  Accuracy =  53.5
# Generation  192  Accuracy =  53.5
# Generation  193  Accuracy =  53.5
# Generation  194  Accuracy =  53.5
# Generation  195  Accuracy =  53.5
# CREATING SAMPLE
# Generation  196  Accuracy =  45.5
# Generation  197  Accuracy =  45.5
# Generation  198  Accuracy =  45.5
# Generation  199  Accuracy =  45.5
# Generation  200  Accuracy =  45.5
# Generation  201  Accuracy =  45.5
# Generation  202  Accuracy =  45.5
# Generation  203  Accuracy =  45.5
# Generation  204  Accuracy =  45.5
# Generation  205  Accuracy =  46.0
# Generation  206  Accuracy =  46.0
# Generation  207  Accuracy =  46.0
# Generation  208  Accuracy =  46.0
# Generation  209  Accuracy =  46.0
# Generation  210  Accuracy =  46.0
# CREATING SAMPLE
# Generation  211  Accuracy =  56.5
# Generation  212  Accuracy =  56.5
# Generation  213  Accuracy =  56.5
# Generation  214  Accuracy =  56.5
# Generation  215  Accuracy =  56.5
# Generation  216  Accuracy =  56.5
# Generation  217  Accuracy =  56.5
# Generation  218  Accuracy =  56.5
# Generation  219  Accuracy =  56.5
# Generation  220  Accuracy =  56.5
# Generation  221  Accuracy =  56.5
# Generation  222  Accuracy =  56.5
# Generation  223  Accuracy =  56.5
# Generation  224  Accuracy =  56.5
# Generation  225  Accuracy =  56.5
# CREATING SAMPLE
# Generation  226  Accuracy =  53.5
# Generation  227  Accuracy =  53.5
# Generation  228  Accuracy =  53.5
# Generation  229  Accuracy =  53.5
# Generation  230  Accuracy =  53.5
# Generation  231  Accuracy =  53.5
# Generation  232  Accuracy =  53.5
# Generation  233  Accuracy =  53.5
# Generation  234  Accuracy =  53.5
# Generation  235  Accuracy =  53.5
# Generation  236  Accuracy =  53.5
# Generation  237  Accuracy =  53.5
# Generation  238  Accuracy =  53.5
# Generation  239  Accuracy =  53.5
# Generation  240  Accuracy =  53.5
# CREATING SAMPLE
# Generation  241  Accuracy =  53.0
# Generation  242  Accuracy =  53.0
# Generation  243  Accuracy =  53.0
# Generation  244  Accuracy =  53.0
# Generation  245  Accuracy =  53.0
# Generation  246  Accuracy =  53.0
# Generation  247  Accuracy =  53.0
# Generation  248  Accuracy =  53.0
# Generation  249  Accuracy =  53.0
# Generation  250  Accuracy =  53.0
# Generation  251  Accuracy =  53.0
# Generation  252  Accuracy =  53.0
# Generation  253  Accuracy =  53.0
# Generation  254  Accuracy =  53.0
# Generation  255  Accuracy =  53.0
# CREATING SAMPLE
# Generation  256  Accuracy =  53.5
# Generation  257  Accuracy =  53.5
# Generation  258  Accuracy =  53.5
# Generation  259  Accuracy =  53.5
# Generation  260  Accuracy =  53.5
# Generation  261  Accuracy =  53.5
# Generation  262  Accuracy =  53.5
# Generation  263  Accuracy =  53.5
# Generation  264  Accuracy =  53.5
# Generation  265  Accuracy =  53.5
# Generation  266  Accuracy =  53.5
# Generation  267  Accuracy =  53.5
# Generation  268  Accuracy =  53.5
# Generation  269  Accuracy =  53.5
# Generation  270  Accuracy =  53.5
# CREATING SAMPLE
# Generation  271  Accuracy =  50.5
# Generation  272  Accuracy =  50.5
# Generation  273  Accuracy =  50.5
# Generation  274  Accuracy =  50.5
# Generation  275  Accuracy =  50.5
# Generation  276  Accuracy =  50.5
# Generation  277  Accuracy =  50.5
# Generation  278  Accuracy =  50.5
# Generation  279  Accuracy =  50.5
# Generation  280  Accuracy =  50.5
# Generation  281  Accuracy =  50.5
# Generation  282  Accuracy =  51.5
# Generation  283  Accuracy =  51.5
# Generation  284  Accuracy =  51.5
# Generation  285  Accuracy =  51.5
# CREATING SAMPLE
# Generation  286  Accuracy =  50.0
# Generation  287  Accuracy =  50.0
# Generation  288  Accuracy =  50.0
# Generation  289  Accuracy =  50.0
# Generation  290  Accuracy =  50.0
# Generation  291  Accuracy =  54.0
# Generation  292  Accuracy =  54.0
# Generation  293  Accuracy =  54.0
# Generation  294  Accuracy =  54.0
# Generation  295  Accuracy =  54.0
# Generation  296  Accuracy =  54.0
# Generation  297  Accuracy =  54.0
# Generation  298  Accuracy =  54.0
# Generation  299  Accuracy =  54.0
# Generation  300  Accuracy =  54.0
# CREATING SAMPLE
# Generation  301  Accuracy =  55.0
# Generation  302  Accuracy =  55.0
# Generation  303  Accuracy =  55.0
# Generation  304  Accuracy =  55.0
# Generation  305  Accuracy =  55.0
# Generation  306  Accuracy =  55.0
# Generation  307  Accuracy =  56.5
# Generation  308  Accuracy =  56.5
# Generation  309  Accuracy =  56.5
# Generation  310  Accuracy =  56.5
# Generation  311  Accuracy =  56.5
# Generation  312  Accuracy =  56.5
# Generation  313  Accuracy =  56.5
# Generation  314  Accuracy =  56.5
# Generation  315  Accuracy =  56.5
# CREATING SAMPLE
# Generation  316  Accuracy =  45.0
# Generation  317  Accuracy =  45.0
# Generation  318  Accuracy =  45.0
# Generation  319  Accuracy =  46.0
# Generation  320  Accuracy =  46.0
# Generation  321  Accuracy =  46.0
# Generation  322  Accuracy =  46.0
# Generation  323  Accuracy =  46.0
# Generation  324  Accuracy =  47.0
# Generation  325  Accuracy =  47.0
# Generation  326  Accuracy =  47.0
# Generation  327  Accuracy =  47.0
# Generation  328  Accuracy =  47.0
# Generation  329  Accuracy =  47.0
# Generation  330  Accuracy =  47.0
# CREATING SAMPLE
# Generation  331  Accuracy =  54.5
# Generation  332  Accuracy =  54.5
# Generation  333  Accuracy =  54.5
# Generation  334  Accuracy =  54.5
# Generation  335  Accuracy =  54.5
# Generation  336  Accuracy =  54.5
# Generation  337  Accuracy =  54.5
# Generation  338  Accuracy =  54.5
# Generation  339  Accuracy =  54.5
# Generation  340  Accuracy =  54.5
# Generation  341  Accuracy =  54.5
# Generation  342  Accuracy =  54.5
# Generation  343  Accuracy =  54.5
# Generation  344  Accuracy =  54.5
# Generation  345  Accuracy =  54.5
# CREATING SAMPLE
# Generation  346  Accuracy =  49.0
# Generation  347  Accuracy =  49.0
# Generation  348  Accuracy =  49.0
# Generation  349  Accuracy =  49.0
# Generation  350  Accuracy =  49.0
# Generation  351  Accuracy =  49.0
# Generation  352  Accuracy =  49.0
# Generation  353  Accuracy =  49.0
# Generation  354  Accuracy =  49.0
# Generation  355  Accuracy =  49.0
# Generation  356  Accuracy =  49.0
# Generation  357  Accuracy =  49.0
# Generation  358  Accuracy =  49.0
# Generation  359  Accuracy =  49.0
# Generation  360  Accuracy =  49.0
# CREATING SAMPLE
# Generation  361  Accuracy =  57.5
# Generation  362  Accuracy =  57.5
# Generation  363  Accuracy =  57.5
# Generation  364  Accuracy =  57.5
# Generation  365  Accuracy =  57.5
# Generation  366  Accuracy =  57.5
# Generation  367  Accuracy =  57.5
# Generation  368  Accuracy =  57.5
# Generation  369  Accuracy =  57.5
# Generation  370  Accuracy =  57.5
# Generation  371  Accuracy =  57.5
# Generation  372  Accuracy =  57.5
# Generation  373  Accuracy =  57.5
# Generation  374  Accuracy =  57.5
# Generation  375  Accuracy =  57.5
# CREATING SAMPLE
# Generation  376  Accuracy =  59.0
# Generation  377  Accuracy =  59.0
# Generation  378  Accuracy =  59.0
# Generation  379  Accuracy =  59.0
# Generation  380  Accuracy =  59.0
# Generation  381  Accuracy =  59.0
# Generation  382  Accuracy =  59.0
# Generation  383  Accuracy =  59.0
# Generation  384  Accuracy =  59.0
# Generation  385  Accuracy =  59.0
# Generation  386  Accuracy =  59.0
# Generation  387  Accuracy =  59.0
# Generation  388  Accuracy =  59.0
# Generation  389  Accuracy =  59.0
# Generation  390  Accuracy =  59.0
# CREATING SAMPLE
# Generation  391  Accuracy =  56.0
# Generation  392  Accuracy =  56.0
# Generation  393  Accuracy =  56.0
# Generation  394  Accuracy =  56.0
# Generation  395  Accuracy =  56.0
# Generation  396  Accuracy =  59.0
# Generation  397  Accuracy =  59.0
# Generation  398  Accuracy =  59.0
# Generation  399  Accuracy =  59.0
# Generation  400  Accuracy =  59.0
# Generation  401  Accuracy =  59.0
# Generation  402  Accuracy =  59.0
# Generation  403  Accuracy =  59.0
# Generation  404  Accuracy =  59.0
# Generation  405  Accuracy =  59.0
# CREATING SAMPLE
# Generation  406  Accuracy =  54.5
# Generation  407  Accuracy =  54.5
# Generation  408  Accuracy =  54.5
# Generation  409  Accuracy =  54.5
# Generation  410  Accuracy =  54.5
# Generation  411  Accuracy =  54.5
# Generation  412  Accuracy =  54.5
# Generation  413  Accuracy =  54.5
# Generation  414  Accuracy =  54.5
# Generation  415  Accuracy =  54.5
# Generation  416  Accuracy =  54.5
# Generation  417  Accuracy =  54.5
# Generation  418  Accuracy =  54.5
# Generation  419  Accuracy =  54.5
# Generation  420  Accuracy =  54.5
# CREATING SAMPLE
# Generation  421  Accuracy =  56.5
# Generation  422  Accuracy =  56.5
# Generation  423  Accuracy =  56.5
# Generation  424  Accuracy =  56.5
# Generation  425  Accuracy =  56.5
# Generation  426  Accuracy =  56.5
# Generation  427  Accuracy =  56.5
# Generation  428  Accuracy =  57.5
# Generation  429  Accuracy =  60.5
# ========================================================================
# RUN - 4
# ========================================================================
# Data contains 8 and 4 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  43.5
# Generation  2  Accuracy =  43.5
# Generation  3  Accuracy =  43.5
# Generation  4  Accuracy =  43.5
# Generation  5  Accuracy =  43.5
# Generation  6  Accuracy =  43.5
# Generation  7  Accuracy =  43.5
# Generation  8  Accuracy =  43.5
# Generation  9  Accuracy =  43.5
# Generation  10  Accuracy =  45.5
# Generation  11  Accuracy =  45.5
# Generation  12  Accuracy =  45.5
# Generation  13  Accuracy =  45.5
# Generation  14  Accuracy =  46.0
# Generation  15  Accuracy =  46.0
# CREATING SAMPLE
# Generation  16  Accuracy =  50.0
# Generation  17  Accuracy =  50.0
# Generation  18  Accuracy =  50.0
# Generation  19  Accuracy =  50.0
# Generation  20  Accuracy =  50.0
# Generation  21  Accuracy =  50.0
# Generation  22  Accuracy =  50.0
# Generation  23  Accuracy =  50.0
# Generation  24  Accuracy =  50.0
# Generation  25  Accuracy =  50.0
# Generation  26  Accuracy =  50.0
# Generation  27  Accuracy =  50.0
# Generation  28  Accuracy =  50.0
# Generation  29  Accuracy =  50.0
# Generation  30  Accuracy =  50.0
# CREATING SAMPLE
# Generation  31  Accuracy =  50.0
# Generation  32  Accuracy =  50.0
# Generation  33  Accuracy =  50.0
# Generation  34  Accuracy =  50.0
# Generation  35  Accuracy =  50.0
# Generation  36  Accuracy =  50.0
# Generation  37  Accuracy =  50.0
# Generation  38  Accuracy =  50.0
# Generation  39  Accuracy =  50.0
# Generation  40  Accuracy =  50.0
# Same Accuracy for last 25 generations
# ========================================================================
# Running GA for Dataset: bank desired Accuracy: 85
# ========================================================================
# ========================================================================
# RUN - 0
# ========================================================================
# Data contains 16 and 2 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  69.0
# Generation  2  Accuracy =  72.5
# Generation  3  Accuracy =  72.5
# Generation  4  Accuracy =  72.5
# Generation  5  Accuracy =  72.5
# Generation  6  Accuracy =  72.5
# Generation  7  Accuracy =  72.5
# Generation  8  Accuracy =  73.0
# Generation  9  Accuracy =  73.0
# Generation  10  Accuracy =  73.0
# Generation  11  Accuracy =  73.0
# Generation  12  Accuracy =  73.0
# Generation  13  Accuracy =  73.0
# Generation  14  Accuracy =  73.0
# Generation  15  Accuracy =  73.0
# CREATING SAMPLE
# Generation  16  Accuracy =  74.5
# Generation  17  Accuracy =  74.5
# Generation  18  Accuracy =  74.5
# Generation  19  Accuracy =  74.5
# Generation  20  Accuracy =  74.5
# Generation  21  Accuracy =  74.5
# Generation  22  Accuracy =  75.0
# Generation  23  Accuracy =  75.0
# Generation  24  Accuracy =  75.0
# Generation  25  Accuracy =  75.0
# Generation  26  Accuracy =  75.0
# Generation  27  Accuracy =  75.5
# Generation  28  Accuracy =  75.5
# Generation  29  Accuracy =  75.5
# Generation  30  Accuracy =  75.5
# CREATING SAMPLE
# Generation  31  Accuracy =  74.0
# Generation  32  Accuracy =  74.0
# Generation  33  Accuracy =  74.0
# Generation  34  Accuracy =  74.0
# Generation  35  Accuracy =  74.0
# Generation  36  Accuracy =  74.0
# Generation  37  Accuracy =  74.0
# Generation  38  Accuracy =  74.0
# Generation  39  Accuracy =  74.0
# Generation  40  Accuracy =  74.0
# Generation  41  Accuracy =  74.0
# Generation  42  Accuracy =  74.0
# Generation  43  Accuracy =  74.0
# Generation  44  Accuracy =  74.0
# Generation  45  Accuracy =  74.0
# CREATING SAMPLE
# Generation  46  Accuracy =  77.0
# Generation  47  Accuracy =  77.0
# Generation  48  Accuracy =  77.0
# Generation  49  Accuracy =  77.0
# Generation  50  Accuracy =  77.0
# Generation  51  Accuracy =  77.0
# Generation  52  Accuracy =  77.0
# Generation  53  Accuracy =  77.0
# Generation  54  Accuracy =  77.0
# Generation  55  Accuracy =  77.0
# Generation  56  Accuracy =  77.0
# Generation  57  Accuracy =  77.0
# Generation  58  Accuracy =  77.0
# Generation  59  Accuracy =  77.0
# Generation  60  Accuracy =  77.0
# CREATING SAMPLE
# Generation  61  Accuracy =  78.0
# Generation  62  Accuracy =  78.0
# Generation  63  Accuracy =  78.0
# Generation  64  Accuracy =  78.0
# Generation  65  Accuracy =  78.0
# Generation  66  Accuracy =  78.0
# Generation  67  Accuracy =  78.0
# Generation  68  Accuracy =  78.0
# Generation  69  Accuracy =  78.0
# Generation  70  Accuracy =  78.0
# Generation  71  Accuracy =  78.0
# Generation  72  Accuracy =  78.0
# Generation  73  Accuracy =  78.0
# Generation  74  Accuracy =  78.0
# Generation  75  Accuracy =  78.0
# CREATING SAMPLE
# Generation  76  Accuracy =  78.0
# Generation  77  Accuracy =  78.0
# Generation  78  Accuracy =  78.0
# Generation  79  Accuracy =  78.0
# Generation  80  Accuracy =  78.0
# Generation  81  Accuracy =  78.0
# Generation  82  Accuracy =  78.0
# Generation  83  Accuracy =  78.0
# Generation  84  Accuracy =  78.0
# Generation  85  Accuracy =  78.0
# Same Accuracy for last 25 generations
# ========================================================================
# RUN - 1
# ========================================================================
# Data contains 16 and 2 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  69.0
# Generation  2  Accuracy =  69.0
# Generation  3  Accuracy =  69.0
# Generation  4  Accuracy =  69.0
# Generation  5  Accuracy =  69.0
# Generation  6  Accuracy =  69.0
# Generation  7  Accuracy =  69.0
# Generation  8  Accuracy =  69.0
# Generation  9  Accuracy =  69.0
# Generation  10  Accuracy =  69.0
# Generation  11  Accuracy =  69.0
# Generation  12  Accuracy =  69.0
# Generation  13  Accuracy =  69.0
# Generation  14  Accuracy =  69.0
# Generation  15  Accuracy =  69.0
# CREATING SAMPLE
# Generation  16  Accuracy =  71.5
# Generation  17  Accuracy =  71.5
# Generation  18  Accuracy =  73.0
# Generation  19  Accuracy =  73.0
# Generation  20  Accuracy =  73.0
# Generation  21  Accuracy =  73.5
# Generation  22  Accuracy =  75.0
# Generation  23  Accuracy =  75.0
# Generation  24  Accuracy =  75.0
# Generation  25  Accuracy =  75.0
# Generation  26  Accuracy =  75.0
# Generation  27  Accuracy =  75.0
# Generation  28  Accuracy =  75.0
# Generation  29  Accuracy =  75.0
# Generation  30  Accuracy =  75.0
# CREATING SAMPLE
# Generation  31  Accuracy =  77.5
# Generation  32  Accuracy =  77.5
# Generation  33  Accuracy =  78.5
# Generation  34  Accuracy =  78.5
# Generation  35  Accuracy =  78.5
# Generation  36  Accuracy =  78.5
# Generation  37  Accuracy =  78.5
# Generation  38  Accuracy =  78.5
# Generation  39  Accuracy =  78.5
# Generation  40  Accuracy =  78.5
# Generation  41  Accuracy =  78.5
# Generation  42  Accuracy =  78.5
# Generation  43  Accuracy =  78.5
# Generation  44  Accuracy =  78.5
# Generation  45  Accuracy =  78.5
# CREATING SAMPLE
# Generation  46  Accuracy =  77.0
# Generation  47  Accuracy =  77.0
# Generation  48  Accuracy =  77.0
# Generation  49  Accuracy =  77.0
# Generation  50  Accuracy =  77.0
# Generation  51  Accuracy =  77.0
# Generation  52  Accuracy =  77.0
# Generation  53  Accuracy =  77.0
# Generation  54  Accuracy =  77.0
# Generation  55  Accuracy =  77.0
# Generation  56  Accuracy =  77.0
# Generation  57  Accuracy =  77.0
# Generation  58  Accuracy =  77.0
# Generation  59  Accuracy =  77.0
# Generation  60  Accuracy =  77.0
# CREATING SAMPLE
# Generation  61  Accuracy =  78.0
# Generation  62  Accuracy =  78.0
# Generation  63  Accuracy =  78.0
# Generation  64  Accuracy =  78.0
# Generation  65  Accuracy =  78.0
# Generation  66  Accuracy =  78.0
# Generation  67  Accuracy =  78.0
# Generation  68  Accuracy =  78.0
# Generation  69  Accuracy =  78.0
# Generation  70  Accuracy =  78.0
# Generation  71  Accuracy =  78.0
# Generation  72  Accuracy =  78.0
# Generation  73  Accuracy =  78.0
# Generation  74  Accuracy =  78.0
# Generation  75  Accuracy =  78.0
# CREATING SAMPLE
# Generation  76  Accuracy =  73.5
# Generation  77  Accuracy =  73.5
# Generation  78  Accuracy =  73.5
# Generation  79  Accuracy =  73.5
# Generation  80  Accuracy =  73.5
# Generation  81  Accuracy =  73.5
# Generation  82  Accuracy =  73.5
# Generation  83  Accuracy =  73.5
# Generation  84  Accuracy =  73.5
# Generation  85  Accuracy =  73.5
# Generation  86  Accuracy =  73.5
# Generation  87  Accuracy =  73.5
# Generation  88  Accuracy =  73.5
# Generation  89  Accuracy =  73.5
# Generation  90  Accuracy =  73.5
# CREATING SAMPLE
# Generation  91  Accuracy =  70.5
# Generation  92  Accuracy =  70.5
# Generation  93  Accuracy =  70.5
# Generation  94  Accuracy =  70.5
# Generation  95  Accuracy =  70.5
# Generation  96  Accuracy =  70.5
# Generation  97  Accuracy =  70.5
# Generation  98  Accuracy =  70.5
# Generation  99  Accuracy =  70.5
# Generation  100  Accuracy =  70.5
# Generation  101  Accuracy =  70.5
# Generation  102  Accuracy =  70.5
# Generation  103  Accuracy =  70.5
# Generation  104  Accuracy =  70.5
# Generation  105  Accuracy =  70.5
# CREATING SAMPLE
# Generation  106  Accuracy =  78.0
# Generation  107  Accuracy =  78.0
# Generation  108  Accuracy =  78.0
# Generation  109  Accuracy =  78.0
# Generation  110  Accuracy =  78.0
# Generation  111  Accuracy =  78.0
# Generation  112  Accuracy =  78.0
# Generation  113  Accuracy =  78.0
# Generation  114  Accuracy =  78.0
# Generation  115  Accuracy =  78.0
# Generation  116  Accuracy =  78.0
# Generation  117  Accuracy =  78.0
# Generation  118  Accuracy =  78.5
# Generation  119  Accuracy =  78.5
# Generation  120  Accuracy =  78.5
# CREATING SAMPLE
# Generation  121  Accuracy =  77.5
# Generation  122  Accuracy =  77.5
# Generation  123  Accuracy =  77.5
# Generation  124  Accuracy =  77.5
# Generation  125  Accuracy =  77.5
# Generation  126  Accuracy =  77.5
# Generation  127  Accuracy =  77.5
# Generation  128  Accuracy =  77.5
# Generation  129  Accuracy =  77.5
# Generation  130  Accuracy =  77.5
# Generation  131  Accuracy =  77.5
# Generation  132  Accuracy =  77.5
# Generation  133  Accuracy =  77.5
# Generation  134  Accuracy =  77.5
# Generation  135  Accuracy =  77.5
# CREATING SAMPLE
# Generation  136  Accuracy =  76.0
# Generation  137  Accuracy =  76.0
# Generation  138  Accuracy =  76.0
# Generation  139  Accuracy =  76.0
# Generation  140  Accuracy =  76.0
# Generation  141  Accuracy =  76.0
# Generation  142  Accuracy =  76.0
# Generation  143  Accuracy =  76.0
# Generation  144  Accuracy =  76.0
# Generation  145  Accuracy =  76.0
# Generation  146  Accuracy =  76.0
# Generation  147  Accuracy =  76.0
# Generation  148  Accuracy =  76.0
# Generation  149  Accuracy =  76.0
# Generation  150  Accuracy =  76.0
# CREATING SAMPLE
# Generation  151  Accuracy =  75.0
# Generation  152  Accuracy =  75.0
# Generation  153  Accuracy =  75.0
# Generation  154  Accuracy =  75.0
# Generation  155  Accuracy =  75.0
# Generation  156  Accuracy =  75.0
# Generation  157  Accuracy =  75.0
# Generation  158  Accuracy =  75.0
# Generation  159  Accuracy =  75.0
# Generation  160  Accuracy =  75.0
# Generation  161  Accuracy =  75.0
# Generation  162  Accuracy =  75.0
# Generation  163  Accuracy =  75.0
# Generation  164  Accuracy =  75.0
# Generation  165  Accuracy =  75.0
# CREATING SAMPLE
# Generation  166  Accuracy =  78.0
# Generation  167  Accuracy =  78.0
# Generation  168  Accuracy =  78.0
# Generation  169  Accuracy =  78.0
# Generation  170  Accuracy =  78.0
# Generation  171  Accuracy =  78.0
# Generation  172  Accuracy =  78.0
# Generation  173  Accuracy =  78.0
# Generation  174  Accuracy =  78.0
# Generation  175  Accuracy =  78.0
# Generation  176  Accuracy =  78.0
# Generation  177  Accuracy =  78.0
# Generation  178  Accuracy =  78.0
# Generation  179  Accuracy =  78.0
# Generation  180  Accuracy =  78.0
# CREATING SAMPLE
# Generation  181  Accuracy =  74.5
# Generation  182  Accuracy =  74.5
# Generation  183  Accuracy =  74.5
# Generation  184  Accuracy =  74.5
# Generation  185  Accuracy =  74.5
# Generation  186  Accuracy =  74.5
# Generation  187  Accuracy =  74.5
# Generation  188  Accuracy =  74.5
# Generation  189  Accuracy =  74.5
# Generation  190  Accuracy =  74.5
# Generation  191  Accuracy =  74.5
# Generation  192  Accuracy =  74.5
# Generation  193  Accuracy =  74.5
# Generation  194  Accuracy =  74.5
# Generation  195  Accuracy =  74.5
# CREATING SAMPLE
# Generation  196  Accuracy =  72.0
# Generation  197  Accuracy =  72.0
# Generation  198  Accuracy =  72.0
# Generation  199  Accuracy =  72.0
# Generation  200  Accuracy =  72.5
# Generation  201  Accuracy =  72.5
# Generation  202  Accuracy =  72.5
# Generation  203  Accuracy =  72.5
# Generation  204  Accuracy =  72.5
# Generation  205  Accuracy =  72.5
# Generation  206  Accuracy =  72.5
# Generation  207  Accuracy =  72.5
# Generation  208  Accuracy =  72.5
# Generation  209  Accuracy =  72.5
# Generation  210  Accuracy =  72.5
# CREATING SAMPLE
# Generation  211  Accuracy =  76.5
# Generation  212  Accuracy =  76.5
# Generation  213  Accuracy =  76.5
# Generation  214  Accuracy =  76.5
# Generation  215  Accuracy =  76.5
# Generation  216  Accuracy =  76.5
# Generation  217  Accuracy =  76.5
# Generation  218  Accuracy =  76.5
# Generation  219  Accuracy =  76.5
# Generation  220  Accuracy =  76.5
# Generation  221  Accuracy =  76.5
# Generation  222  Accuracy =  76.5
# Generation  223  Accuracy =  76.5
# Generation  224  Accuracy =  76.5
# Generation  225  Accuracy =  76.5
# CREATING SAMPLE
# Generation  226  Accuracy =  79.0
# Generation  227  Accuracy =  79.0
# Generation  228  Accuracy =  79.0
# Generation  229  Accuracy =  79.0
# Generation  230  Accuracy =  79.0
# Generation  231  Accuracy =  79.0
# Generation  232  Accuracy =  79.0
# Generation  233  Accuracy =  79.0
# Generation  234  Accuracy =  79.0
# ...
# Generation  176  Accuracy =  88.5
# Generation  177  Accuracy =  89.5
# Generation  178  Accuracy =  89.5
# Generation  179  Accuracy =  89.5
# Generation  180  Accuracy =  89.5
# CREATING SAMPLE
# Generation  181  Accuracy =  88.5
# Generation  182  Accuracy =  88.5
# Generation  183  Accuracy =  88.5
# Generation  184  Accuracy =  89.0
# Generation  185  Accuracy =  89.0
# Generation  186  Accuracy =  89.0
# Generation  187  Accuracy =  89.0
# Generation  188  Accuracy =  89.0
# Generation  189  Accuracy =  89.0
# Generation  190  Accuracy =  89.0
# Generation  191  Accuracy =  89.0
# Generation  192  Accuracy =  89.0
# Generation  193  Accuracy =  89.0
# Generation  194  Accuracy =  89.0
# Generation  195  Accuracy =  89.0
# CREATING SAMPLE
# Generation  196  Accuracy =  89.0
# Generation  197  Accuracy =  89.0
# Generation  198  Accuracy =  89.0
# Generation  199  Accuracy =  89.0
# Generation  200  Accuracy =  89.0
# Generation  201  Accuracy =  89.0
# Generation  202  Accuracy =  89.0
# Generation  203  Accuracy =  89.0
# Generation  204  Accuracy =  89.0
# Generation  205  Accuracy =  89.0
# Generation  206  Accuracy =  89.0
# Generation  207  Accuracy =  89.0
# Generation  208  Accuracy =  89.0
# Same Accuracy for last 25 generations
# ========================================================================
# RUN - 2
# ========================================================================
# Data contains 21 and 3 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  61.0
# Generation  2  Accuracy =  61.0
# Generation  3  Accuracy =  61.0
# Generation  4  Accuracy =  61.0
# Generation  5  Accuracy =  61.0
# Generation  6  Accuracy =  61.0
# Generation  7  Accuracy =  61.0
# Generation  8  Accuracy =  61.0
# Generation  9  Accuracy =  61.0
# Generation  10  Accuracy =  61.0
# Generation  11  Accuracy =  61.0
# Generation  12  Accuracy =  61.0
# Generation  13  Accuracy =  61.0
# Generation  14  Accuracy =  61.0
# Generation  15  Accuracy =  61.0
# CREATING SAMPLE
# Generation  16  Accuracy =  60.5
# Generation  17  Accuracy =  60.5
# Generation  18  Accuracy =  60.5
# Generation  19  Accuracy =  60.5
# Generation  20  Accuracy =  61.5
# Generation  21  Accuracy =  61.5
# Generation  22  Accuracy =  61.5
# Generation  23  Accuracy =  61.5
# Generation  24  Accuracy =  63.0
# Generation  25  Accuracy =  63.0
# Generation  26  Accuracy =  63.0
# Generation  27  Accuracy =  66.5
# Generation  28  Accuracy =  67.5
# Generation  29  Accuracy =  67.5
# Generation  30  Accuracy =  67.5
# CREATING SAMPLE
# Generation  31  Accuracy =  69.0
# Generation  32  Accuracy =  71.0
# Generation  33  Accuracy =  73.0
# Generation  34  Accuracy =  73.0
# Generation  35  Accuracy =  73.0
# Generation  36  Accuracy =  76.5
# Generation  37  Accuracy =  76.5
# Generation  38  Accuracy =  76.5
# Generation  39  Accuracy =  76.5
# Generation  40  Accuracy =  76.5
# Generation  41  Accuracy =  76.5
# Generation  42  Accuracy =  76.5
# Generation  43  Accuracy =  76.5
# Generation  44  Accuracy =  76.5
# Generation  45  Accuracy =  76.5
# CREATING SAMPLE
# Generation  46  Accuracy =  76.0
# Generation  47  Accuracy =  76.0
# Generation  48  Accuracy =  76.0
# Generation  49  Accuracy =  76.0
# Generation  50  Accuracy =  76.0
# Generation  51  Accuracy =  76.0
# Generation  52  Accuracy =  76.0
# Generation  53  Accuracy =  76.0
# Generation  54  Accuracy =  76.0
# Generation  55  Accuracy =  76.0
# Generation  56  Accuracy =  76.0
# Generation  57  Accuracy =  76.0
# Generation  58  Accuracy =  77.0
# Generation  59  Accuracy =  77.0
# Generation  60  Accuracy =  77.0
# CREATING SAMPLE
# Generation  61  Accuracy =  77.0
# Generation  62  Accuracy =  77.0
# Generation  63  Accuracy =  77.0
# Generation  64  Accuracy =  77.0
# Generation  65  Accuracy =  77.0
# Generation  66  Accuracy =  77.0
# Generation  67  Accuracy =  77.0
# Generation  68  Accuracy =  77.0
# Generation  69  Accuracy =  77.0
# Generation  70  Accuracy =  77.0
# Generation  71  Accuracy =  77.0
# Generation  72  Accuracy =  77.0
# Generation  73  Accuracy =  77.0
# Generation  74  Accuracy =  77.0
# Generation  75  Accuracy =  77.0
# CREATING SAMPLE
# Generation  76  Accuracy =  75.5
# Generation  77  Accuracy =  75.5
# Generation  78  Accuracy =  75.5
# Generation  79  Accuracy =  75.5
# Generation  80  Accuracy =  75.5
# Generation  81  Accuracy =  75.5
# Generation  82  Accuracy =  75.5
# Generation  83  Accuracy =  75.5
# Generation  84  Accuracy =  75.5
# Generation  85  Accuracy =  75.5
# Generation  86  Accuracy =  75.5
# Generation  87  Accuracy =  75.5
# Generation  88  Accuracy =  75.5
# Generation  89  Accuracy =  75.5
# Generation  90  Accuracy =  75.5
# CREATING SAMPLE
# Generation  91  Accuracy =  79.5
# Generation  92  Accuracy =  79.5
# Generation  93  Accuracy =  79.5
# Generation  94  Accuracy =  79.5
# Generation  95  Accuracy =  79.5
# Generation  96  Accuracy =  79.5
# Generation  97  Accuracy =  79.5
# Generation  98  Accuracy =  79.5
# Generation  99  Accuracy =  79.5
# Generation  100  Accuracy =  79.5
# Generation  101  Accuracy =  79.5
# Generation  102  Accuracy =  79.5
# Generation  103  Accuracy =  79.5
# Generation  104  Accuracy =  79.5
# Generation  105  Accuracy =  79.5
# CREATING SAMPLE
# Generation  106  Accuracy =  82.0
# Generation  107  Accuracy =  82.0
# Generation  108  Accuracy =  82.0
# Generation  109  Accuracy =  82.0
# Generation  110  Accuracy =  82.0
# Generation  111  Accuracy =  82.0
# Generation  112  Accuracy =  82.0
# Generation  113  Accuracy =  82.0
# Generation  114  Accuracy =  82.0
# Generation  115  Accuracy =  82.0
# Generation  116  Accuracy =  82.0
# Generation  117  Accuracy =  82.0
# Generation  118  Accuracy =  82.0
# Generation  119  Accuracy =  82.0
# Generation  120  Accuracy =  82.0
# CREATING SAMPLE
# Generation  121  Accuracy =  84.0
# Generation  122  Accuracy =  84.0
# Generation  123  Accuracy =  85.5
# Generation  124  Accuracy =  85.5
# Generation  125  Accuracy =  85.5
# Generation  126  Accuracy =  85.5
# Generation  127  Accuracy =  85.5
# Generation  128  Accuracy =  85.5
# Generation  129  Accuracy =  85.5
# Generation  130  Accuracy =  85.5
# Generation  131  Accuracy =  85.5
# Generation  132  Accuracy =  85.5
# Generation  133  Accuracy =  85.5
# Generation  134  Accuracy =  85.5
# Generation  135  Accuracy =  85.5
# CREATING SAMPLE
# Generation  136  Accuracy =  83.5
# Generation  137  Accuracy =  83.5
# Generation  138  Accuracy =  83.5
# Generation  139  Accuracy =  83.5
# Generation  140  Accuracy =  83.5
# Generation  141  Accuracy =  83.5
# Generation  142  Accuracy =  83.5
# Generation  143  Accuracy =  83.5
# Generation  144  Accuracy =  83.5
# Generation  145  Accuracy =  83.5
# Generation  146  Accuracy =  83.5
# Generation  147  Accuracy =  86.0
# Generation  148  Accuracy =  86.0
# Generation  149  Accuracy =  86.0
# Generation  150  Accuracy =  86.0
# CREATING SAMPLE
# Generation  151  Accuracy =  88.0
# Generation  152  Accuracy =  88.0
# Generation  153  Accuracy =  88.0
# Generation  154  Accuracy =  88.0
# Generation  155  Accuracy =  88.0
# Generation  156  Accuracy =  88.0
# Generation  157  Accuracy =  88.5
# Generation  158  Accuracy =  88.5
# Generation  159  Accuracy =  88.5
# Generation  160  Accuracy =  89.5
# Generation  161  Accuracy =  89.5
# Generation  162  Accuracy =  89.5
# Generation  163  Accuracy =  89.5
# Generation  164  Accuracy =  89.5
# Generation  165  Accuracy =  89.5
# CREATING SAMPLE
# Generation  166  Accuracy =  89.0
# Generation  167  Accuracy =  89.0
# Generation  168  Accuracy =  90.5
# ========================================================================
# RUN - 3
# ========================================================================
# Data contains 21 and 3 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  51.0
# Generation  2  Accuracy =  51.0
# Generation  3  Accuracy =  51.0
# Generation  4  Accuracy =  51.0
# Generation  5  Accuracy =  51.0
# Generation  6  Accuracy =  66.0
# Generation  7  Accuracy =  66.0
# Generation  8  Accuracy =  66.0
# Generation  9  Accuracy =  66.0
# Generation  10  Accuracy =  66.0
# Generation  11  Accuracy =  66.0
# Generation  12  Accuracy =  66.0
# Generation  13  Accuracy =  66.0
# Generation  14  Accuracy =  66.0
# Generation  15  Accuracy =  66.0
# CREATING SAMPLE
# Generation  16  Accuracy =  61.5
# Generation  17  Accuracy =  61.5
# Generation  18  Accuracy =  61.5
# Generation  19  Accuracy =  61.5
# Generation  20  Accuracy =  61.5
# Generation  21  Accuracy =  61.5
# Generation  22  Accuracy =  61.5
# Generation  23  Accuracy =  61.5
# Generation  24  Accuracy =  61.5
# Generation  25  Accuracy =  61.5
# Generation  26  Accuracy =  76.5
# Generation  27  Accuracy =  76.5
# Generation  28  Accuracy =  76.5
# Generation  29  Accuracy =  76.5
# Generation  30  Accuracy =  76.5
# CREATING SAMPLE
# Generation  31  Accuracy =  77.5
# Generation  32  Accuracy =  77.5
# Generation  33  Accuracy =  77.5
# Generation  34  Accuracy =  77.5
# Generation  35  Accuracy =  77.5
# Generation  36  Accuracy =  77.5
# Generation  37  Accuracy =  77.5
# Generation  38  Accuracy =  77.5
# Generation  39  Accuracy =  77.5
# Generation  40  Accuracy =  77.5
# Generation  41  Accuracy =  77.5
# Generation  42  Accuracy =  77.5
# Generation  43  Accuracy =  77.5
# Generation  44  Accuracy =  77.5
# Generation  45  Accuracy =  77.5
# CREATING SAMPLE
# Generation  46  Accuracy =  78.0
# Generation  47  Accuracy =  78.0
# Generation  48  Accuracy =  78.0
# Generation  49  Accuracy =  78.0
# Generation  50  Accuracy =  78.0
# Generation  51  Accuracy =  78.0
# Generation  52  Accuracy =  78.0
# Generation  53  Accuracy =  78.0
# Generation  54  Accuracy =  78.0
# Generation  55  Accuracy =  78.0
# Generation  56  Accuracy =  78.0
# Generation  57  Accuracy =  78.0
# Generation  58  Accuracy =  78.0
# Generation  59  Accuracy =  78.0
# Generation  60  Accuracy =  78.0
# CREATING SAMPLE
# Generation  61  Accuracy =  79.0
# Generation  62  Accuracy =  79.0
# Generation  63  Accuracy =  79.0
# Generation  64  Accuracy =  79.0
# Generation  65  Accuracy =  79.0
# Generation  66  Accuracy =  79.0
# Generation  67  Accuracy =  79.0
# Generation  68  Accuracy =  79.0
# Generation  69  Accuracy =  79.0
# Generation  70  Accuracy =  79.0
# Generation  71  Accuracy =  79.0
# Generation  72  Accuracy =  79.0
# Generation  73  Accuracy =  79.0
# Generation  74  Accuracy =  79.0
# Generation  75  Accuracy =  79.0
# CREATING SAMPLE
# Generation  76  Accuracy =  81.0
# Generation  77  Accuracy =  81.0
# Generation  78  Accuracy =  81.0
# Generation  79  Accuracy =  81.0
# Generation  80  Accuracy =  81.0
# Generation  81  Accuracy =  81.0
# Generation  82  Accuracy =  81.0
# Generation  83  Accuracy =  81.0
# Generation  84  Accuracy =  81.0
# Generation  85  Accuracy =  81.0
# Generation  86  Accuracy =  81.0
# Generation  87  Accuracy =  81.0
# Generation  88  Accuracy =  81.0
# Generation  89  Accuracy =  81.0
# Generation  90  Accuracy =  81.0
# CREATING SAMPLE
# Generation  91  Accuracy =  78.5
# Generation  92  Accuracy =  78.5
# Generation  93  Accuracy =  78.5
# Generation  94  Accuracy =  78.5
# Generation  95  Accuracy =  78.5
# Generation  96  Accuracy =  78.5
# Generation  97  Accuracy =  78.5
# Generation  98  Accuracy =  78.5
# Generation  99  Accuracy =  78.5
# Generation  100  Accuracy =  78.5
# Generation  101  Accuracy =  78.5
# Generation  102  Accuracy =  78.5
# Generation  103  Accuracy =  78.5
# Generation  104  Accuracy =  78.5
# Generation  105  Accuracy =  78.5
# CREATING SAMPLE
# Generation  106  Accuracy =  83.0
# Generation  107  Accuracy =  83.0
# Generation  108  Accuracy =  83.0
# Generation  109  Accuracy =  83.0
# Generation  110  Accuracy =  83.0
# Generation  111  Accuracy =  83.0
# Generation  112  Accuracy =  83.0
# Generation  113  Accuracy =  83.0
# Generation  114  Accuracy =  83.0
# Generation  115  Accuracy =  83.0
# Generation  116  Accuracy =  83.0
# Generation  117  Accuracy =  83.0
# Generation  118  Accuracy =  83.0
# Generation  119  Accuracy =  83.0
# Generation  120  Accuracy =  83.0
# CREATING SAMPLE
# Generation  121  Accuracy =  81.5
# Generation  122  Accuracy =  81.5
# Generation  123  Accuracy =  81.5
# Generation  124  Accuracy =  81.5
# Generation  125  Accuracy =  81.5
# Generation  126  Accuracy =  81.5
# Generation  127  Accuracy =  81.5
# Generation  128  Accuracy =  81.5
# Generation  129  Accuracy =  81.5
# Generation  130  Accuracy =  81.5
# Generation  131  Accuracy =  81.5
# Generation  132  Accuracy =  81.5
# Generation  133  Accuracy =  81.5
# Generation  134  Accuracy =  81.5
# Generation  135  Accuracy =  81.5
# CREATING SAMPLE
# Generation  136  Accuracy =  76.0
# Generation  137  Accuracy =  88.5
# Generation  138  Accuracy =  88.5
# Generation  139  Accuracy =  88.5
# Generation  140  Accuracy =  88.5
# Generation  141  Accuracy =  88.5
# Generation  142  Accuracy =  88.5
# Generation  143  Accuracy =  88.5
# Generation  144  Accuracy =  88.5
# Generation  145  Accuracy =  88.5
# Generation  146  Accuracy =  88.5
# Generation  147  Accuracy =  88.5
# Generation  148  Accuracy =  88.5
# Generation  149  Accuracy =  88.5
# Generation  150  Accuracy =  88.5
# CREATING SAMPLE
# Generation  151  Accuracy =  91.5
# ========================================================================
# RUN - 4
# ========================================================================
# Data contains 21 and 3 classes
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  66.5
# Generation  2  Accuracy =  66.5
# Generation  3  Accuracy =  66.5
# Generation  4  Accuracy =  66.5
# Generation  5  Accuracy =  66.5
# Generation  6  Accuracy =  66.5
# Generation  7  Accuracy =  66.5
# Generation  8  Accuracy =  66.5
# Generation  9  Accuracy =  66.5
# Generation  10  Accuracy =  66.5
# Generation  11  Accuracy =  66.5
# Generation  12  Accuracy =  66.5
# Generation  13  Accuracy =  66.5
# Generation  14  Accuracy =  67.0
# Generation  15  Accuracy =  67.0
# CREATING SAMPLE
# Generation  16  Accuracy =  62.0
# Generation  17  Accuracy =  62.0
# Generation  18  Accuracy =  62.0
# Generation  19  Accuracy =  62.0
# Generation  20  Accuracy =  62.0
# Generation  21  Accuracy =  62.0
# Generation  22  Accuracy =  62.0
# Generation  23  Accuracy =  62.0
# Generation  24  Accuracy =  62.0
# Generation  25  Accuracy =  62.0
# Generation  26  Accuracy =  62.0
# Generation  27  Accuracy =  62.0
# Generation  28  Accuracy =  62.0
# Generation  29  Accuracy =  62.0
# Generation  30  Accuracy =  62.0
# CREATING SAMPLE
# Generation  31  Accuracy =  63.0
# Generation  32  Accuracy =  63.0
# Generation  33  Accuracy =  63.0
# Generation  34  Accuracy =  63.0
# Generation  35  Accuracy =  63.0
# Generation  36  Accuracy =  63.0
# Generation  37  Accuracy =  63.0
# Generation  38  Accuracy =  64.0
# Generation  39  Accuracy =  64.0
# Generation  40  Accuracy =  64.0
# Generation  41  Accuracy =  64.0
# Generation  42  Accuracy =  64.0
# Generation  43  Accuracy =  64.0
# Generation  44  Accuracy =  64.0
# Generation  45  Accuracy =  64.0
# CREATING SAMPLE
# Generation  46  Accuracy =  66.0
# Generation  47  Accuracy =  66.0
# Generation  48  Accuracy =  66.0
# Generation  49  Accuracy =  66.0
# Generation  50  Accuracy =  66.0
# Generation  51  Accuracy =  66.0
# Generation  52  Accuracy =  66.0
# Generation  53  Accuracy =  66.0
# Generation  54  Accuracy =  66.0
# Generation  55  Accuracy =  66.0
# Generation  56  Accuracy =  66.0
# Generation  57  Accuracy =  66.0
# Generation  58  Accuracy =  66.0
# Generation  59  Accuracy =  66.0
# Generation  60  Accuracy =  66.0
# CREATING SAMPLE
# Generation  61  Accuracy =  63.5
# Generation  62  Accuracy =  63.5
# Generation  63  Accuracy =  63.5
# Generation  64  Accuracy =  63.5
# Generation  65  Accuracy =  64.5
# Generation  66  Accuracy =  64.5
# Generation  67  Accuracy =  64.5
# Generation  68  Accuracy =  64.5
# Generation  69  Accuracy =  64.5
# Generation  70  Accuracy =  65.5
# Generation  71  Accuracy =  65.5
# Generation  72  Accuracy =  65.5
# Generation  73  Accuracy =  76.5
# Generation  74  Accuracy =  76.5
# Generation  75  Accuracy =  78.0
# CREATING SAMPLE
# Generation  76  Accuracy =  74.0
# Generation  77  Accuracy =  74.0
# Generation  78  Accuracy =  74.0
# Generation  79  Accuracy =  74.0
# Generation  80  Accuracy =  74.0
# Generation  81  Accuracy =  74.0
# Generation  82  Accuracy =  74.0
# Generation  83  Accuracy =  74.0
# Generation  84  Accuracy =  79.5
# Generation  85  Accuracy =  79.5
# Generation  86  Accuracy =  79.5
# Generation  87  Accuracy =  79.5
# Generation  88  Accuracy =  79.5
# Generation  89  Accuracy =  79.5
# Generation  90  Accuracy =  79.5
# CREATING SAMPLE
# Generation  91  Accuracy =  91.0

# %%
for dataset in modelInfo.keys():
  print(dataset)
  for model in modelInfo[dataset]:
    print(model.generationCount , model.trainAccuracy[-1], model.testAccuracy[-1])
# Out:
# abalone
# 325 48.0 35.96
# 103 56.5 19.14
# 110 61.0 57.02
# 429 60.5 51.36
# 40 50.0 70.26
# bank
# 85 78.0 83.54
# 256 85.5 84.89
# 40 72.0 76.21
# 814 79.0 82.86
# 355 80.0 85.34
# thyroid
# 121 90.0 88.83
# 208 89.0 89.29
# 168 90.5 88.45
# 151 91.5 90.46
# 91 91.0 89.35

# %%
i = 4
dataset = 'thyroid'


plt.plot(range(len(modelInfo[dataset][i].testAccuracy)), modelInfo[dataset][i].testAccuracy , label= "Test")
plt.plot(range(len(modelInfo[dataset][i].trainAccuracy)), modelInfo[dataset][i].trainAccuracy, label = "Train" )
plt.xlabel("Generations")
plt.ylabel("Accuracy")
plt.title("Overall Accuracy Curve") 
plt.legend()
plt.show()

# %%
3
