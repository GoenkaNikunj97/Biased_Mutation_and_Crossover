# %%
#importing libraries

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from tqdm import tqdm
import numpy as np
import pandas as pd
import random
import copy

# %%
from google.colab import drive
drive.mount('/content/drive')

DataFolder = "/content/drive/My Drive/Colab Notebooks/geneticsProject/data/"

# CONFIG
SAMPLE_SIZE =200
CHANGE_SAMPLE_AFTER = 15
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class Config:
    MAX_INSTRUCTION_SET_LENGTH = 256
    INIT_MAX_INSTRUCTION_SET_LENGTH = 128
    MIN_INSTRUCTION_SET_LENGTH = 8
    TOTAL_OUTPUT_REGISTER = 10
    TOTAL_OPERATIONS = 4

    #PAR TO TUNE!
    GAP_PERCENTAGE = 20
    MUTATION_PROBABILITY = 90
    CROSSOVER_PROBABILITY = 90
    POPULATION_SIZE = 150
    SAME_NUMBER_OF_ITERATIONS = 50

# %% [markdown]
# ### Get Data

# %%
def getDataFromFile(fileName):
  #Read File
  df = pd.read_csv(fileName, sep=" " ,header=None)
  data = df.dropna(axis=1)

  return data

# %%
def getData(target):
  trainFile = DataFolder + target +"/train.txt"
  testFile = DataFolder + target +"/test.txt"

  #Training Data
  trainData =  getDataFromFile(trainFile)

  #Post Training Evaluation
  testData =  getDataFromFile(testFile)

  return trainData,testData

# %%
def getuniformSample(data, sampleSize, lableSize):
  print("CREATING SAMPLE")
  classesIndex = (data.shape)[1] - 1
  allLables = data[classesIndex].unique()

  #empty Sample df
  sample = pd.DataFrame()
  tempData = data[:]

  while(len(sample) < sampleSize):
    lableToSelect = random.choice(allLables)
    dataForClass = tempData[tempData[classesIndex] == (lableToSelect)]
    selectedData = dataForClass.sample(n=1, replace=False)
    sample = sample.append(selectedData)
    tempData.drop(selectedData.index)
    
  return sample

# %%
def splitDataForXandY(data):
  X = data[data.columns[:-1]]
  Y = data[data.columns[-1]]
  
  # one hot encode lable
  Y = pd.get_dummies(Y)
  
  X = X.values.tolist()
  Y = Y.values.tolist()
  
  return X,Y

# %% [markdown]
# ### Creating Individuals and population

# %%
class Individual:
    # Operators = [+, -, /2, *2]
    # Operators = [0, 1,  2 , 3]
    # instructionSet = [ Select | target Register | operator| source ]

    def __init__(self, instructionSet):
        self.instructionSet = instructionSet
        self.registers = [0] * Config.TOTAL_OUTPUT_REGISTER
        self.fitnessScore = 0

    def reset(self):
        self.registers = [0] * Config.TOTAL_OUTPUT_REGISTER

    def resetFitness(self):
        self.fitnessScore = 0

    def isValid(self):
        if( (len(self.instructionSet) > Config.MIN_INSTRUCTION_SET_LENGTH) and (len(self.instructionSet) < Config.MAX_INSTRUCTION_SET_LENGTH)):
            return True
        else:
            return False

    def runProgram(self, data):
        self.reset()
        for instruction in self.instructionSet:
            select = instruction[0]
            target = instruction[1]
            operator = instruction[2]
            source = instruction[3]

            if select == 0:
                source = source%len(data)
                source = data[source]
            else:
                source = source % Config.TOTAL_OUTPUT_REGISTER
                source = self.registers[source]

            if operator == 0:
                self.registers[target] = self.registers[target] + source
            if operator == 1:
                self.registers[target] = self.registers[target] - source
            if operator == 2:
                self.registers[target] = self.registers[target] / 2
            if operator == 3:
                self.registers[target] = self.registers[target] * 2

    def predict(self, data, lable):

        self.runProgram(data)

        maxLableIndex = np.array(lable).argmax()
        maxRegisterIndex = np.array(self.registers[:len(lable)]).argmax()

        if maxLableIndex == maxRegisterIndex:
            return True
        else:
            return False

# %%
def getInstructionSet(dataLen):
  
  configOb = Config()

  #randomly selecting the length of instruction set
  endIndex = random.randint(2,configOb.INIT_MAX_INSTRUCTION_SET_LENGTH)
  instructionSet = list()
  for i in range(endIndex):
    selectBit = random.randint(0,1)
    targetValue = random.randint(0,configOb.TOTAL_OUTPUT_REGISTER - 1)
    operator = random.randint(0,configOb.TOTAL_OPERATIONS - 1)
    source = random.randint(0,max(dataLen, configOb.TOTAL_OUTPUT_REGISTER ) - 1 )

    instruction = [selectBit, targetValue, operator, source]
    instructionSet.append(instruction)

  return instructionSet

# %%
def createGenotype(X):
  dataLen = len(X[0])
  populationList = list()
  for i in range(Config.POPULATION_SIZE):
    individualInstructionSet = getInstructionSet(dataLen)
    individualOb = Individual(individualInstructionSet)
    populationList.append(individualOb)
    
  print(str(len(populationList)) + " individuals created.")
  return populationList

# %% [markdown]
# ### Methods for GL

# %%
class TwoPointCrossover:

  def getBiasedCrossoverPoints(self, parent):
    n = len(parent.instructionSet)
    temp = 1
    myList = []
    while (temp <= n):
      tempList = [temp-1]*temp
      myList = myList + tempList
      temp +=1

    crossoverPoint1 = random.choice(myList)
    crossoverPoint2 = random.choice(myList)
    while (crossoverPoint1 == crossoverPoint2 or crossoverPoint1 > crossoverPoint2):
      crossoverPoint1 = random.choice(myList)
      crossoverPoint2 = random.choice(myList)

    return crossoverPoint1,crossoverPoint2
  
  def getTwoCrossoverPoints(self, parent):
    crossoverPoint1 = 0
    crossoverPoint2 = 0
    while (crossoverPoint1 == crossoverPoint2):
      crossoverPoint1 = random.randint(0, len(parent.instructionSet) - 2)
      crossoverPoint2 = random.randint(crossoverPoint1 + 1, len(parent.instructionSet) - 1)
      
    return crossoverPoint1,crossoverPoint2
    
  def createChild(self, parent1, parent2, p1CP1,p1CP2, p2CP1,p2CP2 ):
    childInstructionSet = parent1.instructionSet[:p1CP1 - 1]
    childInstructionSet = childInstructionSet + parent2.instructionSet[p2CP1: p2CP2]
    childInstructionSet = childInstructionSet + parent1.instructionSet[p1CP2 + 1:]

    child = Individual(childInstructionSet)

    return child
  
  def crossover(self, parent1, parent2):
    p1CP1, p1CP2 = self.getTwoCrossoverPoints(parent1)
    p2CP1, p2CP2 = self.getTwoCrossoverPoints(parent2)

    child1 = self.createChild(parent1, parent2, p1CP1, p1CP2, p2CP1, p2CP2)

    child2 = self.createChild(parent2, parent1, p2CP1, p2CP2, p1CP1, p1CP2)

    if (not (child1.isValid())):
      child1 = None
      if (not (child2.isValid())):
        child2 = None
    return child1, child2

# %%
 class Mutation:
   mutationTypes = 3

   def getBiasedMutationPoints(self, parent):
     n = len(parent.instructionSet)
     temp = n
     i = 0
     myList = []
     while (temp > 0):
       tempList = [i]*temp
       myList = myList + tempList
       temp -= 1
       i += 1
     crossoverPoint1 = random.choice(myList)
     #print(crossoverPoint1, "is selected from list of length" , len(parent.instructionSet))
     return crossoverPoint1

   def swapMutation(self, child):
     bit1 = self.getBiasedMutationPoints(child)
     bit2 = self.getBiasedMutationPoints(child)
     #print("Swapping bit: ",bit1, "and ", bit2)
     child.instructionSet[bit1], child.instructionSet[bit2] = child.instructionSet[bit2], child.instructionSet[bit1]
     
     return child
   def reverseMutation(self, child):
     bit1 = self.getBiasedMutationPoints(child)
     bit2 = random.randint(bit1, len(child.instructionSet) - 1)

     mutatedChild = child.instructionSet[0:bit1] + child.instructionSet[bit2: bit1-1: -1] + child.instructionSet[bit2+1:]
     mutatedChild = Individual(mutatedChild)

     return mutatedChild
     
   def scrambleMutation(self, child):
     bit1 = self.getBiasedMutationPoints(child)
     bit2 = random.randint(bit1, len(child.instructionSet) - 1)

     temp = child.instructionSet[bit1: bit2]
     random.shuffle(temp)
     mutatedList = child.instructionSet[:bit1] + temp + child.instructionSet[bit2:]
     mutatedChild = Individual(mutatedList)

     return mutatedChild

   def mutateIndividual(self, childToMutate):
     child = childToMutate
     type = random.randint(0, self.mutationTypes - 1)
     if (random.randint(0, 100) < Config.MUTATION_PROBABILITY):
         if (type == 0):
             child = self.swapMutation(child)
         if (type == 1):
             child = self.reverseMutation(child)
         if (type == 2):
             child = self.scrambleMutation(child)
     return child

# %%
def calculateFitness(populationList, data, lable):
  for person in populationList:
    correctPrediction = 0
    person.resetFitness()
    for i in range(len(data)):
      answer = person.predict(data[i] , lable[i])
      correctPrediction += answer

    fitness = 100*(correctPrediction/len(data))
    person.fitnessScore = fitness

# %%
def getGapedPopulation(populationList):
  sortedPopulation = sorted(populationList, key=lambda x: x.fitnessScore, reverse=True)
  
  totalGap = (Config.GAP_PERCENTAGE * len(sortedPopulation)) / 100
  
  gapedPopulation = sortedPopulation[: int(len(sortedPopulation)- totalGap)]
  return gapedPopulation

# %%
def isChildReadyToPush(populationList, child,newPopulation):
  crossoverChance = random.randint(0, 100) < Config.CROSSOVER_PROBABILITY
  if (crossoverChance and (not (child is None)) and (len(newPopulation) < len(populationList))):
    return True
  else:
    return False

# %%
def breed(populationList, gapedPopulation):
  newPopulation = gapedPopulation[:]
  while (len(newPopulation) < len(populationList)):
    parent1 = random.choice(gapedPopulation)
    parent2 = random.choice(gapedPopulation)
    if (len(parent1.instructionSet) > 5 and len(parent2.instructionSet) > 5):
      child1,child2 = TwoPointCrossover().crossover(parent1, parent2)
    else:
      break
    mutationOb = Mutation()
    
    if (isChildReadyToPush(populationList, child1, newPopulation)):
      mutatedChild = mutationOb.mutateIndividual(child1)
      newPopulation.append(mutatedChild)
      
      if (isChildReadyToPush(populationList,child2,newPopulation)):
        mutatedChild = mutationOb.mutateIndividual(child2)
        newPopulation.append(mutatedChild)
  
  return newPopulation

# %% [markdown]
# ### Making Data for visualization

# %%
def pushToGenerationAccuracyDictionary(classwiseAccuracy,classWiseAccuracyInGeneration):
  for key in classwiseAccuracy.keys():
    if key in classWiseAccuracyInGeneration:
      classWiseAccuracyInGeneration[key].append(classwiseAccuracy[key])
    else:
      classWiseAccuracyInGeneration[key] = []
      classWiseAccuracyInGeneration[key].append(classwiseAccuracy[key])

# %%
def calculateClasswiseAccuracy(individual, data, lable, classWiseAccuracyInGeneration):
  classwiseAccuracy = dict()
  for i in range(len(data)):
    lableToPush = tuple(lable[i])
    answer = individual.predict(data[i], lable[i])
    if (answer):
      if (lableToPush in classwiseAccuracy):
        classwiseAccuracy[lableToPush] += 1
      else:
        classwiseAccuracy[lableToPush] = 1
    else:
      if (lableToPush in classwiseAccuracy):
        classwiseAccuracy[lableToPush] += 0
      else:
        classwiseAccuracy[lableToPush] = 0
  pushToGenerationAccuracyDictionary(classwiseAccuracy, classWiseAccuracyInGeneration)

# %% [markdown]
# ### Training Model

# %%
#method to run everything
def runGA(targetFile, accuracy):
  trainData,testData = getData(targetFile)
  attributes = (trainData.shape)[1] - 1
  classes = len(trainData[attributes].unique())
  #print("Data contains", attributes, "and", classes, "classes")

  sample = getuniformSample(trainData, SAMPLE_SIZE, classes)
  

  X, Y = splitDataForXandY(sample)
  X_test, Y_test = splitDataForXandY(testData)

  #init Population
  populationList = list()
  populationList = createGenotype(X)

  classWiseAccuracyInGeneration = dict()

  generationAccuracy = 0
  desiredAccuracy = accuracy
  generationCount = 0
  accuracyOverGenerations = list()
  testAccuracy = list()

  while (generationAccuracy < desiredAccuracy and generationCount < 500 ):
    if (generationCount % CHANGE_SAMPLE_AFTER == 0):
      sample = getuniformSample(trainData, SAMPLE_SIZE, classes)
      X, Y = splitDataForXandY(sample)
      
    calculateFitness(populationList, X, Y)
    gapedPopulation = getGapedPopulation(populationList)

    mostFitIndi = gapedPopulation[0]
    calculateClasswiseAccuracy(mostFitIndi, X, Y,classWiseAccuracyInGeneration)
    
    accuracyOverGenerations.append(round(gapedPopulation[0].fitnessScore, 2))
    print("Generation ", generationCount + 1, " Accuracy = ", accuracyOverGenerations[generationCount])

    newPopulation = breed(populationList, gapedPopulation)
    populationList = newPopulation
    generationAccuracy = accuracyOverGenerations[generationCount]
    generationCount += 1

    calculateFitness([gapedPopulation[0]], X_test, Y_test)
    testAccuracy.append(round(gapedPopulation[0].fitnessScore, 2))
    
    if(len(accuracyOverGenerations) > 30):
      checkList = accuracyOverGenerations[-25:]
      result = checkList.count(checkList[0]) == len(checkList)
      if (result):
        print("Same Accuracy for last 25 generations")
        break

  
  return generationCount,accuracyOverGenerations,testAccuracy

# %%
class ModelInfo():
  def __init__(self, generationCount,accuracyOverGenerations,testAccuracy ):
        self.generationCount = generationCount
        self.trainAccuracy = accuracyOverGenerations
        self.testAccuracy = testAccuracy

# %%
datasetList = ['abalone','bank','thyroid']
accuracy = [60, 85, 90]
modelInfo = {}
a = 0
for dataset in datasetList:
  modelList = []
  print("========================================================================")
  print("Running GA for Dataset:", dataset, "desired Accuracy:", accuracy[a])
  print("========================================================================")
  for i in range(5):
    print("========================================================================")
    print("RUN -",i)
    print("========================================================================")
    generationCount,accuracyOverGenerations,testAccuracy = runGA(dataset, accuracy[a])
    plt.plot(range(len(accuracyOverGenerations)), accuracyOverGenerations)
    plt.plot(range(len(accuracyOverGenerations)), testAccuracy)
    plt.xlabel("Generations")
    plt.ylabel("Accuracy")
    plt.title("Overall Accuracy Curve") 
    plt.show()
    modelObject = ModelInfo(generationCount,accuracyOverGenerations,testAccuracy)
    modelList.append(modelObject)

  modelInfo[dataset] = modelList
  a += 1
# Out:
# ========================================================================
# Running GA for Dataset: abalone desired Accuracy: 60
# ========================================================================
# ========================================================================
# RUN - 0
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  47.0
# Generation  2  Accuracy =  47.0
# Generation  3  Accuracy =  47.0
# Generation  4  Accuracy =  47.0
# Generation  5  Accuracy =  48.5
# Generation  6  Accuracy =  48.5
# Generation  7  Accuracy =  49.0
# Generation  8  Accuracy =  49.0
# Generation  9  Accuracy =  49.0
# Generation  10  Accuracy =  49.0
# Generation  11  Accuracy =  49.0
# Generation  12  Accuracy =  49.5
# Generation  13  Accuracy =  49.5
# Generation  14  Accuracy =  49.5
# Generation  15  Accuracy =  49.5
# CREATING SAMPLE
# Generation  16  Accuracy =  47.5
# Generation  17  Accuracy =  47.5
# Generation  18  Accuracy =  47.5
# Generation  19  Accuracy =  47.5
# Generation  20  Accuracy =  47.5
# Generation  21  Accuracy =  47.5
# Generation  22  Accuracy =  47.5
# Generation  23  Accuracy =  47.5
# Generation  24  Accuracy =  47.5
# Generation  25  Accuracy =  47.5
# Generation  26  Accuracy =  47.5
# Generation  27  Accuracy =  49.5
# Generation  28  Accuracy =  49.5
# Generation  29  Accuracy =  49.5
# Generation  30  Accuracy =  49.5
# CREATING SAMPLE
# Generation  31  Accuracy =  54.5
# Generation  32  Accuracy =  54.5
# Generation  33  Accuracy =  54.5
# Generation  34  Accuracy =  54.5
# Generation  35  Accuracy =  54.5
# Generation  36  Accuracy =  54.5
# Generation  37  Accuracy =  54.5
# Generation  38  Accuracy =  54.5
# Generation  39  Accuracy =  54.5
# Generation  40  Accuracy =  54.5
# Generation  41  Accuracy =  54.5
# Generation  42  Accuracy =  54.5
# Generation  43  Accuracy =  54.5
# Generation  44  Accuracy =  54.5
# Generation  45  Accuracy =  54.5
# CREATING SAMPLE
# Generation  46  Accuracy =  51.5
# Generation  47  Accuracy =  51.5
# Generation  48  Accuracy =  51.5
# Generation  49  Accuracy =  51.5
# Generation  50  Accuracy =  51.5
# Generation  51  Accuracy =  51.5
# Generation  52  Accuracy =  51.5
# Generation  53  Accuracy =  51.5
# Generation  54  Accuracy =  51.5
# Generation  55  Accuracy =  51.5
# Generation  56  Accuracy =  51.5
# Generation  57  Accuracy =  51.5
# Generation  58  Accuracy =  51.5
# Generation  59  Accuracy =  51.5
# Generation  60  Accuracy =  51.5
# CREATING SAMPLE
# Generation  61  Accuracy =  56.0
# Generation  62  Accuracy =  56.0
# Generation  63  Accuracy =  56.0
# Generation  64  Accuracy =  56.0
# Generation  65  Accuracy =  56.0
# Generation  66  Accuracy =  56.0
# Generation  67  Accuracy =  56.0
# Generation  68  Accuracy =  56.0
# Generation  69  Accuracy =  56.0
# Generation  70  Accuracy =  56.0
# Generation  71  Accuracy =  56.0
# Generation  72  Accuracy =  56.0
# Generation  73  Accuracy =  56.0
# Generation  74  Accuracy =  56.0
# Generation  75  Accuracy =  56.0
# CREATING SAMPLE
# Generation  76  Accuracy =  52.0
# Generation  77  Accuracy =  52.0
# Generation  78  Accuracy =  52.0
# Generation  79  Accuracy =  52.0
# Generation  80  Accuracy =  52.0
# Generation  81  Accuracy =  52.0
# Generation  82  Accuracy =  52.0
# Generation  83  Accuracy =  52.0
# Generation  84  Accuracy =  52.0
# Generation  85  Accuracy =  53.0
# Generation  86  Accuracy =  53.0
# Generation  87  Accuracy =  53.0
# Generation  88  Accuracy =  53.0
# Generation  89  Accuracy =  53.0
# Generation  90  Accuracy =  53.0
# CREATING SAMPLE
# Generation  91  Accuracy =  53.0
# Generation  92  Accuracy =  57.0
# Generation  93  Accuracy =  57.0
# Generation  94  Accuracy =  57.0
# Generation  95  Accuracy =  57.0
# Generation  96  Accuracy =  57.0
# Generation  97  Accuracy =  57.0
# Generation  98  Accuracy =  57.0
# Generation  99  Accuracy =  57.0
# Generation  100  Accuracy =  57.0
# Generation  101  Accuracy =  57.0
# Generation  102  Accuracy =  57.0
# Generation  103  Accuracy =  57.0
# Generation  104  Accuracy =  57.0
# Generation  105  Accuracy =  57.0
# CREATING SAMPLE
# Generation  106  Accuracy =  55.0
# Generation  107  Accuracy =  57.0
# Generation  108  Accuracy =  57.0
# Generation  109  Accuracy =  57.0
# Generation  110  Accuracy =  57.0
# Generation  111  Accuracy =  57.0
# Generation  112  Accuracy =  57.0
# Generation  113  Accuracy =  57.0
# Generation  114  Accuracy =  57.0
# Generation  115  Accuracy =  57.0
# Generation  116  Accuracy =  57.0
# Generation  117  Accuracy =  57.0
# Generation  118  Accuracy =  57.0
# Generation  119  Accuracy =  57.0
# Generation  120  Accuracy =  57.0
# CREATING SAMPLE
# Generation  121  Accuracy =  52.0
# Generation  122  Accuracy =  52.0
# Generation  123  Accuracy =  52.0
# Generation  124  Accuracy =  52.0
# Generation  125  Accuracy =  52.0
# Generation  126  Accuracy =  52.0
# Generation  127  Accuracy =  52.0
# Generation  128  Accuracy =  52.0
# Generation  129  Accuracy =  52.0
# Generation  130  Accuracy =  52.0
# Generation  131  Accuracy =  52.0
# Generation  132  Accuracy =  52.0
# Generation  133  Accuracy =  52.0
# Generation  134  Accuracy =  52.0
# Generation  135  Accuracy =  52.0
# CREATING SAMPLE
# Generation  136  Accuracy =  55.5
# Generation  137  Accuracy =  55.5
# Generation  138  Accuracy =  55.5
# Generation  139  Accuracy =  55.5
# Generation  140  Accuracy =  55.5
# Generation  141  Accuracy =  55.5
# Generation  142  Accuracy =  55.5
# Generation  143  Accuracy =  55.5
# Generation  144  Accuracy =  55.5
# Generation  145  Accuracy =  55.5
# Generation  146  Accuracy =  55.5
# Generation  147  Accuracy =  55.5
# Generation  148  Accuracy =  55.5
# Generation  149  Accuracy =  55.5
# Generation  150  Accuracy =  55.5
# CREATING SAMPLE
# Generation  151  Accuracy =  57.5
# Generation  152  Accuracy =  57.5
# Generation  153  Accuracy =  57.5
# Generation  154  Accuracy =  57.5
# Generation  155  Accuracy =  57.5
# Generation  156  Accuracy =  58.0
# Generation  157  Accuracy =  58.0
# Generation  158  Accuracy =  58.0
# Generation  159  Accuracy =  59.0
# Generation  160  Accuracy =  59.0
# Generation  161  Accuracy =  59.0
# Generation  162  Accuracy =  59.0
# Generation  163  Accuracy =  59.0
# Generation  164  Accuracy =  59.0
# Generation  165  Accuracy =  59.0
# CREATING SAMPLE
# Generation  166  Accuracy =  56.0
# Generation  167  Accuracy =  56.0
# Generation  168  Accuracy =  56.0
# Generation  169  Accuracy =  56.0
# Generation  170  Accuracy =  56.0
# Generation  171  Accuracy =  56.0
# Generation  172  Accuracy =  56.0
# Generation  173  Accuracy =  56.0
# Generation  174  Accuracy =  56.0
# Generation  175  Accuracy =  56.0
# Generation  176  Accuracy =  56.0
# Generation  177  Accuracy =  56.0
# Generation  178  Accuracy =  56.0
# Generation  179  Accuracy =  56.0
# Generation  180  Accuracy =  56.0
# CREATING SAMPLE
# Generation  181  Accuracy =  62.5
# ========================================================================
# RUN - 1
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  46.0
# Generation  2  Accuracy =  46.0
# Generation  3  Accuracy =  46.0
# Generation  4  Accuracy =  48.0
# Generation  5  Accuracy =  51.0
# Generation  6  Accuracy =  51.0
# Generation  7  Accuracy =  51.0
# Generation  8  Accuracy =  51.0
# Generation  9  Accuracy =  51.0
# Generation  10  Accuracy =  51.0
# Generation  11  Accuracy =  51.0
# Generation  12  Accuracy =  51.0
# Generation  13  Accuracy =  51.0
# Generation  14  Accuracy =  51.0
# Generation  15  Accuracy =  51.0
# CREATING SAMPLE
# Generation  16  Accuracy =  47.0
# Generation  17  Accuracy =  47.0
# Generation  18  Accuracy =  47.0
# Generation  19  Accuracy =  47.0
# Generation  20  Accuracy =  47.0
# Generation  21  Accuracy =  47.0
# Generation  22  Accuracy =  47.0
# Generation  23  Accuracy =  47.0
# Generation  24  Accuracy =  47.0
# Generation  25  Accuracy =  47.0
# Generation  26  Accuracy =  47.0
# Generation  27  Accuracy =  47.0
# Generation  28  Accuracy =  47.0
# Generation  29  Accuracy =  47.0
# Generation  30  Accuracy =  47.0
# CREATING SAMPLE
# Generation  31  Accuracy =  46.0
# Generation  32  Accuracy =  46.0
# Generation  33  Accuracy =  47.5
# Generation  34  Accuracy =  47.5
# Generation  35  Accuracy =  47.5
# Generation  36  Accuracy =  47.5
# Generation  37  Accuracy =  47.5
# Generation  38  Accuracy =  48.5
# Generation  39  Accuracy =  48.5
# Generation  40  Accuracy =  48.5
# Generation  41  Accuracy =  49.0
# Generation  42  Accuracy =  49.0
# Generation  43  Accuracy =  49.0
# Generation  44  Accuracy =  49.0
# Generation  45  Accuracy =  49.0
# CREATING SAMPLE
# Generation  46  Accuracy =  45.5
# Generation  47  Accuracy =  45.5
# Generation  48  Accuracy =  45.5
# Generation  49  Accuracy =  45.5
# Generation  50  Accuracy =  45.5
# Generation  51  Accuracy =  45.5
# Generation  52  Accuracy =  45.5
# Generation  53  Accuracy =  45.5
# Generation  54  Accuracy =  45.5
# Generation  55  Accuracy =  45.5
# Generation  56  Accuracy =  45.5
# Generation  57  Accuracy =  45.5
# Generation  58  Accuracy =  45.5
# Generation  59  Accuracy =  45.5
# Generation  60  Accuracy =  45.5
# CREATING SAMPLE
# Generation  61  Accuracy =  49.0
# Generation  62  Accuracy =  49.0
# Generation  63  Accuracy =  49.0
# Generation  64  Accuracy =  49.0
# Generation  65  Accuracy =  49.0
# Generation  66  Accuracy =  49.0
# Generation  67  Accuracy =  49.0
# Generation  68  Accuracy =  49.0
# Generation  69  Accuracy =  49.0
# Generation  70  Accuracy =  49.0
# Generation  71  Accuracy =  49.0
# Generation  72  Accuracy =  49.0
# Generation  73  Accuracy =  49.0
# Generation  74  Accuracy =  49.0
# Generation  75  Accuracy =  49.0
# CREATING SAMPLE
# Generation  76  Accuracy =  50.0
# Generation  77  Accuracy =  50.0
# Generation  78  Accuracy =  50.0
# Generation  79  Accuracy =  50.0
# Generation  80  Accuracy =  50.0
# Generation  81  Accuracy =  50.0
# Generation  82  Accuracy =  50.0
# Generation  83  Accuracy =  50.0
# Generation  84  Accuracy =  53.5
# Generation  85  Accuracy =  53.5
# Generation  86  Accuracy =  53.5
# Generation  87  Accuracy =  57.0
# Generation  88  Accuracy =  57.0
# Generation  89  Accuracy =  57.0
# Generation  90  Accuracy =  57.0
# CREATING SAMPLE
# Generation  91  Accuracy =  54.0
# Generation  92  Accuracy =  54.0
# Generation  93  Accuracy =  54.0
# Generation  94  Accuracy =  54.0
# Generation  95  Accuracy =  54.0
# Generation  96  Accuracy =  54.0
# Generation  97  Accuracy =  54.0
# Generation  98  Accuracy =  54.0
# Generation  99  Accuracy =  54.0
# Generation  100  Accuracy =  54.0
# Generation  101  Accuracy =  54.0
# Generation  102  Accuracy =  54.0
# Generation  103  Accuracy =  54.0
# Generation  104  Accuracy =  54.0
# Generation  105  Accuracy =  54.0
# CREATING SAMPLE
# Generation  106  Accuracy =  58.5
# Generation  107  Accuracy =  58.5
# Generation  108  Accuracy =  58.5
# Generation  109  Accuracy =  58.5
# Generation  110  Accuracy =  58.5
# Generation  111  Accuracy =  58.5
# Generation  112  Accuracy =  58.5
# Generation  113  Accuracy =  58.5
# Generation  114  Accuracy =  58.5
# Generation  115  Accuracy =  58.5
# Generation  116  Accuracy =  58.5
# Generation  117  Accuracy =  58.5
# Generation  118  Accuracy =  58.5
# Generation  119  Accuracy =  58.5
# Generation  120  Accuracy =  58.5
# CREATING SAMPLE
# Generation  121  Accuracy =  59.5
# Generation  122  Accuracy =  59.5
# Generation  123  Accuracy =  59.5
# Generation  124  Accuracy =  59.5
# Generation  125  Accuracy =  59.5
# Generation  126  Accuracy =  59.5
# Generation  127  Accuracy =  59.5
# Generation  128  Accuracy =  59.5
# Generation  129  Accuracy =  59.5
# Generation  130  Accuracy =  59.5
# Generation  131  Accuracy =  59.5
# Generation  132  Accuracy =  59.5
# Generation  133  Accuracy =  59.5
# Generation  134  Accuracy =  59.5
# Generation  135  Accuracy =  59.5
# CREATING SAMPLE
# Generation  136  Accuracy =  56.0
# Generation  137  Accuracy =  56.0
# Generation  138  Accuracy =  56.0
# Generation  139  Accuracy =  56.0
# Generation  140  Accuracy =  56.0
# Generation  141  Accuracy =  56.0
# Generation  142  Accuracy =  56.0
# Generation  143  Accuracy =  56.0
# Generation  144  Accuracy =  56.0
# Generation  145  Accuracy =  56.0
# Generation  146  Accuracy =  56.0
# Generation  147  Accuracy =  56.0
# Generation  148  Accuracy =  56.0
# Generation  149  Accuracy =  56.0
# Generation  150  Accuracy =  56.0
# CREATING SAMPLE
# Generation  151  Accuracy =  64.5
# ========================================================================
# RUN - 2
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  51.0
# Generation  2  Accuracy =  51.0
# Generation  3  Accuracy =  51.0
# Generation  4  Accuracy =  51.0
# Generation  5  Accuracy =  51.0
# Generation  6  Accuracy =  51.0
# Generation  7  Accuracy =  51.0
# Generation  8  Accuracy =  51.0
# Generation  9  Accuracy =  51.0
# Generation  10  Accuracy =  51.0
# Generation  11  Accuracy =  51.0
# Generation  12  Accuracy =  51.0
# Generation  13  Accuracy =  51.0
# Generation  14  Accuracy =  51.0
# Generation  15  Accuracy =  51.0
# CREATING SAMPLE
# Generation  16  Accuracy =  50.5
# Generation  17  Accuracy =  50.5
# Generation  18  Accuracy =  50.5
# Generation  19  Accuracy =  50.5
# Generation  20  Accuracy =  50.5
# Generation  21  Accuracy =  50.5
# Generation  22  Accuracy =  50.5
# Generation  23  Accuracy =  50.5
# Generation  24  Accuracy =  50.5
# Generation  25  Accuracy =  50.5
# Generation  26  Accuracy =  50.5
# Generation  27  Accuracy =  50.5
# Generation  28  Accuracy =  50.5
# Generation  29  Accuracy =  50.5
# Generation  30  Accuracy =  51.5
# CREATING SAMPLE
# Generation  31  Accuracy =  50.0
# Generation  32  Accuracy =  50.0
# Generation  33  Accuracy =  50.0
# Generation  34  Accuracy =  50.0
# Generation  35  Accuracy =  50.0
# Generation  36  Accuracy =  50.0
# Generation  37  Accuracy =  50.0
# Generation  38  Accuracy =  50.0
# Generation  39  Accuracy =  50.0
# Generation  40  Accuracy =  50.0
# Generation  41  Accuracy =  50.0
# Generation  42  Accuracy =  50.0
# Generation  43  Accuracy =  50.0
# Generation  44  Accuracy =  50.0
# Generation  45  Accuracy =  51.0
# CREATING SAMPLE
# Generation  46  Accuracy =  51.5
# Generation  47  Accuracy =  51.5
# Generation  48  Accuracy =  53.5
# Generation  49  Accuracy =  53.5
# Generation  50  Accuracy =  53.5
# Generation  51  Accuracy =  53.5
# Generation  52  Accuracy =  55.0
# Generation  53  Accuracy =  55.5
# Generation  54  Accuracy =  55.5
# Generation  55  Accuracy =  55.5
# Generation  56  Accuracy =  55.5
# Generation  57  Accuracy =  55.5
# Generation  58  Accuracy =  55.5
# Generation  59  Accuracy =  55.5
# Generation  60  Accuracy =  55.5
# CREATING SAMPLE
# Generation  61  Accuracy =  49.5
# Generation  62  Accuracy =  49.5
# Generation  63  Accuracy =  49.5
# Generation  64  Accuracy =  49.5
# Generation  65  Accuracy =  49.5
# Generation  66  Accuracy =  49.5
# Generation  67  Accuracy =  49.5
# Generation  68  Accuracy =  49.5
# Generation  69  Accuracy =  49.5
# Generation  70  Accuracy =  49.5
# Generation  71  Accuracy =  49.5
# Generation  72  Accuracy =  49.5
# Generation  73  Accuracy =  49.5
# Generation  74  Accuracy =  49.5
# Generation  75  Accuracy =  49.5
# CREATING SAMPLE
# Generation  76  Accuracy =  49.0
# Generation  77  Accuracy =  49.0
# Generation  78  Accuracy =  49.0
# Generation  79  Accuracy =  49.0
# Generation  80  Accuracy =  49.0
# Generation  81  Accuracy =  49.0
# Generation  82  Accuracy =  49.0
# Generation  83  Accuracy =  49.0
# Generation  84  Accuracy =  49.0
# Generation  85  Accuracy =  49.0
# Generation  86  Accuracy =  49.0
# Generation  87  Accuracy =  49.0
# Generation  88  Accuracy =  49.0
# Generation  89  Accuracy =  49.0
# Generation  90  Accuracy =  49.0
# CREATING SAMPLE
# Generation  91  Accuracy =  47.0
# Generation  92  Accuracy =  47.0
# Generation  93  Accuracy =  47.0
# Generation  94  Accuracy =  47.0
# Generation  95  Accuracy =  47.0
# Generation  96  Accuracy =  47.0
# Generation  97  Accuracy =  47.0
# Generation  98  Accuracy =  50.0
# Generation  99  Accuracy =  50.0
# Generation  100  Accuracy =  50.0
# Generation  101  Accuracy =  50.0
# Generation  102  Accuracy =  50.0
# Generation  103  Accuracy =  50.0
# Generation  104  Accuracy =  50.0
# Generation  105  Accuracy =  50.0
# CREATING SAMPLE
# Generation  106  Accuracy =  49.5
# Generation  107  Accuracy =  49.5
# Generation  108  Accuracy =  49.5
# Generation  109  Accuracy =  49.5
# Generation  110  Accuracy =  49.5
# Generation  111  Accuracy =  49.5
# Generation  112  Accuracy =  49.5
# Generation  113  Accuracy =  49.5
# Generation  114  Accuracy =  49.5
# Generation  115  Accuracy =  49.5
# Generation  116  Accuracy =  49.5
# Generation  117  Accuracy =  49.5
# Generation  118  Accuracy =  49.5
# Generation  119  Accuracy =  49.5
# Generation  120  Accuracy =  49.5
# CREATING SAMPLE
# Generation  121  Accuracy =  46.5
# Generation  122  Accuracy =  46.5
# Generation  123  Accuracy =  46.5
# Generation  124  Accuracy =  46.5
# Generation  125  Accuracy =  46.5
# Generation  126  Accuracy =  46.5
# Generation  127  Accuracy =  46.5
# Generation  128  Accuracy =  46.5
# Generation  129  Accuracy =  46.5
# Generation  130  Accuracy =  46.5
# Generation  131  Accuracy =  46.5
# Generation  132  Accuracy =  46.5
# Generation  133  Accuracy =  46.5
# Generation  134  Accuracy =  46.5
# Generation  135  Accuracy =  50.0
# CREATING SAMPLE
# Generation  136  Accuracy =  47.5
# Generation  137  Accuracy =  47.5
# Generation  138  Accuracy =  47.5
# Generation  139  Accuracy =  47.5
# Generation  140  Accuracy =  47.5
# Generation  141  Accuracy =  47.5
# Generation  142  Accuracy =  47.5
# Generation  143  Accuracy =  47.5
# Generation  144  Accuracy =  47.5
# Generation  145  Accuracy =  47.5
# Generation  146  Accuracy =  47.5
# Generation  147  Accuracy =  47.5
# Generation  148  Accuracy =  47.5
# Generation  149  Accuracy =  47.5
# Generation  150  Accuracy =  47.5
# CREATING SAMPLE
# Generation  151  Accuracy =  52.5
# Generation  152  Accuracy =  52.5
# Generation  153  Accuracy =  52.5
# Generation  154  Accuracy =  52.5
# Generation  155  Accuracy =  52.5
# Generation  156  Accuracy =  52.5
# Generation  157  Accuracy =  52.5
# Generation  158  Accuracy =  52.5
# Generation  159  Accuracy =  52.5
# Generation  160  Accuracy =  52.5
# Generation  161  Accuracy =  52.5
# Generation  162  Accuracy =  52.5
# Generation  163  Accuracy =  52.5
# Generation  164  Accuracy =  52.5
# Generation  165  Accuracy =  52.5
# CREATING SAMPLE
# Generation  166  Accuracy =  50.5
# Generation  167  Accuracy =  50.5
# Generation  168  Accuracy =  50.5
# Generation  169  Accuracy =  50.5
# Generation  170  Accuracy =  50.5
# Generation  171  Accuracy =  50.5
# Generation  172  Accuracy =  50.5
# Generation  173  Accuracy =  50.5
# Generation  174  Accuracy =  50.5
# Generation  175  Accuracy =  50.5
# Generation  176  Accuracy =  50.5
# Generation  177  Accuracy =  50.5
# Generation  178  Accuracy =  50.5
# Generation  179  Accuracy =  50.5
# Generation  180  Accuracy =  50.5
# CREATING SAMPLE
# Generation  181  Accuracy =  52.5
# Generation  182  Accuracy =  52.5
# Generation  183  Accuracy =  52.5
# Generation  184  Accuracy =  52.5
# Generation  185  Accuracy =  52.5
# Generation  186  Accuracy =  52.5
# Generation  187  Accuracy =  52.5
# Generation  188  Accuracy =  52.5
# Generation  189  Accuracy =  52.5
# Generation  190  Accuracy =  52.5
# Generation  191  Accuracy =  52.5
# Generation  192  Accuracy =  52.5
# Generation  193  Accuracy =  52.5
# Generation  194  Accuracy =  52.5
# Generation  195  Accuracy =  52.5
# CREATING SAMPLE
# Generation  196  Accuracy =  54.0
# Generation  197  Accuracy =  54.0
# Generation  198  Accuracy =  54.0
# Generation  199  Accuracy =  54.0
# Generation  200  Accuracy =  54.0
# Generation  201  Accuracy =  54.0
# Generation  202  Accuracy =  54.0
# Generation  203  Accuracy =  54.0
# Generation  204  Accuracy =  54.0
# Generation  205  Accuracy =  54.0
# Generation  206  Accuracy =  54.0
# Generation  207  Accuracy =  54.0
# Generation  208  Accuracy =  54.0
# Generation  209  Accuracy =  54.0
# Generation  210  Accuracy =  54.0
# CREATING SAMPLE
# Generation  211  Accuracy =  50.5
# Generation  212  Accuracy =  50.5
# Generation  213  Accuracy =  50.5
# Generation  214  Accuracy =  50.5
# Generation  215  Accuracy =  50.5
# Generation  216  Accuracy =  50.5
# Generation  217  Accuracy =  50.5
# Generation  218  Accuracy =  50.5
# Generation  219  Accuracy =  50.5
# Generation  220  Accuracy =  51.0
# Generation  221  Accuracy =  51.0
# Generation  222  Accuracy =  51.0
# Generation  223  Accuracy =  51.0
# Generation  224  Accuracy =  51.0
# Generation  225  Accuracy =  51.0
# CREATING SAMPLE
# Generation  226  Accuracy =  49.0
# Generation  227  Accuracy =  49.0
# Generation  228  Accuracy =  49.0
# Generation  229  Accuracy =  49.0
# Generation  230  Accuracy =  49.0
# Generation  231  Accuracy =  49.0
# Generation  232  Accuracy =  49.5
# Generation  233  Accuracy =  49.5
# Generation  234  Accuracy =  49.5
# Generation  235  Accuracy =  49.5
# Generation  236  Accuracy =  49.5
# Generation  237  Accuracy =  49.5
# Generation  238  Accuracy =  49.5
# Generation  239  Accuracy =  49.5
# Generation  240  Accuracy =  49.5
# CREATING SAMPLE
# Generation  241  Accuracy =  43.0
# Generation  242  Accuracy =  43.0
# Generation  243  Accuracy =  43.0
# Generation  244  Accuracy =  43.0
# Generation  245  Accuracy =  49.0
# Generation  246  Accuracy =  49.0
# Generation  247  Accuracy =  49.0
# Generation  248  Accuracy =  49.0
# Generation  249  Accuracy =  49.0
# Generation  250  Accuracy =  49.5
# Generation  251  Accuracy =  49.5
# Generation  252  Accuracy =  49.5
# Generation  253  Accuracy =  49.5
# Generation  254  Accuracy =  49.5
# Generation  255  Accuracy =  49.5
# CREATING SAMPLE
# Generation  256  Accuracy =  43.5
# Generation  257  Accuracy =  43.5
# Generation  258  Accuracy =  43.5
# Generation  259  Accuracy =  43.5
# Generation  260  Accuracy =  43.5
# Generation  261  Accuracy =  43.5
# Generation  262  Accuracy =  43.5
# Generation  263  Accuracy =  43.5
# Generation  264  Accuracy =  43.5
# Generation  265  Accuracy =  43.5
# Generation  266  Accuracy =  43.5
# Generation  267  Accuracy =  43.5
# Generation  268  Accuracy =  43.5
# Generation  269  Accuracy =  43.5
# Generation  270  Accuracy =  43.5
# CREATING SAMPLE
# Generation  271  Accuracy =  53.5
# Generation  272  Accuracy =  53.5
# Generation  273  Accuracy =  53.5
# Generation  274  Accuracy =  53.5
# Generation  275  Accuracy =  53.5
# Generation  276  Accuracy =  53.5
# Generation  277  Accuracy =  53.5
# Generation  278  Accuracy =  53.5
# Generation  279  Accuracy =  53.5
# Generation  280  Accuracy =  53.5
# Generation  281  Accuracy =  53.5
# Generation  282  Accuracy =  53.5
# Generation  283  Accuracy =  53.5
# Generation  284  Accuracy =  53.5
# Generation  285  Accuracy =  53.5
# CREATING SAMPLE
# Generation  286  Accuracy =  50.0
# Generation  287  Accuracy =  50.0
# Generation  288  Accuracy =  50.0
# Generation  289  Accuracy =  50.0
# Generation  290  Accuracy =  50.0
# Generation  291  Accuracy =  50.0
# Generation  292  Accuracy =  50.0
# Generation  293  Accuracy =  50.0
# Generation  294  Accuracy =  50.0
# Generation  295  Accuracy =  50.0
# Generation  296  Accuracy =  50.0
# Generation  297  Accuracy =  50.0
# Generation  298  Accuracy =  50.0
# Generation  299  Accuracy =  50.0
# Generation  300  Accuracy =  50.0
# CREATING SAMPLE
# Generation  301  Accuracy =  49.5
# Generation  302  Accuracy =  49.5
# Generation  303  Accuracy =  49.5
# Generation  304  Accuracy =  49.5
# Generation  305  Accuracy =  49.5
# Generation  306  Accuracy =  49.5
# Generation  307  Accuracy =  49.5
# Generation  308  Accuracy =  49.5
# Generation  309  Accuracy =  49.5
# Generation  310  Accuracy =  49.5
# Generation  311  Accuracy =  49.5
# Generation  312  Accuracy =  49.5
# Generation  313  Accuracy =  49.5
# Generation  314  Accuracy =  49.5
# Generation  315  Accuracy =  49.5
# CREATING SAMPLE
# Generation  316  Accuracy =  46.5
# Generation  317  Accuracy =  48.0
# Generation  318  Accuracy =  49.0
# Generation  319  Accuracy =  49.0
# Generation  320  Accuracy =  51.0
# Generation  321  Accuracy =  51.0
# Generation  322  Accuracy =  51.0
# Generation  323  Accuracy =  51.0
# Generation  324  Accuracy =  51.0
# Generation  325  Accuracy =  51.0
# Generation  326  Accuracy =  51.0
# Generation  327  Accuracy =  51.0
# Generation  328  Accuracy =  51.0
# Generation  329  Accuracy =  52.5
# Generation  330  Accuracy =  52.5
# CREATING SAMPLE
# Generation  331  Accuracy =  57.0
# Generation  332  Accuracy =  57.0
# Generation  333  Accuracy =  57.0
# Generation  334  Accuracy =  57.0
# Generation  335  Accuracy =  57.0
# Generation  336  Accuracy =  57.0
# Generation  337  Accuracy =  57.0
# Generation  338  Accuracy =  57.0
# Generation  339  Accuracy =  57.0
# Generation  340  Accuracy =  57.0
# Generation  341  Accuracy =  58.5
# Generation  342  Accuracy =  58.5
# Generation  343  Accuracy =  58.5
# Generation  344  Accuracy =  58.5
# Generation  345  Accuracy =  58.5
# CREATING SAMPLE
# Generation  346  Accuracy =  54.0
# Generation  347  Accuracy =  54.0
# Generation  348  Accuracy =  54.0
# Generation  349  Accuracy =  54.0
# Generation  350  Accuracy =  54.0
# Generation  351  Accuracy =  54.0
# Generation  352  Accuracy =  54.0
# Generation  353  Accuracy =  54.0
# Generation  354  Accuracy =  54.0
# Generation  355  Accuracy =  54.0
# Generation  356  Accuracy =  54.0
# Generation  357  Accuracy =  54.0
# Generation  358  Accuracy =  54.0
# Generation  359  Accuracy =  54.0
# Generation  360  Accuracy =  54.0
# CREATING SAMPLE
# Generation  361  Accuracy =  53.0
# Generation  362  Accuracy =  53.0
# Generation  363  Accuracy =  53.0
# Generation  364  Accuracy =  53.0
# Generation  365  Accuracy =  53.0
# Generation  366  Accuracy =  53.0
# Generation  367  Accuracy =  53.0
# Generation  368  Accuracy =  53.0
# Generation  369  Accuracy =  53.0
# Generation  370  Accuracy =  53.0
# Generation  371  Accuracy =  54.0
# Generation  372  Accuracy =  54.0
# Generation  373  Accuracy =  54.0
# Generation  374  Accuracy =  54.0
# Generation  375  Accuracy =  54.0
# CREATING SAMPLE
# Generation  376  Accuracy =  57.5
# Generation  377  Accuracy =  57.5
# Generation  378  Accuracy =  57.5
# Generation  379  Accuracy =  57.5
# Generation  380  Accuracy =  57.5
# Generation  381  Accuracy =  57.5
# Generation  382  Accuracy =  57.5
# Generation  383  Accuracy =  57.5
# Generation  384  Accuracy =  57.5
# Generation  385  Accuracy =  57.5
# Generation  386  Accuracy =  57.5
# Generation  387  Accuracy =  57.5
# Generation  388  Accuracy =  57.5
# Generation  389  Accuracy =  57.5
# Generation  390  Accuracy =  57.5
# CREATING SAMPLE
# Generation  391  Accuracy =  53.5
# Generation  392  Accuracy =  53.5
# Generation  393  Accuracy =  53.5
# Generation  394  Accuracy =  54.0
# Generation  395  Accuracy =  54.0
# Generation  396  Accuracy =  54.0
# Generation  397  Accuracy =  54.0
# Generation  398  Accuracy =  54.0
# Generation  399  Accuracy =  54.0
# Generation  400  Accuracy =  54.0
# Generation  401  Accuracy =  54.0
# Generation  402  Accuracy =  54.0
# Generation  403  Accuracy =  54.0
# Generation  404  Accuracy =  54.0
# Generation  405  Accuracy =  54.0
# CREATING SAMPLE
# Generation  406  Accuracy =  52.5
# Generation  407  Accuracy =  52.5
# Generation  408  Accuracy =  52.5
# Generation  409  Accuracy =  52.5
# Generation  410  Accuracy =  52.5
# Generation  411  Accuracy =  52.5
# Generation  412  Accuracy =  52.5
# Generation  413  Accuracy =  52.5
# Generation  414  Accuracy =  52.5
# Generation  415  Accuracy =  52.5
# Generation  416  Accuracy =  52.5
# Generation  417  Accuracy =  52.5
# Generation  418  Accuracy =  52.5
# Generation  419  Accuracy =  52.5
# Generation  420  Accuracy =  52.5
# CREATING SAMPLE
# Generation  421  Accuracy =  56.5
# Generation  422  Accuracy =  56.5
# Generation  423  Accuracy =  56.5
# Generation  424  Accuracy =  56.5
# Generation  425  Accuracy =  56.5
# Generation  426  Accuracy =  56.5
# Generation  427  Accuracy =  56.5
# Generation  428  Accuracy =  56.5
# Generation  429  Accuracy =  56.5
# Generation  430  Accuracy =  56.5
# Generation  431  Accuracy =  56.5
# Generation  432  Accuracy =  56.5
# Generation  433  Accuracy =  56.5
# Generation  434  Accuracy =  56.5
# Generation  435  Accuracy =  56.5
# CREATING SAMPLE
# Generation  436  Accuracy =  52.0
# Generation  437  Accuracy =  52.0
# Generation  438  Accuracy =  52.0
# Generation  439  Accuracy =  52.0
# Generation  440  Accuracy =  52.0
# Generation  441  Accuracy =  52.0
# Generation  442  Accuracy =  55.0
# Generation  443  Accuracy =  55.0
# Generation  444  Accuracy =  55.0
# Generation  445  Accuracy =  55.0
# Generation  446  Accuracy =  55.0
# Generation  447  Accuracy =  55.0
# Generation  448  Accuracy =  55.0
# Generation  449  Accuracy =  55.0
# Generation  450  Accuracy =  55.0
# CREATING SAMPLE
# Generation  451  Accuracy =  61.5
# ========================================================================
# RUN - 3
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  47.0
# Generation  2  Accuracy =  47.0
# Generation  3  Accuracy =  47.0
# Generation  4  Accuracy =  47.0
# Generation  5  Accuracy =  47.0
# Generation  6  Accuracy =  47.0
# Generation  7  Accuracy =  47.0
# Generation  8  Accuracy =  47.0
# Generation  9  Accuracy =  47.0
# Generation  10  Accuracy =  47.0
# Generation  11  Accuracy =  47.0
# Generation  12  Accuracy =  47.0
# Generation  13  Accuracy =  47.0
# Generation  14  Accuracy =  47.0
# Generation  15  Accuracy =  47.0
# CREATING SAMPLE
# Generation  16  Accuracy =  46.0
# Generation  17  Accuracy =  46.0
# Generation  18  Accuracy =  46.0
# Generation  19  Accuracy =  46.0
# Generation  20  Accuracy =  46.0
# Generation  21  Accuracy =  46.0
# Generation  22  Accuracy =  46.0
# Generation  23  Accuracy =  46.0
# Generation  24  Accuracy =  46.0
# Generation  25  Accuracy =  46.0
# Generation  26  Accuracy =  46.0
# Generation  27  Accuracy =  46.0
# Generation  28  Accuracy =  46.0
# Generation  29  Accuracy =  46.0
# Generation  30  Accuracy =  46.0
# CREATING SAMPLE
# Generation  31  Accuracy =  50.0
# Generation  32  Accuracy =  50.0
# Generation  33  Accuracy =  50.0
# Generation  34  Accuracy =  50.0
# Generation  35  Accuracy =  50.0
# Generation  36  Accuracy =  50.0
# Generation  37  Accuracy =  50.0
# Generation  38  Accuracy =  50.0
# Generation  39  Accuracy =  52.5
# Generation  40  Accuracy =  52.5
# Generation  41  Accuracy =  52.5
# Generation  42  Accuracy =  52.5
# Generation  43  Accuracy =  52.5
# Generation  44  Accuracy =  52.5
# Generation  45  Accuracy =  52.5
# CREATING SAMPLE
# Generation  46  Accuracy =  46.5
# Generation  47  Accuracy =  46.5
# Generation  48  Accuracy =  46.5
# Generation  49  Accuracy =  46.5
# Generation  50  Accuracy =  46.5
# Generation  51  Accuracy =  46.5
# Generation  52  Accuracy =  46.5
# Generation  53  Accuracy =  46.5
# Generation  54  Accuracy =  46.5
# Generation  55  Accuracy =  46.5
# Generation  56  Accuracy =  46.5
# Generation  57  Accuracy =  46.5
# Generation  58  Accuracy =  46.5
# Generation  59  Accuracy =  46.5
# Generation  60  Accuracy =  46.5
# CREATING SAMPLE
# Generation  61  Accuracy =  52.5
# Generation  62  Accuracy =  52.5
# Generation  63  Accuracy =  52.5
# Generation  64  Accuracy =  52.5
# Generation  65  Accuracy =  52.5
# Generation  66  Accuracy =  52.5
# Generation  67  Accuracy =  52.5
# Generation  68  Accuracy =  52.5
# Generation  69  Accuracy =  52.5
# Generation  70  Accuracy =  52.5
# Generation  71  Accuracy =  52.5
# Generation  72  Accuracy =  52.5
# Generation  73  Accuracy =  52.5
# Generation  74  Accuracy =  53.0
# Generation  75  Accuracy =  53.0
# CREATING SAMPLE
# Generation  76  Accuracy =  50.5
# Generation  77  Accuracy =  50.5
# Generation  78  Accuracy =  50.5
# Generation  79  Accuracy =  50.5
# Generation  80  Accuracy =  50.5
# Generation  81  Accuracy =  50.5
# Generation  82  Accuracy =  50.5
# Generation  83  Accuracy =  50.5
# Generation  84  Accuracy =  50.5
# Generation  85  Accuracy =  50.5
# Generation  86  Accuracy =  50.5
# Generation  87  Accuracy =  50.5
# Generation  88  Accuracy =  50.5
# Generation  89  Accuracy =  50.5
# Generation  90  Accuracy =  50.5
# CREATING SAMPLE
# Generation  91  Accuracy =  49.0
# Generation  92  Accuracy =  49.0
# Generation  93  Accuracy =  49.0
# Generation  94  Accuracy =  49.0
# Generation  95  Accuracy =  49.0
# Generation  96  Accuracy =  49.0
# Generation  97  Accuracy =  49.0
# Generation  98  Accuracy =  49.0
# Generation  99  Accuracy =  49.0
# Generation  100  Accuracy =  49.0
# Generation  101  Accuracy =  49.0
# Generation  102  Accuracy =  49.0
# Generation  103  Accuracy =  49.0
# Generation  104  Accuracy =  49.0
# Generation  105  Accuracy =  49.0
# CREATING SAMPLE
# Generation  106  Accuracy =  52.0
# Generation  107  Accuracy =  52.0
# Generation  108  Accuracy =  52.0
# Generation  109  Accuracy =  52.0
# Generation  110  Accuracy =  52.0
# Generation  111  Accuracy =  52.0
# Generation  112  Accuracy =  52.0
# Generation  113  Accuracy =  52.0
# Generation  114  Accuracy =  52.0
# Generation  115  Accuracy =  52.0
# Generation  116  Accuracy =  52.0
# Generation  117  Accuracy =  52.0
# Generation  118  Accuracy =  52.0
# Generation  119  Accuracy =  52.0
# Generation  120  Accuracy =  52.0
# CREATING SAMPLE
# Generation  121  Accuracy =  54.5
# Generation  122  Accuracy =  54.5
# Generation  123  Accuracy =  54.5
# Generation  124  Accuracy =  54.5
# Generation  125  Accuracy =  54.5
# Generation  126  Accuracy =  54.5
# Generation  127  Accuracy =  54.5
# Generation  128  Accuracy =  54.5
# Generation  129  Accuracy =  54.5
# Generation  130  Accuracy =  54.5
# Generation  131  Accuracy =  54.5
# Generation  132  Accuracy =  54.5
# Generation  133  Accuracy =  54.5
# Generation  134  Accuracy =  54.5
# Generation  135  Accuracy =  54.5
# CREATING SAMPLE
# Generation  136  Accuracy =  52.5
# Generation  137  Accuracy =  52.5
# Generation  138  Accuracy =  52.5
# Generation  139  Accuracy =  52.5
# Generation  140  Accuracy =  52.5
# Generation  141  Accuracy =  52.5
# Generation  142  Accuracy =  52.5
# Generation  143  Accuracy =  52.5
# Generation  144  Accuracy =  52.5
# Generation  145  Accuracy =  52.5
# Generation  146  Accuracy =  52.5
# Generation  147  Accuracy =  52.5
# Generation  148  Accuracy =  52.5
# Generation  149  Accuracy =  52.5
# Generation  150  Accuracy =  52.5
# CREATING SAMPLE
# Generation  151  Accuracy =  53.0
# Generation  152  Accuracy =  53.0
# Generation  153  Accuracy =  53.0
# Generation  154  Accuracy =  53.0
# Generation  155  Accuracy =  53.0
# Generation  156  Accuracy =  53.0
# Generation  157  Accuracy =  53.0
# Generation  158  Accuracy =  53.0
# Generation  159  Accuracy =  53.0
# Generation  160  Accuracy =  53.0
# Generation  161  Accuracy =  53.0
# Generation  162  Accuracy =  53.0
# Generation  163  Accuracy =  53.0
# Generation  164  Accuracy =  53.0
# Generation  165  Accuracy =  53.0
# CREATING SAMPLE
# Generation  166  Accuracy =  48.5
# Generation  167  Accuracy =  48.5
# Generation  168  Accuracy =  48.5
# Generation  169  Accuracy =  49.5
# Generation  170  Accuracy =  49.5
# Generation  171  Accuracy =  49.5
# Generation  172  Accuracy =  49.5
# Generation  173  Accuracy =  49.5
# Generation  174  Accuracy =  49.5
# Generation  175  Accuracy =  49.5
# Generation  176  Accuracy =  49.5
# Generation  177  Accuracy =  49.5
# Generation  178  Accuracy =  49.5
# Generation  179  Accuracy =  51.0
# Generation  180  Accuracy =  51.0
# CREATING SAMPLE
# Generation  181  Accuracy =  54.0
# Generation  182  Accuracy =  54.0
# Generation  183  Accuracy =  54.0
# Generation  184  Accuracy =  54.0
# Generation  185  Accuracy =  54.0
# Generation  186  Accuracy =  54.0
# Generation  187  Accuracy =  54.0
# Generation  188  Accuracy =  54.0
# Generation  189  Accuracy =  54.0
# Generation  190  Accuracy =  54.0
# Generation  191  Accuracy =  58.5
# Generation  192  Accuracy =  58.5
# Generation  193  Accuracy =  58.5
# Generation  194  Accuracy =  58.5
# Generation  195  Accuracy =  58.5
# CREATING SAMPLE
# Generation  196  Accuracy =  55.0
# Generation  197  Accuracy =  55.0
# Generation  198  Accuracy =  55.0
# Generation  199  Accuracy =  55.0
# Generation  200  Accuracy =  55.0
# Generation  201  Accuracy =  58.0
# Generation  202  Accuracy =  58.0
# Generation  203  Accuracy =  58.0
# Generation  204  Accuracy =  58.0
# Generation  205  Accuracy =  58.0
# Generation  206  Accuracy =  58.0
# Generation  207  Accuracy =  58.0
# Generation  208  Accuracy =  58.0
# Generation  209  Accuracy =  58.0
# Generation  210  Accuracy =  58.0
# CREATING SAMPLE
# Generation  211  Accuracy =  56.0
# Generation  212  Accuracy =  56.0
# Generation  213  Accuracy =  56.0
# Generation  214  Accuracy =  56.0
# Generation  215  Accuracy =  56.0
# Generation  216  Accuracy =  56.0
# Generation  217  Accuracy =  56.0
# Generation  218  Accuracy =  56.0
# Generation  219  Accuracy =  56.0
# Generation  220  Accuracy =  56.0
# Generation  221  Accuracy =  56.0
# Generation  222  Accuracy =  56.0
# Generation  223  Accuracy =  56.0
# Generation  224  Accuracy =  56.0
# Generation  225  Accuracy =  56.0
# CREATING SAMPLE
# Generation  226  Accuracy =  57.0
# Generation  227  Accuracy =  57.0
# Generation  228  Accuracy =  57.0
# Generation  229  Accuracy =  59.0
# Generation  230  Accuracy =  59.0
# Generation  231  Accuracy =  59.0
# Generation  232  Accuracy =  59.0
# Generation  233  Accuracy =  59.0
# Generation  234  Accuracy =  59.0
# Generation  235  Accuracy =  59.0
# Generation  236  Accuracy =  59.0
# Generation  237  Accuracy =  59.0
# Generation  238  Accuracy =  59.0
# Generation  239  Accuracy =  59.0
# Generation  240  Accuracy =  59.0
# CREATING SAMPLE
# Generation  241  Accuracy =  60.0
# ========================================================================
# RUN - 4
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  50.5
# Generation  2  Accuracy =  50.5
# Generation  3  Accuracy =  50.5
# Generation  4  Accuracy =  50.5
# Generation  5  Accuracy =  50.5
# Generation  6  Accuracy =  50.5
# Generation  7  Accuracy =  50.5
# Generation  8  Accuracy =  51.5
# Generation  9  Accuracy =  51.5
# Generation  10  Accuracy =  51.5
# Generation  11  Accuracy =  51.5
# Generation  12  Accuracy =  51.5
# Generation  13  Accuracy =  51.5
# Generation  14  Accuracy =  51.5
# Generation  15  Accuracy =  51.5
# CREATING SAMPLE
# Generation  16  Accuracy =  48.5
# Generation  17  Accuracy =  48.5
# Generation  18  Accuracy =  49.5
# Generation  19  Accuracy =  49.5
# Generation  20  Accuracy =  49.5
# Generation  21  Accuracy =  49.5
# Generation  22  Accuracy =  49.5
# Generation  23  Accuracy =  49.5
# Generation  24  Accuracy =  49.5
# Generation  25  Accuracy =  49.5
# Generation  26  Accuracy =  49.5
# Generation  27  Accuracy =  49.5
# Generation  28  Accuracy =  49.5
# Generation  29  Accuracy =  50.0
# Generation  30  Accuracy =  50.0
# CREATING SAMPLE
# Generation  31  Accuracy =  45.5
# Generation  32  Accuracy =  45.5
# Generation  33  Accuracy =  45.5
# Generation  34  Accuracy =  47.0
# Generation  35  Accuracy =  47.0
# Generation  36  Accuracy =  47.0
# Generation  37  Accuracy =  47.0
# Generation  38  Accuracy =  47.0
# Generation  39  Accuracy =  47.0
# Generation  40  Accuracy =  47.0
# Generation  41  Accuracy =  47.0
# Generation  42  Accuracy =  47.0
# Generation  43  Accuracy =  47.0
# Generation  44  Accuracy =  47.0
# Generation  45  Accuracy =  47.0
# CREATING SAMPLE
# Generation  46  Accuracy =  53.0
# Generation  47  Accuracy =  53.0
# Generation  48  Accuracy =  53.0
# Generation  49  Accuracy =  53.0
# Generation  50  Accuracy =  53.0
# Generation  51  Accuracy =  53.0
# Generation  52  Accuracy =  53.0
# Generation  53  Accuracy =  53.0
# Generation  54  Accuracy =  53.0
# Generation  55  Accuracy =  53.0
# Generation  56  Accuracy =  53.0
# Generation  57  Accuracy =  53.0
# Generation  58  Accuracy =  53.0
# Generation  59  Accuracy =  53.0
# Generation  60  Accuracy =  53.0
# CREATING SAMPLE
# Generation  61  Accuracy =  55.0
# Generation  62  Accuracy =  55.0
# Generation  63  Accuracy =  55.0
# Generation  64  Accuracy =  55.0
# Generation  65  Accuracy =  55.0
# Generation  66  Accuracy =  55.0
# Generation  67  Accuracy =  55.0
# Generation  68  Accuracy =  60.0
# ========================================================================
# Running GA for Dataset: bank desired Accuracy: 85
# ========================================================================
# ========================================================================
# RUN - 0
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  62.5
# Generation  2  Accuracy =  62.5
# Generation  3  Accuracy =  62.5
# Generation  4  Accuracy =  62.5
# Generation  5  Accuracy =  75.5
# Generation  6  Accuracy =  75.5
# Generation  7  Accuracy =  75.5
# Generation  8  Accuracy =  75.5
# Generation  9  Accuracy =  75.5
# Generation  10  Accuracy =  75.5
# Generation  11  Accuracy =  75.5
# Generation  12  Accuracy =  75.5
# Generation  13  Accuracy =  75.5
# Generation  14  Accuracy =  75.5
# Generation  15  Accuracy =  75.5
# CREATING SAMPLE
# Generation  16  Accuracy =  71.0
# Generation  17  Accuracy =  71.0
# Generation  18  Accuracy =  71.0
# Generation  19  Accuracy =  71.0
# Generation  20  Accuracy =  74.0
# Generation  21  Accuracy =  74.0
# Generation  22  Accuracy =  74.0
# Generation  23  Accuracy =  74.0
# Generation  24  Accuracy =  74.0
# Generation  25  Accuracy =  74.0
# Generation  26  Accuracy =  74.0
# Generation  27  Accuracy =  74.0
# Generation  28  Accuracy =  74.0
# Generation  29  Accuracy =  74.0
# Generation  30  Accuracy =  74.0
# CREATING SAMPLE
# Generation  31  Accuracy =  79.0
# Generation  32  Accuracy =  79.0
# Generation  33  Accuracy =  79.0
# Generation  34  Accuracy =  79.0
# Generation  35  Accuracy =  79.0
# Generation  36  Accuracy =  79.0
# Generation  37  Accuracy =  79.0
# Generation  38  Accuracy =  79.0
# Generation  39  Accuracy =  79.0
# Generation  40  Accuracy =  79.0
# Generation  41  Accuracy =  79.0
# Generation  42  Accuracy =  79.0
# Generation  43  Accuracy =  79.0
# Generation  44  Accuracy =  79.0
# Generation  45  Accuracy =  79.0
# CREATING SAMPLE
# Generation  46  Accuracy =  75.0
# Generation  47  Accuracy =  75.0
# Generation  48  Accuracy =  75.0
# Generation  49  Accuracy =  75.0
# Generation  50  Accuracy =  75.0
# Generation  51  Accuracy =  75.0
# Generation  52  Accuracy =  75.0
# Generation  53  Accuracy =  75.0
# Generation  54  Accuracy =  75.0
# Generation  55  Accuracy =  75.0
# Generation  56  Accuracy =  75.0
# Generation  57  Accuracy =  75.0
# Generation  58  Accuracy =  75.0
# Generation  59  Accuracy =  75.0
# Generation  60  Accuracy =  75.0
# CREATING SAMPLE
# Generation  61  Accuracy =  75.5
# Generation  62  Accuracy =  75.5
# Generation  63  Accuracy =  75.5
# Generation  64  Accuracy =  75.5
# Generation  65  Accuracy =  75.5
# Generation  66  Accuracy =  75.5
# Generation  67  Accuracy =  75.5
# Generation  68  Accuracy =  75.5
# Generation  69  Accuracy =  76.0
# Generation  70  Accuracy =  76.0
# Generation  71  Accuracy =  76.0
# Generation  72  Accuracy =  76.0
# Generation  73  Accuracy =  76.0
# Generation  74  Accuracy =  76.0
# Generation  75  Accuracy =  76.0
# CREATING SAMPLE
# Generation  76  Accuracy =  78.0
# Generation  77  Accuracy =  78.0
# Generation  78  Accuracy =  78.0
# Generation  79  Accuracy =  78.0
# Generation  80  Accuracy =  78.0
# Generation  81  Accuracy =  78.0
# Generation  82  Accuracy =  78.0
# Generation  83  Accuracy =  78.5
# Generation  84  Accuracy =  78.5
# Generation  85  Accuracy =  78.5
# Generation  86  Accuracy =  78.5
# Generation  87  Accuracy =  78.5
# Generation  88  Accuracy =  78.5
# Generation  89  Accuracy =  78.5
# Generation  90  Accuracy =  78.5
# CREATING SAMPLE
# Generation  91  Accuracy =  77.5
# Generation  92  Accuracy =  77.5
# Generation  93  Accuracy =  77.5
# Generation  94  Accuracy =  77.5
# Generation  95  Accuracy =  77.5
# Generation  96  Accuracy =  77.5
# Generation  97  Accuracy =  77.5
# Generation  98  Accuracy =  77.5
# Generation  99  Accuracy =  77.5
# Generation  100  Accuracy =  77.5
# Generation  101  Accuracy =  77.5
# Generation  102  Accuracy =  77.5
# Generation  103  Accuracy =  77.5
# Generation  104  Accuracy =  77.5
# Generation  105  Accuracy =  77.5
# CREATING SAMPLE
# Generation  106  Accuracy =  74.0
# Generation  107  Accuracy =  74.0
# Generation  108  Accuracy =  74.0
# Generation  109  Accuracy =  74.0
# Generation  110  Accuracy =  74.0
# Generation  111  Accuracy =  74.0
# Generation  112  Accuracy =  74.0
# Generation  113  Accuracy =  74.0
# Generation  114  Accuracy =  74.5
# Generation  115  Accuracy =  74.5
# Generation  116  Accuracy =  74.5
# Generation  117  Accuracy =  74.5
# Generation  118  Accuracy =  74.5
# Generation  119  Accuracy =  74.5
# Generation  120  Accuracy =  74.5
# CREATING SAMPLE
# Generation  121  Accuracy =  73.5
# Generation  122  Accuracy =  73.5
# Generation  123  Accuracy =  73.5
# Generation  124  Accuracy =  73.5
# Generation  125  Accuracy =  73.5
# Generation  126  Accuracy =  73.5
# Generation  127  Accuracy =  73.5
# Generation  128  Accuracy =  73.5
# Generation  129  Accuracy =  74.0
# Generation  130  Accuracy =  74.0
# Generation  131  Accuracy =  74.0
# Generation  132  Accuracy =  74.0
# Generation  133  Accuracy =  74.0
# Generation  134  Accuracy =  74.0
# Generation  135  Accuracy =  74.0
# CREATING SAMPLE
# Generation  136  Accuracy =  78.0
# Generation  137  Accuracy =  78.0
# Generation  138  Accuracy =  78.0
# Generation  139  Accuracy =  78.0
# Generation  140  Accuracy =  78.0
# Generation  141  Accuracy =  78.0
# Generation  142  Accuracy =  78.0
# Generation  143  Accuracy =  78.0
# Generation  144  Accuracy =  78.0
# Generation  145  Accuracy =  78.0
# Generation  146  Accuracy =  78.0
# Generation  147  Accuracy =  78.0
# Generation  148  Accuracy =  78.0
# Generation  149  Accuracy =  78.0
# Generation  150  Accuracy =  78.0
# CREATING SAMPLE
# Generation  151  Accuracy =  77.5
# Generation  152  Accuracy =  77.5
# Generation  153  Accuracy =  77.5
# Generation  154  Accuracy =  77.5
# Generation  155  Accuracy =  77.5
# Generation  156  Accuracy =  77.5
# Generation  157  Accuracy =  77.5
# Generation  158  Accuracy =  77.5
# Generation  159  Accuracy =  77.5
# Generation  160  Accuracy =  77.5
# Generation  161  Accuracy =  77.5
# Generation  162  Accuracy =  77.5
# Generation  163  Accuracy =  77.5
# Generation  164  Accuracy =  77.5
# Generation  165  Accuracy =  77.5
# CREATING SAMPLE
# Generation  166  Accuracy =  74.5
# Generation  167  Accuracy =  74.5
# Generation  168  Accuracy =  74.5
# Generation  169  Accuracy =  74.5
# Generation  170  Accuracy =  74.5
# Generation  171  Accuracy =  75.0
# Generation  172  Accuracy =  75.0
# Generation  173  Accuracy =  75.0
# Generation  174  Accuracy =  75.0
# Generation  175  Accuracy =  75.0
# Generation  176  Accuracy =  75.0
# Generation  177  Accuracy =  75.0
# Generation  178  Accuracy =  75.0
# Generation  179  Accuracy =  75.0
# Generation  180  Accuracy =  75.0
# CREATING SAMPLE
# Generation  181  Accuracy =  77.5
# Generation  182  Accuracy =  77.5
# Generation  183  Accuracy =  77.5
# Generation  184  Accuracy =  77.5
# Generation  185  Accuracy =  77.5
# Generation  186  Accuracy =  77.5
# Generation  187  Accuracy =  77.5
# Generation  188  Accuracy =  77.5
# Generation  189  Accuracy =  77.5
# Generation  190  Accuracy =  78.0
# Generation  191  Accuracy =  78.0
# Generation  192  Accuracy =  78.0
# Generation  193  Accuracy =  78.0
# Generation  194  Accuracy =  78.0
# Generation  195  Accuracy =  78.0
# CREATING SAMPLE
# Generation  196  Accuracy =  79.0
# Generation  197  Accuracy =  79.0
# Generation  198  Accuracy =  79.0
# Generation  199  Accuracy =  79.0
# Generation  200  Accuracy =  79.0
# Generation  201  Accuracy =  79.0
# Generation  202  Accuracy =  79.0
# Generation  203  Accuracy =  79.0
# Generation  204  Accuracy =  79.0
# Generation  205  Accuracy =  79.0
# Generation  206  Accuracy =  79.0
# Generation  207  Accuracy =  79.0
# Generation  208  Accuracy =  79.0
# Generation  209  Accuracy =  79.0
# Generation  210  Accuracy =  79.0
# CREATING SAMPLE
# Generation  211  Accuracy =  80.0
# Generation  212  Accuracy =  80.0
# Generation  213  Accuracy =  80.0
# Generation  214  Accuracy =  80.0
# Generation  215  Accuracy =  80.0
# Generation  216  Accuracy =  80.0
# Generation  217  Accuracy =  80.0
# Generation  218  Accuracy =  80.0
# Generation  219  Accuracy =  80.0
# Generation  220  Accuracy =  80.0
# Generation  221  Accuracy =  80.0
# Generation  222  Accuracy =  80.0
# Generation  223  Accuracy =  80.0
# Generation  224  Accuracy =  80.0
# Generation  225  Accuracy =  80.0
# CREATING SAMPLE
# Generation  226  Accuracy =  78.5
# Generation  227  Accuracy =  78.5
# Generation  228  Accuracy =  78.5
# Generation  229  Accuracy =  78.5
# Generation  230  Accuracy =  78.5
# Generation  231  Accuracy =  78.5
# Generation  232  Accuracy =  78.5
# Generation  233  Accuracy =  78.5
# Generation  234  Accuracy =  78.5
# Generation  235  Accuracy =  78.5
# Generation  236  Accuracy =  78.5
# Generation  237  Accuracy =  78.5
# Generation  238  Accuracy =  78.5
# Generation  239  Accuracy =  78.5
# Generation  240  Accuracy =  78.5
# CREATING SAMPLE
# Generation  241  Accuracy =  76.5
# Generation  242  Accuracy =  77.0
# Generation  243  Accuracy =  77.0
# Generation  244  Accuracy =  77.0
# Generation  245  Accuracy =  77.0
# Generation  246  Accuracy =  77.0
# Generation  247  Accuracy =  77.0
# ...
# Generation  7  Accuracy =  57.5
# Generation  8  Accuracy =  57.5
# Generation  9  Accuracy =  57.5
# Generation  10  Accuracy =  57.5
# Generation  11  Accuracy =  59.0
# Generation  12  Accuracy =  59.0
# Generation  13  Accuracy =  59.0
# Generation  14  Accuracy =  59.0
# Generation  15  Accuracy =  68.0
# CREATING SAMPLE
# Generation  16  Accuracy =  64.0
# Generation  17  Accuracy =  65.5
# Generation  18  Accuracy =  75.5
# Generation  19  Accuracy =  75.5
# Generation  20  Accuracy =  75.5
# Generation  21  Accuracy =  75.5
# Generation  22  Accuracy =  75.5
# Generation  23  Accuracy =  75.5
# Generation  24  Accuracy =  75.5
# Generation  25  Accuracy =  75.5
# Generation  26  Accuracy =  75.5
# Generation  27  Accuracy =  75.5
# Generation  28  Accuracy =  75.5
# Generation  29  Accuracy =  75.5
# Generation  30  Accuracy =  75.5
# CREATING SAMPLE
# Generation  31  Accuracy =  76.5
# Generation  32  Accuracy =  76.5
# Generation  33  Accuracy =  76.5
# Generation  34  Accuracy =  76.5
# Generation  35  Accuracy =  76.5
# Generation  36  Accuracy =  76.5
# Generation  37  Accuracy =  76.5
# Generation  38  Accuracy =  76.5
# Generation  39  Accuracy =  77.0
# Generation  40  Accuracy =  77.0
# Generation  41  Accuracy =  77.0
# Generation  42  Accuracy =  77.0
# Generation  43  Accuracy =  77.0
# Generation  44  Accuracy =  77.0
# Generation  45  Accuracy =  77.0
# CREATING SAMPLE
# Generation  46  Accuracy =  73.5
# Generation  47  Accuracy =  73.5
# Generation  48  Accuracy =  73.5
# Generation  49  Accuracy =  73.5
# Generation  50  Accuracy =  73.5
# Generation  51  Accuracy =  73.5
# Generation  52  Accuracy =  73.5
# Generation  53  Accuracy =  73.5
# Generation  54  Accuracy =  73.5
# Generation  55  Accuracy =  73.5
# Generation  56  Accuracy =  73.5
# Generation  57  Accuracy =  73.5
# Generation  58  Accuracy =  73.5
# Generation  59  Accuracy =  84.0
# Generation  60  Accuracy =  84.0
# CREATING SAMPLE
# Generation  61  Accuracy =  87.5
# Generation  62  Accuracy =  87.5
# Generation  63  Accuracy =  87.5
# Generation  64  Accuracy =  87.5
# Generation  65  Accuracy =  87.5
# Generation  66  Accuracy =  87.5
# Generation  67  Accuracy =  87.5
# Generation  68  Accuracy =  87.5
# Generation  69  Accuracy =  87.5
# Generation  70  Accuracy =  87.5
# Generation  71  Accuracy =  87.5
# Generation  72  Accuracy =  87.5
# Generation  73  Accuracy =  87.5
# Generation  74  Accuracy =  87.5
# Generation  75  Accuracy =  87.5
# CREATING SAMPLE
# Generation  76  Accuracy =  91.0
# ========================================================================
# RUN - 2
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  53.5
# Generation  2  Accuracy =  53.5
# Generation  3  Accuracy =  53.5
# Generation  4  Accuracy =  53.5
# Generation  5  Accuracy =  53.5
# Generation  6  Accuracy =  60.5
# Generation  7  Accuracy =  60.5
# Generation  8  Accuracy =  60.5
# Generation  9  Accuracy =  60.5
# Generation  10  Accuracy =  71.5
# Generation  11  Accuracy =  71.5
# Generation  12  Accuracy =  71.5
# Generation  13  Accuracy =  71.5
# Generation  14  Accuracy =  71.5
# Generation  15  Accuracy =  71.5
# CREATING SAMPLE
# Generation  16  Accuracy =  64.0
# Generation  17  Accuracy =  64.0
# Generation  18  Accuracy =  64.0
# Generation  19  Accuracy =  64.0
# Generation  20  Accuracy =  64.0
# Generation  21  Accuracy =  64.0
# Generation  22  Accuracy =  64.0
# Generation  23  Accuracy =  64.0
# Generation  24  Accuracy =  64.0
# Generation  25  Accuracy =  64.0
# Generation  26  Accuracy =  64.0
# Generation  27  Accuracy =  64.0
# Generation  28  Accuracy =  64.0
# Generation  29  Accuracy =  64.0
# Generation  30  Accuracy =  64.0
# CREATING SAMPLE
# Generation  31  Accuracy =  72.0
# Generation  32  Accuracy =  72.0
# Generation  33  Accuracy =  72.0
# Generation  34  Accuracy =  72.0
# Generation  35  Accuracy =  72.0
# Generation  36  Accuracy =  72.0
# Generation  37  Accuracy =  72.0
# Generation  38  Accuracy =  72.0
# Generation  39  Accuracy =  72.0
# Generation  40  Accuracy =  72.0
# Generation  41  Accuracy =  72.0
# Generation  42  Accuracy =  72.0
# Generation  43  Accuracy =  72.0
# Generation  44  Accuracy =  72.0
# Generation  45  Accuracy =  72.0
# CREATING SAMPLE
# Generation  46  Accuracy =  70.0
# Generation  47  Accuracy =  70.0
# Generation  48  Accuracy =  70.0
# Generation  49  Accuracy =  70.0
# Generation  50  Accuracy =  70.0
# Generation  51  Accuracy =  70.0
# Generation  52  Accuracy =  70.0
# Generation  53  Accuracy =  70.0
# Generation  54  Accuracy =  70.0
# Generation  55  Accuracy =  70.0
# Generation  56  Accuracy =  70.0
# Generation  57  Accuracy =  70.0
# Generation  58  Accuracy =  70.0
# Generation  59  Accuracy =  70.0
# Generation  60  Accuracy =  70.0
# CREATING SAMPLE
# Generation  61  Accuracy =  64.0
# Generation  62  Accuracy =  64.0
# Generation  63  Accuracy =  64.0
# Generation  64  Accuracy =  64.0
# Generation  65  Accuracy =  64.0
# Generation  66  Accuracy =  79.5
# Generation  67  Accuracy =  79.5
# Generation  68  Accuracy =  79.5
# Generation  69  Accuracy =  79.5
# Generation  70  Accuracy =  79.5
# Generation  71  Accuracy =  79.5
# Generation  72  Accuracy =  79.5
# Generation  73  Accuracy =  79.5
# Generation  74  Accuracy =  79.5
# Generation  75  Accuracy =  79.5
# CREATING SAMPLE
# Generation  76  Accuracy =  81.5
# Generation  77  Accuracy =  81.5
# Generation  78  Accuracy =  81.5
# Generation  79  Accuracy =  81.5
# Generation  80  Accuracy =  81.5
# Generation  81  Accuracy =  81.5
# Generation  82  Accuracy =  83.5
# Generation  83  Accuracy =  83.5
# Generation  84  Accuracy =  83.5
# Generation  85  Accuracy =  83.5
# Generation  86  Accuracy =  83.5
# Generation  87  Accuracy =  83.5
# Generation  88  Accuracy =  83.5
# Generation  89  Accuracy =  83.5
# Generation  90  Accuracy =  83.5
# CREATING SAMPLE
# Generation  91  Accuracy =  82.5
# Generation  92  Accuracy =  82.5
# Generation  93  Accuracy =  82.5
# Generation  94  Accuracy =  82.5
# Generation  95  Accuracy =  82.5
# Generation  96  Accuracy =  82.5
# Generation  97  Accuracy =  82.5
# Generation  98  Accuracy =  82.5
# Generation  99  Accuracy =  82.5
# Generation  100  Accuracy =  82.5
# Generation  101  Accuracy =  82.5
# Generation  102  Accuracy =  82.5
# Generation  103  Accuracy =  82.5
# Generation  104  Accuracy =  82.5
# Generation  105  Accuracy =  82.5
# CREATING SAMPLE
# Generation  106  Accuracy =  83.0
# Generation  107  Accuracy =  83.0
# Generation  108  Accuracy =  83.0
# Generation  109  Accuracy =  83.0
# Generation  110  Accuracy =  83.0
# Generation  111  Accuracy =  83.0
# Generation  112  Accuracy =  83.0
# Generation  113  Accuracy =  83.0
# Generation  114  Accuracy =  89.5
# Generation  115  Accuracy =  89.5
# Generation  116  Accuracy =  89.5
# Generation  117  Accuracy =  89.5
# Generation  118  Accuracy =  89.5
# Generation  119  Accuracy =  89.5
# Generation  120  Accuracy =  89.5
# CREATING SAMPLE
# Generation  121  Accuracy =  85.0
# Generation  122  Accuracy =  85.0
# Generation  123  Accuracy =  86.5
# Generation  124  Accuracy =  86.5
# Generation  125  Accuracy =  86.5
# Generation  126  Accuracy =  86.5
# Generation  127  Accuracy =  86.5
# Generation  128  Accuracy =  86.5
# Generation  129  Accuracy =  86.5
# Generation  130  Accuracy =  86.5
# Generation  131  Accuracy =  86.5
# Generation  132  Accuracy =  86.5
# Generation  133  Accuracy =  86.5
# Generation  134  Accuracy =  93.5
# ========================================================================
# RUN - 3
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  56.5
# Generation  2  Accuracy =  56.5
# Generation  3  Accuracy =  56.5
# Generation  4  Accuracy =  56.5
# Generation  5  Accuracy =  56.5
# Generation  6  Accuracy =  56.5
# Generation  7  Accuracy =  56.5
# Generation  8  Accuracy =  56.5
# Generation  9  Accuracy =  56.5
# Generation  10  Accuracy =  56.5
# Generation  11  Accuracy =  56.5
# Generation  12  Accuracy =  56.5
# Generation  13  Accuracy =  58.5
# Generation  14  Accuracy =  58.5
# Generation  15  Accuracy =  58.5
# CREATING SAMPLE
# Generation  16  Accuracy =  61.0
# Generation  17  Accuracy =  61.0
# Generation  18  Accuracy =  61.0
# Generation  19  Accuracy =  61.0
# Generation  20  Accuracy =  61.0
# Generation  21  Accuracy =  61.0
# Generation  22  Accuracy =  61.0
# Generation  23  Accuracy =  61.0
# Generation  24  Accuracy =  61.0
# Generation  25  Accuracy =  61.0
# Generation  26  Accuracy =  61.0
# Generation  27  Accuracy =  61.0
# Generation  28  Accuracy =  61.0
# Generation  29  Accuracy =  61.0
# Generation  30  Accuracy =  61.0
# CREATING SAMPLE
# Generation  31  Accuracy =  63.0
# Generation  32  Accuracy =  63.0
# Generation  33  Accuracy =  63.0
# Generation  34  Accuracy =  63.0
# Generation  35  Accuracy =  64.0
# Generation  36  Accuracy =  64.0
# Generation  37  Accuracy =  64.0
# Generation  38  Accuracy =  64.0
# Generation  39  Accuracy =  64.0
# Generation  40  Accuracy =  64.0
# Generation  41  Accuracy =  64.0
# Generation  42  Accuracy =  64.0
# Generation  43  Accuracy =  66.0
# Generation  44  Accuracy =  66.0
# Generation  45  Accuracy =  66.0
# CREATING SAMPLE
# Generation  46  Accuracy =  66.5
# Generation  47  Accuracy =  66.5
# Generation  48  Accuracy =  66.5
# Generation  49  Accuracy =  66.5
# Generation  50  Accuracy =  66.5
# Generation  51  Accuracy =  66.5
# Generation  52  Accuracy =  66.5
# Generation  53  Accuracy =  66.5
# Generation  54  Accuracy =  66.5
# Generation  55  Accuracy =  66.5
# Generation  56  Accuracy =  66.5
# Generation  57  Accuracy =  66.5
# Generation  58  Accuracy =  66.5
# Generation  59  Accuracy =  66.5
# Generation  60  Accuracy =  66.5
# CREATING SAMPLE
# Generation  61  Accuracy =  65.0
# Generation  62  Accuracy =  65.0
# Generation  63  Accuracy =  65.0
# Generation  64  Accuracy =  65.0
# Generation  65  Accuracy =  65.0
# Generation  66  Accuracy =  65.5
# Generation  67  Accuracy =  65.5
# Generation  68  Accuracy =  65.5
# Generation  69  Accuracy =  65.5
# Generation  70  Accuracy =  65.5
# Generation  71  Accuracy =  65.5
# Generation  72  Accuracy =  65.5
# Generation  73  Accuracy =  65.5
# Generation  74  Accuracy =  65.5
# Generation  75  Accuracy =  65.5
# CREATING SAMPLE
# Generation  76  Accuracy =  64.5
# Generation  77  Accuracy =  64.5
# Generation  78  Accuracy =  64.5
# Generation  79  Accuracy =  64.5
# Generation  80  Accuracy =  65.0
# Generation  81  Accuracy =  65.0
# Generation  82  Accuracy =  65.0
# Generation  83  Accuracy =  65.0
# Generation  84  Accuracy =  65.0
# Generation  85  Accuracy =  65.0
# Generation  86  Accuracy =  65.0
# Generation  87  Accuracy =  66.5
# Generation  88  Accuracy =  66.5
# Generation  89  Accuracy =  66.5
# Generation  90  Accuracy =  66.5
# CREATING SAMPLE
# Generation  91  Accuracy =  71.0
# Generation  92  Accuracy =  71.0
# Generation  93  Accuracy =  71.0
# Generation  94  Accuracy =  71.0
# Generation  95  Accuracy =  71.0
# Generation  96  Accuracy =  71.0
# Generation  97  Accuracy =  71.5
# Generation  98  Accuracy =  71.5
# Generation  99  Accuracy =  71.5
# Generation  100  Accuracy =  71.5
# Generation  101  Accuracy =  71.5
# Generation  102  Accuracy =  71.5
# Generation  103  Accuracy =  71.5
# Generation  104  Accuracy =  81.0
# Generation  105  Accuracy =  81.0
# CREATING SAMPLE
# Generation  106  Accuracy =  79.0
# Generation  107  Accuracy =  79.0
# Generation  108  Accuracy =  79.0
# Generation  109  Accuracy =  79.0
# Generation  110  Accuracy =  79.0
# Generation  111  Accuracy =  79.0
# Generation  112  Accuracy =  79.0
# Generation  113  Accuracy =  79.0
# Generation  114  Accuracy =  79.0
# Generation  115  Accuracy =  79.0
# Generation  116  Accuracy =  79.0
# Generation  117  Accuracy =  79.0
# Generation  118  Accuracy =  79.0
# Generation  119  Accuracy =  79.0
# Generation  120  Accuracy =  79.0
# CREATING SAMPLE
# Generation  121  Accuracy =  80.0
# Generation  122  Accuracy =  80.0
# Generation  123  Accuracy =  80.0
# Generation  124  Accuracy =  80.0
# Generation  125  Accuracy =  80.0
# Generation  126  Accuracy =  80.0
# Generation  127  Accuracy =  80.0
# Generation  128  Accuracy =  80.0
# Generation  129  Accuracy =  80.0
# Generation  130  Accuracy =  80.0
# Generation  131  Accuracy =  80.0
# Generation  132  Accuracy =  80.0
# Generation  133  Accuracy =  80.0
# Generation  134  Accuracy =  80.0
# Generation  135  Accuracy =  80.0
# CREATING SAMPLE
# Generation  136  Accuracy =  79.0
# Generation  137  Accuracy =  79.0
# Generation  138  Accuracy =  79.0
# Generation  139  Accuracy =  79.0
# Generation  140  Accuracy =  79.0
# Generation  141  Accuracy =  79.0
# Generation  142  Accuracy =  79.0
# Generation  143  Accuracy =  79.0
# Generation  144  Accuracy =  79.0
# Generation  145  Accuracy =  79.5
# Generation  146  Accuracy =  79.5
# Generation  147  Accuracy =  79.5
# Generation  148  Accuracy =  79.5
# Generation  149  Accuracy =  79.5
# Generation  150  Accuracy =  79.5
# CREATING SAMPLE
# Generation  151  Accuracy =  84.0
# Generation  152  Accuracy =  84.0
# Generation  153  Accuracy =  84.0
# Generation  154  Accuracy =  84.0
# Generation  155  Accuracy =  84.0
# Generation  156  Accuracy =  84.0
# Generation  157  Accuracy =  84.0
# Generation  158  Accuracy =  84.0
# Generation  159  Accuracy =  84.0
# Generation  160  Accuracy =  84.0
# Generation  161  Accuracy =  84.0
# Generation  162  Accuracy =  84.0
# Generation  163  Accuracy =  84.0
# Generation  164  Accuracy =  84.0
# Generation  165  Accuracy =  84.0
# CREATING SAMPLE
# Generation  166  Accuracy =  82.0
# Generation  167  Accuracy =  82.0
# Generation  168  Accuracy =  86.0
# Generation  169  Accuracy =  86.0
# Generation  170  Accuracy =  86.0
# Generation  171  Accuracy =  86.0
# Generation  172  Accuracy =  86.0
# Generation  173  Accuracy =  86.0
# Generation  174  Accuracy =  86.0
# Generation  175  Accuracy =  86.0
# Generation  176  Accuracy =  86.0
# Generation  177  Accuracy =  86.0
# Generation  178  Accuracy =  86.0
# Generation  179  Accuracy =  86.0
# Generation  180  Accuracy =  86.0
# CREATING SAMPLE
# Generation  181  Accuracy =  89.5
# Generation  182  Accuracy =  89.5
# Generation  183  Accuracy =  90.5
# ========================================================================
# RUN - 4
# ========================================================================
# CREATING SAMPLE
# 150 individuals created.
# CREATING SAMPLE
# Generation  1  Accuracy =  62.5
# Generation  2  Accuracy =  62.5
# Generation  3  Accuracy =  62.5
# Generation  4  Accuracy =  62.5
# Generation  5  Accuracy =  62.5
# Generation  6  Accuracy =  62.5
# Generation  7  Accuracy =  62.5
# Generation  8  Accuracy =  62.5
# Generation  9  Accuracy =  62.5
# Generation  10  Accuracy =  62.5
# Generation  11  Accuracy =  62.5
# Generation  12  Accuracy =  62.5
# Generation  13  Accuracy =  62.5
# Generation  14  Accuracy =  62.5
# Generation  15  Accuracy =  62.5
# CREATING SAMPLE
# Generation  16  Accuracy =  67.5
# Generation  17  Accuracy =  67.5
# Generation  18  Accuracy =  67.5
# Generation  19  Accuracy =  67.5
# Generation  20  Accuracy =  67.5
# Generation  21  Accuracy =  67.5
# Generation  22  Accuracy =  67.5
# Generation  23  Accuracy =  67.5
# Generation  24  Accuracy =  67.5
# Generation  25  Accuracy =  67.5
# Generation  26  Accuracy =  67.5
# Generation  27  Accuracy =  67.5
# Generation  28  Accuracy =  67.5
# Generation  29  Accuracy =  67.5
# Generation  30  Accuracy =  67.5
# CREATING SAMPLE
# Generation  31  Accuracy =  71.0
# Generation  32  Accuracy =  71.0
# Generation  33  Accuracy =  71.0
# Generation  34  Accuracy =  71.0
# Generation  35  Accuracy =  71.0
# Generation  36  Accuracy =  71.0
# Generation  37  Accuracy =  71.0
# Generation  38  Accuracy =  71.0
# Generation  39  Accuracy =  71.0
# Generation  40  Accuracy =  71.0
# Generation  41  Accuracy =  71.0
# Generation  42  Accuracy =  75.0
# Generation  43  Accuracy =  76.0
# Generation  44  Accuracy =  76.0
# Generation  45  Accuracy =  76.0
# CREATING SAMPLE
# Generation  46  Accuracy =  74.0
# Generation  47  Accuracy =  74.0
# Generation  48  Accuracy =  74.0
# Generation  49  Accuracy =  74.0
# Generation  50  Accuracy =  74.0
# Generation  51  Accuracy =  74.0
# Generation  52  Accuracy =  74.0
# Generation  53  Accuracy =  74.0
# Generation  54  Accuracy =  77.5
# Generation  55  Accuracy =  79.0
# Generation  56  Accuracy =  79.0
# Generation  57  Accuracy =  88.0
# Generation  58  Accuracy =  88.0
# Generation  59  Accuracy =  88.0
# Generation  60  Accuracy =  88.0
# CREATING SAMPLE
# Generation  61  Accuracy =  91.0

# %%
for dataset in modelInfo.keys():
  print(dataset)
  for model in modelInfo[dataset]:
    print(model.generationCount , model.trainAccuracy[-1], model.testAccuracy[-1])
# Out:
# abalone
# 181 62.5 21.85
# 151 64.5 52.87
# 451 61.5 19.7
# 241 60.0 35.65
# 68 60.0 19.94
# bank
# 500 74.5 81.06
# 250 76.5 67.98
# 190 78.0 75.08
# 340 79.0 85.46
# 130 76.5 72.94
# thyroid
# 204 91.0 93.29
# 76 91.0 86.87
# 134 93.5 90.72
# 183 90.5 90.9
# 61 91.0 83.75

# %%
i = 4
dataset = 'thyroid'


plt.plot(range(len(modelInfo[dataset][i].testAccuracy)), modelInfo[dataset][i].testAccuracy , label= "Test")
plt.plot(range(len(modelInfo[dataset][i].trainAccuracy)), modelInfo[dataset][i].trainAccuracy, label = "Train" )
plt.xlabel("Generations")
plt.ylabel("Accuracy")
plt.title("Overall Accuracy Curve") 
plt.legend()
plt.show()
# Out:
# Text(0.5, 1.0, 'Overall Accuracy Curve')
